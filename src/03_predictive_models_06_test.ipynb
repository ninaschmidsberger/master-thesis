# %%
from gettext import install
import pandas as pd
import numpy as np

from math import sqrt
from pathlib import Path

import warnings
from enum import Enum

from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error


from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNetCV, LassoCV, LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import KFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import json
from pathlib import Path

from sklearn.model_selection import train_test_split


from pandas.core.interchange import dataframe

import matplotlib.pyplot as plt
from statsmodels.iolib import summary

from numpy.linalg import lstsq
from scipy.stats import kruskal
import scikit_posthocs as sp
import statsmodels.formula.api as smf
import seaborn as sns
import xgboost
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_score, GridSearchCV, StratifiedKFold
from sklearn.linear_model import RidgeCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, cohen_kappa_score
from sklearn.linear_model import Ridge

# %% [markdown]
# ## File paths

# %%
input_path = Path("data/input/06_input")
output_path = Path("data/output/06_output")

# %% [markdown]
# ## Parameters

# %%
anchor_correlated_outcome_variables = [
    # pain_right — |rho| >= 0.20 threshold applied
    "V06KOOSKPR",  # KOOS Pain right knee — preferred over WOMAC (contains WOMAC, 0-100 scale)
    "V06P7RKRCV",  # Right knee pain: severity, past 7 days, rated on scale of 0-10
    "V06ICPTSKR",  # ICOAP Right knee: Intermittent and Constant Pain Total Score, 0-100
    "V06KGLRS",    # Global knee rating — patient impression, distinct construct

    # pain_left — |rho| >= 0.20 threshold applied
    "V06KOOSKPL",  # KOOS Pain left knee
    "V06P7LKRCV",  # Left knee pain: severity, past 7 days, rated on scale of 0-10
    "V06ICPTSKL",  # ICOAP Left knee: Intermittent and Constant Pain Total Score

    # sleep — |rho| >= 0.10 threshold applied / "V06WPLKN3" > 0.20
    "V06WPLKN3",   # Left knee pain in bed
    "V06WPRKN3",   # Right knee pain in bed
    "V06CPRKN2",   # Right knee constant pain affecting sleep

    # function — |rho| >= 0.10 threshold applied
    "V0620MPACE",  # 20m walk pace (m/s) — represents full 20m walk cluster
    "V06CSPACE",   # Repeated chair stand: pace in stands/sec
    "V06STEPST1",  # 20-meter walk: trial 1 number of steps
    "V06400MTIM",  # 400-meter walk: total time at 400m or at stop

    # adl — |rho| >= 0.10 threshold applied
    "V06LLD6B",    # LLDI: Extent feel limited in taking part in active recreation
    "V06LLD6A",    # LLDI: How often take part in active recreation
    "V06LLDILST",  # LLDI: Limitation Dimension, Total Score (calculated)
    "V06LLD10B",   # LLDI: Extent feel limited in taking part in regular fitness program

    # self_reported_function_right — |rho| >= 0.20 threshold applied
    "V06DIRKN1",   # Right knee difficulty: down stairs, last 7 days
    "V06DIRKN3",   # Right knee difficulty: stand from sitting, last 7 days
    "V06DIRKN7",   # Right knee difficulty: in car/out of car, last 7 days
    "V06DIRKN2",   # Right knee difficulty: up stairs, last 7 days
    "V06DIRKN8",   # Right knee difficulty: shopping, last 7 days
    "V06DIRKN5",   # Right knee difficulty: bending, last 7 days
    "V06DIRKN6",   # Right knee difficulty: walking, last 7 days
    "V06DIRKN15",  # Right knee difficulty: on/off toilet, last 7 days
    "V06DIRKN16",  # Right knee difficulty: heavy chores, last 7 days
    "V06DIRKN4",   # Right knee difficulty: standing, last 7 days
    "V06DIRKN9",   # Right knee difficulty: socks on, last 7 days
    "V06DIRKN17",  # Right knee difficulty: light chores, last 7 days
    "V06DIRKN13",  # Right knee difficulty: get in/out of bathtub, last 7 days

    # self_reported_function_left — |rho| >= 0.20 threshold applied
    "V06DILKN1",   # Left knee difficulty: down stairs, last 7 days
    "V06DILKN7",   # Left knee difficulty: in car/out of car, last 7 days
    "V06DILKN3",   # Left knee difficulty: stand from sitting, last 7 days
    "V06DILKN6",   # Left knee difficulty: walking, last 7 days
    "V06DILKN8",   # Left knee difficulty: shopping, last 7 days
    "V06DILKN2",   # Left knee difficulty: up stairs, last 7 days
    "V06DILKN4",   # Left knee difficulty: standing, last 7 days
    "V06DILKN5",   # Left knee difficulty: bending, last 7 days
    "V06DILKN16",  # Left knee difficulty: heavy chores, last 7 days
    "V06DILKN13",  # Left knee difficulty: get in/out of bathtub, last 7 days
    "V06DILKN10",  # Left knee difficulty: get out of bed, last 7 days
    "V06DILKN15",  # Left knee difficulty: on/off toilet, last 7 days
    "V06DILKN9",   # Left knee difficulty: socks on, last 7 days
    "V06DILKN17",  # Left knee difficulty: light chores, last 7 days
    "V06DILKN12",  # Left knee difficulty: lying down, last 7 days

    # self_reported_function_bilateral — |rho| >= 0.20 threshold applied
    "V06KOOSFX2",  # Either knee difficulty: running, last 7 days
    "V06KOOSFX4",  # Either knee difficulty: twisting/pivoting on injured knee, last 7 days
    "V06KOOSFX1",  # Either knee difficulty: squatting, last 7 days
    "V06KOOSFX5",  # Either knee difficulty: kneeling, last 7 days
]

# %%
PREDICTOR_COLUMNS = [
    "V06AACNT",
    "V06AALTMNT",
    "V06AAMDMNT",
    "V06AAMVMNT",
    "V06AAVMNT",
    "V06AAMVBMT",
    "V06AAVBMT",
    "V06ANVDAYS",
    "V06AACSM03",
    "V06ADHHS8",
    "V06ADHHSD8",
    "wake_minute_mean",
    "wake_minute_sd",
    "V06CESD11",
    "sleep_minute_mean",
    "sleep_minute_sd",
    "wear_duration_mean",
    "valid_days",
    "weekly_guideline_gap_minutes",
    "mean_sedentary_bout_count",
    "mean_sedentary_bout_mean_duration",
    "mean_sedentary_bout_max_duration",
    "mean_sedentary_bout_total_minutes",
    "mean_light_bout_count",
    "mean_light_bout_mean_duration",
    "mean_light_bout_max_duration",
    "mean_light_bout_total_minutes",
    "mean_moderate_bout_count",
    "mean_moderate_bout_mean_duration",
    "mean_moderate_bout_max_duration",
    "mean_moderate_bout_total_minutes",
    "mean_vigorous_bout_count",
    "mean_vigorous_bout_mean_duration",
    "mean_vigorous_bout_max_duration",
    "mean_vigorous_bout_total_minutes",
    "mean_mvpa_bout_count",
    "mean_mvpa_bout_mean_duration",
    "mean_mvpa_bout_max_duration",
    "mean_mvpa_bout_total_minutes",
    "mean_active_bout_count",
    "mean_active_bout_mean_duration",
    "mean_active_bout_max_duration",
    "mean_active_bout_total_minutes",
]

# %%
HARMONIC_PREDICTOR_COLUMNS = [
'mesor', 'amplitude', 'acrophase', 'intradaily_variability', 'interdaily_stability', 'mesor_mean_curve_weekday', 'mesor_mean_curve_weekend', 'amplitude_mean_curve_weekday', 'amplitude_mean_curve_weekend', 'acrophase_mean_curve_weekday', 'acrophase_mean_curve_weekend', 'iv_weekday', 'iv_weekend', 'iv_contrast']

# %%
FINAL_PREDICTOR_COLUMNS = [
    # Sleep / wear
    "wake_minute_mean",                # Mean wake time across valid days
    "wake_minute_sd",                  # Standard deviation of wake time
    "wear_duration_mean",              # Mean daily wear duration in minutes

    # Bout structure: sedentary
    "mean_sedentary_bout_count",
    "mean_sedentary_bout_mean_duration",
    "mean_sedentary_bout_max_duration",
    "mean_sedentary_bout_total_minutes",

    # Bout structure: light
    "mean_light_bout_max_duration",

    # Bout structure: MVPA
    "mean_mvpa_bout_count",
    "mean_mvpa_bout_mean_duration",

    # Bout structure: active
    "mean_active_bout_mean_duration",
    "mean_active_bout_max_duration",
    "mean_active_bout_total_minutes",

    # Harmonic features: overall
    "acrophase",                       # Overall acrophase retained — not involved in any redundant pair
    "interdaily_stability",            # IS retained as overall only — day-split not meaningful

    # Harmonic features: day-type specific
    "mesor_mean_curve_weekday",        # Mean activity level on weekdays
    "mesor_mean_curve_weekend",        # Mean activity level on weekends
    "amplitude_mean_curve_weekday",    # Peak-to-mean swing on weekdays
    "amplitude_mean_curve_weekend",    # Peak-to-mean swing on weekends
    "acrophase_mean_curve_weekday",    # Timing of activity peak on weekdays
    "acrophase_mean_curve_weekend",    # Timing of activity peak on weekends

    # IV: day-type specific
    "iv_weekday",                      # Within-day fragmentation on weekdays
    "iv_weekend",                      # Within-day fragmentation on weekends
    "iv_contrast",                     # iv_weekday - iv_weekend: work-related fragmentation burden
]

# %% [markdown]
# ## Read data

# %%
summary_metrics_06 = pd.read_csv(output_path / "summary_metrics_06.csv", sep="|", na_values=[" ", ""],)

# %% [markdown]
# # 1. Prediction models without harmonic features

# %% [markdown]
# ## 1.1. Linear Regression

# %%
def predict_outcome(
        dataframe: pd.DataFrame,
        predictor_columns: list[str],
        outcome_column: str,
) -> None:
    """
    Fits a multivariate OLS linear regression model to predict a single
    outcome variable from a given set of predictors and prints a full
    model summary.

    :param dataframe: DataFrame containing all predictor and outcome columns.
    :param predictor_columns: List of column names to use as predictors.
    :param outcome_column: Column name of the outcome variable to predict.
    :return: None
    :raises TypeError: If any predictor column cannot be cast to float64.
    """
    clean_dataframe = (
        dataframe[predictor_columns + [outcome_column]]
        .replace(r'^\s*$', np.nan, regex=True)
        .dropna()
    )

    try:
        predictor_matrix = clean_dataframe[predictor_columns].to_numpy(dtype=np.float64)
    except (ValueError, TypeError) as error:
        non_numeric_columns = (
            clean_dataframe[predictor_columns]
            .select_dtypes(exclude="number")
            .columns
            .tolist()
        )
        raise TypeError(
            f"Could not cast predictor columns to float64. "
            f"Non-numeric columns detected: {non_numeric_columns}"
        ) from error

    outcome_vector = clean_dataframe[outcome_column].to_numpy(dtype=np.float64)

    predictor_matrix_train, predictor_matrix_test, outcome_train, outcome_test = train_test_split(
        predictor_matrix,
        outcome_vector,
        test_size=0.2,
        random_state=42,
    )

    model = LinearRegression()
    model.fit(predictor_matrix_train, outcome_train)

    outcome_train_predicted = model.predict(predictor_matrix_train)
    outcome_test_predicted = model.predict(predictor_matrix_test)
    residuals = outcome_train - outcome_train_predicted

    number_of_samples, number_of_predictors = predictor_matrix_train.shape
    degrees_of_freedom = number_of_samples - number_of_predictors - 1

    sum_of_squares_residual = np.sum(residuals ** 2)
    sum_of_squares_total = np.sum((outcome_train - outcome_train.mean()) ** 2)
    r_squared = 1 - sum_of_squares_residual / sum_of_squares_total
    adjusted_r_squared = 1 - (1 - r_squared) * (number_of_samples - 1) / degrees_of_freedom
    f_statistic = (r_squared / number_of_predictors) / ((1 - r_squared) / degrees_of_freedom)
    f_p_value = stats.f.sf(f_statistic, number_of_predictors, degrees_of_freedom)

    train_root_mean_squared_error = sqrt(mean_squared_error(outcome_train, outcome_train_predicted))
    test_root_mean_squared_error = sqrt(mean_squared_error(outcome_test, outcome_test_predicted))
    test_r_squared = r2_score(outcome_test, outcome_test_predicted)

    shapiro_statistic, shapiro_p_value = stats.shapiro(residuals)
    durbin_watson_statistic = np.sum(np.diff(residuals) ** 2) / sum_of_squares_residual

    # ── Print results ──────────────────────────────────────────────────────────

    print("=" * 60)
    print(f"MODEL: Predicting '{outcome_column}'")
    print(f"Predictors: {predictor_columns}")
    print("=" * 60)

    print("\n--- COEFFICIENTS ---")
    print(f"  Intercept: {model.intercept_:.4f}")
    for predictor_column, coefficient in zip(predictor_columns, model.coef_):
        print(f"  {predictor_column}: {coefficient:.4f}")

    print("\n--- MODEL FIT ---")
    print(f"  R²:          {r_squared:.4f}")
    print(f"  Adjusted R²: {adjusted_r_squared:.4f}")
    print(f"  F-statistic: {f_statistic:.4f}  (p={f_p_value:.4g})")
    print(f"  n={number_of_samples}  predictors={number_of_predictors}  df={degrees_of_freedom}")

    print("\n--- TRAIN / TEST PERFORMANCE (80/20 split) ---")
    print(f"  Train — R²: {r_squared:.4f}  RMSE: {train_root_mean_squared_error:.4f}")
    print(f"  Test  — R²: {test_r_squared:.4f}  RMSE: {test_root_mean_squared_error:.4f}")
    if r_squared - test_r_squared > 0.1:
        print(f"  ⚠ R² gap of {r_squared - test_r_squared:.3f} may indicate overfitting.")

    print("\n--- RESIDUAL DIAGNOSTICS ---")
    print(f"  Durbin-Watson: {durbin_watson_statistic:.4f}  (2 = no autocorrelation)")
    print(f"  Shapiro-Wilk:  W={shapiro_statistic:.4f}  p={shapiro_p_value:.4f}", end="  ")
    print("✓ approx. normal" if shapiro_p_value > 0.05 else "⚠ may not be normal")


predictor_columns = [
    # Derived sleep metrics (accelerometry-based)
    "wake_minute_mean",
    "wake_minute_sd",
    "wear_duration_mean",

    # Bout structure: sedentary
    "mean_sedentary_bout_count",
    "mean_sedentary_bout_mean_duration",
    "mean_sedentary_bout_max_duration",
    "mean_sedentary_bout_total_minutes",

    # Bout structure: light
    "mean_light_bout_count",
    "mean_light_bout_mean_duration",
    "mean_light_bout_max_duration",

    # Bout structure: MVPA
    "mean_mvpa_bout_count",
    "mean_mvpa_bout_mean_duration",
    "mean_mvpa_bout_max_duration",

    # Bout structure: active (all non-sedentary)
    "mean_active_bout_count",
    "mean_active_bout_mean_duration",
    "mean_active_bout_max_duration",
    "mean_active_bout_total_minutes",
]

summary_metrics_06 = summary_metrics_06.copy()
summary_metrics_06["koos_pain_bilateral"] = summary_metrics_06[["V06KOOSKPR", "V06KOOSKPL"]].min(axis=1)

outcome_column = "koos_pain_bilateral"

# %%
predict_outcome(
    dataframe=summary_metrics_06,
    predictor_columns=predictor_columns,
    outcome_column=outcome_column,
)
# Out:
# ============================================================
# MODEL: Predicting 'koos_pain_bilateral'
# Predictors: ['wake_minute_mean', 'wake_minute_sd', 'wear_duration_mean', 'mean_sedentary_bout_count', 'mean_sedentary_bout_mean_duration', 'mean_sedentary_bout_max_duration', 'mean_sedentary_bout_total_minutes', 'mean_light_bout_count', 'mean_light_bout_mean_duration', 'mean_light_bout_max_duration', 'mean_mvpa_bout_count', 'mean_mvpa_bout_mean_duration', 'mean_mvpa_bout_max_duration', 'mean_active_bout_count', 'mean_active_bout_mean_duration', 'mean_active_bout_max_duration', 'mean_active_bout_total_minutes']
# ============================================================
#
# --- COEFFICIENTS ---
#   Intercept: 65.2527
#   wake_minute_mean: 0.0049
#   wake_minute_sd: -0.0035
#   wear_duration_mean: -0.0019
#   mean_sedentary_bout_count: -3.3577
#   mean_sedentary_bout_mean_duration: -0.0771
#   mean_sedentary_bout_max_duration: -0.0199
#   mean_sedentary_bout_total_minutes: 0.0356
#   mean_light_bout_count: -1.5880
#   mean_light_bout_mean_duration: -2.4721
#   mean_light_bout_max_duration: -0.0844
#   mean_mvpa_bout_count: 1.2889
#   mean_mvpa_bout_mean_duration: 0.1086
#   mean_mvpa_bout_max_duration: 0.0619
#   mean_active_bout_count: 4.7925
#   mean_active_bout_mean_duration: -0.7199
#   mean_active_bout_max_duration: 0.0987
#   mean_active_bout_total_minutes: 0.0635
#
# --- MODEL FIT ---
#   R²:          0.0595
#   Adjusted R²: 0.0486
#   F-statistic: 5.4280  (p=6.286e-12)
#   n=1476  predictors=17  df=1458
#
# --- TRAIN / TEST PERFORMANCE (80/20 split) ---
#   Train — R²: 0.0595  RMSE: 16.9862
#   Test  — R²: 0.0125  RMSE: 17.9147
#
# --- RESIDUAL DIAGNOSTICS ---
#   Durbin-Watson: 2.0946  (2 = no autocorrelation)
#   Shapiro-Wilk:  W=0.9096  p=0.0000  ⚠ may not be normal

# %% [markdown]
# ## 1.2. Lasso, Elastic Net, Random Forest

# %%
RANDOM_STATE = 42
CROSS_VALIDATION_FOLDS = 10
TEST_SET_FRACTION = 0.20

COVARIATE_COLUMNS = ["V06AGE", "V06BMI", "kl_grade_index_knee", "V06COMORB"]

KL_GRADE_RIGHT_COLUMN = "V06XRKL_Right"
KL_GRADE_LEFT_COLUMN = "V06XRKL_Left"

# %%
def prepare_modelling_dataset(
    dataframe: pd.DataFrame,
    outcome_column: str,
    predictor_columns: list[str],
    covariate_columns: list[str] = COVARIATE_COLUMNS,
) -> tuple[pd.DataFrame, pd.Series, pd.DataFrame, pd.Series]:
    """
    Prepare the modelling dataset by dropping rows with missing values
    in any covariate, predictor, or outcome column, then splitting into
    an 80 % training set and a 20 % held-out test set.

    Stratification for the split is performed on KL grade (binned into
    three groups: 0–1, 2–3, 4) to preserve the severity distribution
    across both splits.

    :param dataframe: Merged DataFrame containing covariates, predictors,
        and outcome variables (one row per patient).
    :param outcome_column: Name of the column to use as the prediction
        target.
    :param predictor_columns: List of activity predictor column names.
    :param covariate_columns: List of covariate column names that are
        always included as a fixed block.
    :returns: Tuple of
        (training_predictors, training_outcome,
         test_predictors, test_outcome)
        where predictors include both covariates and activity columns.
    :raises ValueError: If fewer than 100 complete cases remain after
        dropping missing values, which would make modelling unreliable.
    """
    all_required_columns = covariate_columns + predictor_columns + [outcome_column]
    complete_cases = dataframe[all_required_columns].dropna()

    complete_case_count = len(complete_cases)
    total_count = len(dataframe)
    print(
        f"Complete cases for '{outcome_column}':\n"
        f"  Total patients  : {total_count}\n"
        f"  Complete cases  : {complete_case_count} "
        f"({100 * complete_case_count / total_count:.1f} %)\n"
        f"  Dropped (missing): {total_count - complete_case_count}"
    )

    if complete_case_count < 100:
        raise ValueError(
            f"Only {complete_case_count} complete cases remain for "
            f"'{outcome_column}'. Modelling would be unreliable. "
            f"Consider imputation or relaxing inclusion criteria."
        )

    outcome_series = complete_cases[outcome_column]
    all_predictor_columns = covariate_columns + predictor_columns
    predictor_dataframe = complete_cases[all_predictor_columns]

    # Stratify split on KL grade groups to preserve severity distribution
    kl_grade_bins = pd.cut(
        complete_cases["kl_grade_index_knee"],
        bins=[-0.5, 1.5, 3.5, 4.5],
        labels=["kl_0_1", "kl_2_3", "kl_4"],
    )

    (
        training_predictors,
        test_predictors,
        training_outcome,
        test_outcome,
    ) = train_test_split(
        predictor_dataframe,
        outcome_series,
        test_size=TEST_SET_FRACTION,
        random_state=RANDOM_STATE,
        stratify=kl_grade_bins,
    )

    print(
        f"Train/test split (stratified by KL grade):\n"
        f"  Training set : {len(training_predictors)} patients\n"
        f"  Test set     : {len(test_predictors)} patients"
    )

    return training_predictors, training_outcome, test_predictors, test_outcome


def derive_symptomatic_side_outcome(
    dataframe: pd.DataFrame,
    output_column: str,
    right_column: str | None,
    left_column: str | None,
    higher_is_worse: bool = False,
) -> pd.DataFrame:
    """
    Derive a symptomatic side outcome variable by selecting the more
    symptomatic knee per patient based on the outcome value itself.

    For scales where lower = worse (e.g. KOOS, difficulty items), the side
    with the lower value is selected. For scales where higher = worse
    (e.g. pain severity, pain in bed), the side with the higher value is
    selected. Missing values on one side cause the other side to be
    selected automatically.

    Variables that exist on only one side (right or left column is None)
    are passed through directly without selection logic.

    :param dataframe: Input DataFrame containing one row per patient.
    :param output_column: Name for the derived symptomatic side column.
    :param right_column: Column name for the right knee value, or None
        if the variable only exists for one side.
    :param left_column: Column name for the left knee value, or None
        if the variable only exists for one side.
    :param higher_is_worse: If True, the higher value is selected
        (pain severity scales). If False, the lower value is selected
        (difficulty/function scales).
    :returns: DataFrame with the derived symptomatic side column appended.
    """
    working_dataframe = dataframe.copy()

    # Single-side variables — pass through directly
    if right_column is None and left_column is not None:
        working_dataframe[output_column] = working_dataframe[left_column]
        return working_dataframe
    if left_column is None and right_column is not None:
        working_dataframe[output_column] = working_dataframe[right_column]
        return working_dataframe

    value_right = working_dataframe[right_column]
    value_left = working_dataframe[left_column]

    if higher_is_worse:
        # Higher value = more symptomatic — select the higher side
        use_right = value_right.fillna(-np.inf) >= value_left.fillna(-np.inf)
    else:
        # Lower value = more symptomatic — select the lower side
        use_right = value_right.fillna(np.inf) <= value_left.fillna(np.inf)

    working_dataframe[output_column] = np.where(
        use_right, value_right, value_left
    )

    return working_dataframe


def fit_explanatory_lasso_model(
    training_predictors: pd.DataFrame,
    training_outcome: pd.Series,
    predictor_columns: list[str],
    covariate_columns: list[str] = COVARIATE_COLUMNS,
) -> dict:
    """
    Fit the two-block explanatory model using LASSO regularisation on the
    activity predictor block.

    The baseline model (covariates only, plain OLS) and the full model
    (covariates + LASSO-regularised activity predictors) are both fitted.
    The incremental R² (full minus baseline, evaluated via cross-validation)
    is the key explanatory result.

    Covariates are never regularised — they are passed through as-is.
    Activity predictors are standardised before fitting.

    :param training_predictors: Training set DataFrame containing both
        covariate and activity predictor columns.
    :param training_outcome: Training set outcome Series.
    :param predictor_columns: List of activity predictor column names
        (these will be standardised and regularised).
    :param covariate_columns: List of covariate column names (these are
        included without regularisation).
    :returns: Dictionary with keys:
        - ``baseline_r2_cv``: Cross-validated R² of the baseline model.
        - ``full_r2_cv``: Cross-validated R² of the full LASSO model.
        - ``incremental_r2``: Difference (full minus baseline).
        - ``selected_predictors``: List of activity predictors with
          non-zero LASSO coefficients.
        - ``lasso_coefficients``: Series of non-zero coefficients mapped
          to predictor names.
        - ``optimal_alpha``: The regularisation strength selected by CV.
    """

    covariate_training = training_predictors[covariate_columns]
    activity_training = training_predictors[predictor_columns]

    # --- Baseline model: covariates only, plain OLS ---
    baseline_model = LinearRegression()
    baseline_scores = cross_val_score(
        estimator=baseline_model,
        X=covariate_training,
        y=training_outcome,
        cv=KFold(
            n_splits=CROSS_VALIDATION_FOLDS,
            shuffle=True,
            random_state=RANDOM_STATE,
        ),
        scoring="r2",
    )
    baseline_r2_cv = baseline_scores.mean()

    # --- Full model: covariates (unscaled) + standardised activity predictors ---
    scaler = StandardScaler()
    activity_training_scaled = scaler.fit_transform(activity_training)

    # Concatenate covariates with scaled activity predictors
    full_training_matrix = np.hstack(
        [covariate_training.values, activity_training_scaled]
    )

    lasso_model = LassoCV(
        cv=CROSS_VALIDATION_FOLDS,
        random_state=RANDOM_STATE,
        max_iter=50_000,
    )

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        lasso_model.fit(full_training_matrix, training_outcome)

    full_scores = cross_val_score(
        estimator=lasso_model,
        X=full_training_matrix,
        y=training_outcome,
        cv=KFold(
            n_splits=CROSS_VALIDATION_FOLDS,
            shuffle=True,
            random_state=RANDOM_STATE,
        ),
        scoring="r2",
    )
    full_r2_cv = full_scores.mean()

    # Extract non-zero activity predictor coefficients (skip covariate block)
    number_of_covariates = len(covariate_columns)
    activity_coefficients = lasso_model.coef_[number_of_covariates:]
    non_zero_mask = activity_coefficients != 0

    selected_predictors = [
        column
        for column, is_selected in zip(predictor_columns, non_zero_mask)
        if is_selected
    ]
    lasso_coefficients = pd.Series(
        data=activity_coefficients[non_zero_mask],
        index=selected_predictors,
        name="lasso_coefficient",
    ).sort_values(key=abs, ascending=False)

    incremental_r2 = full_r2_cv - baseline_r2_cv

    print(
        f"\n--- Stage 1: Explanatory LASSO model ---\n"
        f"  Baseline R² (covariates only, 10-fold CV) : {baseline_r2_cv:.4f}\n"
        f"  Full R² (covariates + activity, 10-fold CV): {full_r2_cv:.4f}\n"
        f"  Incremental R² (activity block)           : {incremental_r2:.4f}\n"
        f"  Optimal LASSO alpha                       : {lasso_model.alpha_:.6f}\n"
        f"  Activity predictors selected (non-zero)   : "
        f"{len(selected_predictors)} / {len(predictor_columns)}"
    )

    if selected_predictors:
        print("\n  Non-zero LASSO coefficients (ranked by absolute magnitude):")
        for predictor_name, coefficient_value in lasso_coefficients.items():
            print(f"    {predictor_name:<45} {coefficient_value:+.4f}")

    return {
        "baseline_r2_cv": baseline_r2_cv,
        "full_r2_cv": full_r2_cv,
        "incremental_r2": incremental_r2,
        "selected_predictors": selected_predictors,
        "lasso_coefficients": lasso_coefficients,
        "optimal_alpha": lasso_model.alpha_,
    }


def fit_predictive_elastic_net_model(
    training_predictors: pd.DataFrame,
    training_outcome: pd.Series,
    test_predictors: pd.DataFrame,
    test_outcome: pd.Series,
    predictor_columns: list[str],
    covariate_columns: list[str] = COVARIATE_COLUMNS,
) -> dict:
    """
    Fit an Elastic Net model for maximum predictive accuracy and evaluate
    it on the held-out test set.

    Covariates are included unregularised. Activity predictors are
    standardised. Alpha and l1_ratio are jointly tuned via cross-validation
    on the training set only.

    :param training_predictors: Training set predictor DataFrame.
    :param training_outcome: Training set outcome Series.
    :param test_predictors: Held-out test set predictor DataFrame.
    :param test_outcome: Held-out test set outcome Series.
    :param predictor_columns: Activity predictor column names.
    :param covariate_columns: Covariate column names.
    :returns: Dictionary with keys ``rmse``, ``mae``, ``r2`` evaluated
        on the held-out test set, plus ``optimal_alpha`` and
        ``optimal_l1_ratio``.
    """
    covariate_training = training_predictors[covariate_columns].values
    activity_training = training_predictors[predictor_columns].values
    covariate_test = test_predictors[covariate_columns].values
    activity_test = test_predictors[predictor_columns].values

    scaler = StandardScaler()
    activity_training_scaled = scaler.fit_transform(activity_training)
    activity_test_scaled = scaler.transform(activity_test)

    full_training_matrix = np.hstack([covariate_training, activity_training_scaled])
    full_test_matrix = np.hstack([covariate_test, activity_test_scaled])

    elastic_net_model = ElasticNetCV(
        l1_ratio=[0.1, 0.3, 0.5, 0.7, 0.9, 0.95, 1.0],
        cv=CROSS_VALIDATION_FOLDS,
        random_state=RANDOM_STATE,
        max_iter=50_000,
    )

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        elastic_net_model.fit(full_training_matrix, training_outcome)

    test_predictions = elastic_net_model.predict(full_test_matrix)

    rmse = np.sqrt(mean_squared_error(test_outcome, test_predictions))
    mae = mean_absolute_error(test_outcome, test_predictions)
    r2 = r2_score(test_outcome, test_predictions)

    print(
        f"\n--- Stage 2a: Elastic Net (held-out test set) ---\n"
        f"  R²   : {r2:.4f}\n"
        f"  RMSE : {rmse:.4f}\n"
        f"  MAE  : {mae:.4f}\n"
        f"  Optimal alpha    : {elastic_net_model.alpha_:.6f}\n"
        f"  Optimal l1 ratio : {elastic_net_model.l1_ratio_:.2f}"
    )

    return {
        "rmse": rmse,
        "mae": mae,
        "r2": r2,
        "optimal_alpha": elastic_net_model.alpha_,
        "optimal_l1_ratio": elastic_net_model.l1_ratio_,
    }


def fit_predictive_random_forest_model(
    training_predictors: pd.DataFrame,
    training_outcome: pd.Series,
    test_predictors: pd.DataFrame,
    test_outcome: pd.Series,
    predictor_columns: list[str],
    covariate_columns: list[str] = COVARIATE_COLUMNS,
) -> dict:
    """
    Fit a Random Forest regressor for maximum predictive accuracy and
    evaluate it on the held-out test set.

    Hyperparameters (number of trees, max depth, min samples per leaf)
    are fixed at sensible defaults for a dataset of this size. Feature
    importances (mean decrease in impurity) are reported for the activity
    predictor block.

    :param training_predictors: Training set predictor DataFrame.
    :param training_outcome: Training set outcome Series.
    :param test_predictors: Held-out test set predictor DataFrame.
    :param test_outcome: Held-out test set outcome Series.
    :param predictor_columns: Activity predictor column names.
    :param covariate_columns: Covariate column names.
    :returns: Dictionary with keys ``rmse``, ``mae``, ``r2`` on the
        held-out test set, plus ``feature_importances`` as a Series
        sorted by importance descending.
    """
    all_predictor_columns = covariate_columns + predictor_columns

    training_matrix = training_predictors[all_predictor_columns].values
    test_matrix = test_predictors[all_predictor_columns].values

    random_forest_model = RandomForestRegressor(
        n_estimators=500,
        max_depth=None,
        min_samples_leaf=10,
        n_jobs=-1,
        random_state=RANDOM_STATE,
    )
    random_forest_model.fit(training_matrix, training_outcome)

    test_predictions = random_forest_model.predict(test_matrix)

    rmse = np.sqrt(mean_squared_error(test_outcome, test_predictions))
    mae = mean_absolute_error(test_outcome, test_predictions)
    r2 = r2_score(test_outcome, test_predictions)

    feature_importances = pd.Series(
        data=random_forest_model.feature_importances_,
        index=all_predictor_columns,
        name="importance",
    ).sort_values(ascending=False)

    print(
        f"\n--- Stage 2b: Random Forest (held-out test set) ---\n"
        f"  R²   : {r2:.4f}\n"
        f"  RMSE : {rmse:.4f}\n"
        f"  MAE  : {mae:.4f}\n"
        f"\n  Top 10 feature importances:"
    )
    for feature_name, importance_value in feature_importances.head(10).items():
        print(f"    {feature_name:<45} {importance_value:.4f}")

    return {
        "rmse": rmse,
        "mae": mae,
        "r2": r2,
        "feature_importances": feature_importances,
    }


def summarise_pipeline_results(
    outcome_column: str,
    explanatory_results: dict,
    elastic_net_results: dict,
    random_forest_results: dict,
) -> pd.DataFrame:
    """
    Compile a summary table of results across both stages and all models.

    :param outcome_column: Name of the outcome variable modelled.
    :param explanatory_results: Output of ``fit_explanatory_lasso_model``.
    :param elastic_net_results: Output of ``fit_predictive_elastic_net_model``.
    :param random_forest_results: Output of ``fit_predictive_random_forest_model``.
    :returns: Single-row DataFrame with one column per metric, suitable
        for concatenation across multiple outcome variables.
    """
    summary = {
        "outcome_variable": outcome_column,
        "stage_1_baseline_r2_cv": explanatory_results["baseline_r2_cv"],
        "stage_1_full_r2_cv": explanatory_results["full_r2_cv"],
        "stage_1_incremental_r2": explanatory_results["incremental_r2"],
        "stage_1_selected_predictor_count": len(
            explanatory_results["selected_predictors"]
        ),
        "stage_2_elastic_net_r2_test": elastic_net_results["r2"],
        "stage_2_elastic_net_rmse_test": elastic_net_results["rmse"],
        "stage_2_elastic_net_mae_test": elastic_net_results["mae"],
        "stage_2_random_forest_r2_test": random_forest_results["r2"],
        "stage_2_random_forest_rmse_test": random_forest_results["rmse"],
        "stage_2_random_forest_mae_test": random_forest_results["mae"],
    }

    return pd.DataFrame([summary])


def run_pipeline_for_outcome_group(
    group_name: str,
    merged_dataframe: pd.DataFrame,
    merged_dataframe_with_symptomatic_side: pd.DataFrame,
    activity_predictor_columns: list[str],
    output_path,
) -> pd.DataFrame:
    """
    Run the two-stage predictive modelling pipeline for a named outcome group.

    Available groups:
        - ``pain``          : KOOS pain, ICOAP, pain severity, pain in bed,
                              global rating
        - ``function``      : WOMAC difficulty items, KOOS function items,
                              20m walk, chair stand, 400m walk
        - ``adl``           : LLDI limitation total, ADL items
        - ``activity``      : PASE household and leisure items
        - ``catastrophizing``: Coping strategies catastrophizing score
        - ``all``           : All outcome groups combined

    :param group_name: Name of the outcome group to model. Must be one of
        the groups listed above.
    :param merged_dataframe: Full merged DataFrame after whitespace cleaning
        and ``kl_grade_index_knee`` derivation. Used for bilateral outcomes.
    :param merged_dataframe_with_symptomatic_side: DataFrame with all
        symptomatic side outcome columns derived. Used for knee-specific
        outcomes.
    :param activity_predictor_columns: List of activity predictor column
        names to use in the modelling pipeline.
    :param output_path: Path object pointing to the output directory where
        the results CSV will be saved.
    :returns: DataFrame with one row per outcome variable containing all
        Stage 1 and Stage 2 metrics.
    :raises ValueError: If ``group_name`` is not a recognised group.
    """
    outcome_groups = {
        "pain": {
            "symptomatic_side": [
                "koos_pain_symptomatic_side",
                "icoap_total_symptomatic_side",
                "pain_7day_symptomatic_side",
                "pain_bed_symptomatic_side",
                "global_rating_symptomatic_side",
            ],
            "bilateral": [],
        },
        "self_reported_function": {
            "symptomatic_side": [
                "dirkn1_symptomatic_side",
                "dirkn2_symptomatic_side",
                "dirkn3_symptomatic_side",
                "dirkn4_symptomatic_side",
                "dirkn5_symptomatic_side",
                "dirkn6_symptomatic_side",
                "dirkn7_symptomatic_side",
                "dirkn8_symptomatic_side",
                "dirkn9_symptomatic_side",
                "dirkn13_symptomatic_side",
                "dirkn15_symptomatic_side",
                "dirkn16_symptomatic_side",
                "dirkn17_symptomatic_side",
                "dilkn10_symptomatic_side",
                "dilkn12_symptomatic_side",
            ],
            "bilateral": [
                "V06KOOSFX1",   # Either knee: squatting
                "V06KOOSFX2",   # Either knee: running
                "V06KOOSFX4",   # Either knee: twisting/pivoting
                "V06KOOSFX5",   # Either knee: kneeling
            ],
        },
        "function": {
             "symptomatic_side": [],
            "bilateral": [
                "V0620MPACE",   # 20m walk pace
                "V06CSPACE",    # Chair stand pace
                "V06STEPST1",   # 20m walk steps
                "V06400MTIM",   # 400m walk time
            ],
        },
        "adl": {
            "symptomatic_side": [],
            "bilateral": [
                "V06LLD6B",     # LLDI: limited in active recreation
                "V06LLD6A",     # LLDI: frequency active recreation
                "V06LLDILST",   # LLDI: limitation total score
                "V06LLD10B",    # LLDI: limited in fitness program
            ],
        },
    }

    outcome_groups["all"] = {
        "symptomatic_side": [
            outcome
            for group in outcome_groups.values()
            for outcome in group["symptomatic_side"]
        ],
        "bilateral": [
            outcome
            for group in outcome_groups.values()
            for outcome in group["bilateral"]
        ],
    }

    if group_name not in outcome_groups:
        raise ValueError(
            f"Unknown group '{group_name}'. "
            f"Available groups: {sorted(outcome_groups.keys())}"
        )

    selected_group = outcome_groups[group_name]
    all_outcome_columns = (
        selected_group["symptomatic_side"]
        + selected_group["bilateral"]
    )

    print(
        f"\nRunning pipeline for group '{group_name}' "
        f"({len(all_outcome_columns)} outcome variables)"
    )

    all_results = []

    for outcome_column in all_outcome_columns:

        print(f"\n{'='*60}")
        print(f"Modelling outcome: {outcome_column}")
        print(f"{'='*60}")

        source_dataframe = (
            merged_dataframe_with_symptomatic_side
            if outcome_column in selected_group["symptomatic_side"]
            else merged_dataframe
        )

        try:
            (
                training_predictors,
                training_outcome,
                test_predictors,
                test_outcome,
            ) = prepare_modelling_dataset(
                dataframe=source_dataframe,
                outcome_column=outcome_column,
                predictor_columns=activity_predictor_columns,
            )

            explanatory_results = fit_explanatory_lasso_model(
                training_predictors=training_predictors,
                training_outcome=training_outcome,
                predictor_columns=activity_predictor_columns,
            )

            elastic_net_results = fit_predictive_elastic_net_model(
                training_predictors=training_predictors,
                training_outcome=training_outcome,
                test_predictors=test_predictors,
                test_outcome=test_outcome,
                predictor_columns=activity_predictor_columns,
            )

            random_forest_results = fit_predictive_random_forest_model(
                training_predictors=training_predictors,
                training_outcome=training_outcome,
                test_predictors=test_predictors,
                test_outcome=test_outcome,
                predictor_columns=activity_predictor_columns,
            )

            results_summary = summarise_pipeline_results(
                outcome_column=outcome_column,
                explanatory_results=explanatory_results,
                elastic_net_results=elastic_net_results,
                random_forest_results=random_forest_results,
            )

            all_results.append(results_summary)

        except ValueError as error:
            print(f"  Skipped '{outcome_column}': {error}")

    combined_results = pd.concat(all_results, ignore_index=True)

    output_filename = f"modelling_results_{group_name}.csv"
    combined_results.to_csv(
        output_path / output_filename,
        index=False,
    )
    print(
        f"\nGroup '{group_name}' complete — "
        f"{len(combined_results)} outcomes modelled. "
        f"Results saved to: {output_filename}"
    )

    return combined_results

# %%
MERGED_DATAFRAME_SEPARATOR = "|"

merged_dataframe = pd.read_csv(
    output_path / "summary_metrics_06.csv",
    sep=MERGED_DATAFRAME_SEPARATOR,
    na_values=[" ", ""],
)

# Replace any remaining whitespace-only strings with NaN across all columns
merged_dataframe = merged_dataframe.apply(
    lambda column: column.map(
        lambda value: np.nan
        if isinstance(value, str) and value.strip() == ""
        else value
    )
)

print(f"Loaded merged DataFrame: {merged_dataframe.shape}")

PREDICTOR_COLUMNS = [
    "V06AACNT",
    "V06AALTMNT",
    "V06AAMDMNT",
    "V06AAMVMNT",
    "V06AAVMNT",
    "V06AAMVBMT",
    "V06AAVBMT",
    "V06ANVDAYS",
    "V06AACSM03",
    "V06ADHHS8",
    "V06ADHHSD8",
    "wake_minute_mean",
    "wake_minute_sd",
    "V06CESD11",
    "sleep_minute_mean",
    "sleep_minute_sd",
    "wear_duration_mean",
    "valid_days",
    "weekly_guideline_gap_minutes",
    "mean_sedentary_bout_count",
    "mean_sedentary_bout_mean_duration",
    "mean_sedentary_bout_max_duration",
    "mean_sedentary_bout_total_minutes",
    "mean_light_bout_count",
    "mean_light_bout_mean_duration",
    "mean_light_bout_max_duration",
    "mean_light_bout_total_minutes",
    "mean_moderate_bout_count",
    "mean_moderate_bout_mean_duration",
    "mean_moderate_bout_max_duration",
    "mean_moderate_bout_total_minutes",
    "mean_vigorous_bout_count",
    "mean_vigorous_bout_mean_duration",
    "mean_vigorous_bout_max_duration",
    "mean_vigorous_bout_total_minutes",
    "mean_mvpa_bout_count",
    "mean_mvpa_bout_mean_duration",
    "mean_mvpa_bout_max_duration",
    "mean_mvpa_bout_total_minutes",
    "mean_active_bout_count",
    "mean_active_bout_mean_duration",
    "mean_active_bout_max_duration",
    "mean_active_bout_total_minutes",
]

ACTIVITY_PREDICTOR_COLUMNS = [
    column
    for column in PREDICTOR_COLUMNS
    if column not in COVARIATE_COLUMNS
]

# ---------------------------------------------------------------------------
# Bilateral outcome variable pairs
# ---------------------------------------------------------------------------

# Pairs where LOWER value = worse (KOOS only — 0–100 higher=better)
BILATERAL_PAIRS_LOWER_IS_WORSE = {
    "koos_pain_symptomatic_side":  ("V06KOOSKPR",  "V06KOOSKPL"),
    "dilkn10_symptomatic_side":    (None,           "V06DILKN10"),  # left only
    "dilkn12_symptomatic_side":    (None,           "V06DILKN12"),  # left only
}

# Pairs where HIGHER value = worse (pain severity, ICOAP, WOMAC difficulty items)
BILATERAL_PAIRS_HIGHER_IS_WORSE = {
    "icoap_total_symptomatic_side":  ("V06ICPTSKR",  "V06ICPTSKL"),
    "pain_7day_symptomatic_side":    ("V06P7RKRCV",  "V06P7LKRCV"),
    "pain_bed_symptomatic_side":     ("V06WPRKN3",   "V06WPLKN3"),
    "global_rating_symptomatic_side": ("V06KGLRS",   None),
    "dirkn1_symptomatic_side":       ("V06DIRKN1",   "V06DILKN1"),
    "dirkn2_symptomatic_side":       ("V06DIRKN2",   "V06DILKN2"),
    "dirkn3_symptomatic_side":       ("V06DIRKN3",   "V06DILKN3"),
    "dirkn4_symptomatic_side":       ("V06DIRKN4",   "V06DILKN4"),
    "dirkn5_symptomatic_side":       ("V06DIRKN5",   "V06DILKN5"),
    "dirkn6_symptomatic_side":       ("V06DIRKN6",   "V06DILKN6"),
    "dirkn7_symptomatic_side":       ("V06DIRKN7",   "V06DILKN7"),
    "dirkn8_symptomatic_side":       ("V06DIRKN8",   "V06DILKN8"),
    "dirkn9_symptomatic_side":       ("V06DIRKN9",   "V06DILKN9"),
    "dirkn13_symptomatic_side":      ("V06DIRKN13",  "V06DILKN13"),
    "dirkn15_symptomatic_side":      ("V06DIRKN15",  "V06DILKN15"),
    "dirkn16_symptomatic_side":      ("V06DIRKN16",  "V06DILKN16"),
    "dirkn17_symptomatic_side":      ("V06DIRKN17",  "V06DILKN17"),
}

merged_dataframe_with_symptomatic_side = merged_dataframe.copy()

for output_column, (right_column, left_column) in BILATERAL_PAIRS_LOWER_IS_WORSE.items():
    merged_dataframe_with_symptomatic_side = derive_symptomatic_side_outcome(
        dataframe=merged_dataframe_with_symptomatic_side,
        output_column=output_column,
        right_column=right_column,
        left_column=left_column,
        higher_is_worse=False,
    )

for output_column, (right_column, left_column) in BILATERAL_PAIRS_HIGHER_IS_WORSE.items():
    merged_dataframe_with_symptomatic_side = derive_symptomatic_side_outcome(
        dataframe=merged_dataframe_with_symptomatic_side,
        output_column=output_column,
        right_column=right_column,
        left_column=left_column,
        higher_is_worse=True,
    )

print(
    f"Symptomatic side outcomes derived: "
    f"{len(BILATERAL_PAIRS_LOWER_IS_WORSE) + len(BILATERAL_PAIRS_HIGHER_IS_WORSE)}"
)
# Out:
# Loaded merged DataFrame: (1845, 124)
# Symptomatic side outcomes derived: 20

# %% [markdown]
# ### 1.2.1. Results for pain outcomes

# %%
pain_results = run_pipeline_for_outcome_group(
    group_name="pain",
    merged_dataframe=merged_dataframe,
    merged_dataframe_with_symptomatic_side=merged_dataframe_with_symptomatic_side,
    activity_predictor_columns=ACTIVITY_PREDICTOR_COLUMNS,
    output_path=output_path,
)
# Out:
# Running pipeline for group 'pain' (5 outcome variables)
#
# ============================================================
# Modelling outcome: koos_pain_symptomatic_side
# ============================================================
# Complete cases for 'koos_pain_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1810 (98.1 %)
#   Dropped (missing): 35
# Train/test split (stratified by KL grade):
#   Training set : 1448 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.1024
#   Full R² (covariates + activity, 10-fold CV): 0.1268
#   Incremental R² (activity block)           : 0.0243
#   Optimal LASSO alpha                       : 0.035135
#   Activity predictors selected (non-zero)   : 27 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_light_bout_total_minutes                 +5.6685
#     mean_mvpa_bout_count                          +5.0583
#     V06AALTMNT                                    -3.6780
#     mean_moderate_bout_total_minutes              -3.3476
#     V06CESD11                                     -2.7865
#     mean_moderate_bout_max_duration               +2.4613
#     mean_light_bout_count                         -2.3348
#     mean_active_bout_mean_duration                -2.2530
#     V06ADHHS8                                     +1.9883
#     mean_vigorous_bout_count                      +0.8380
#     mean_vigorous_bout_mean_duration              -0.8004
#     mean_sedentary_bout_total_minutes             +0.7578
#     mean_active_bout_max_duration                 -0.7288
#     wake_minute_sd                                -0.6554
#     mean_light_bout_max_duration                  +0.6228
#     V06AACNT                                      -0.3951
#     V06ANVDAYS                                    +0.3827
#     sleep_minute_mean                             -0.3610
#     wake_minute_mean                              -0.3598
#     sleep_minute_sd                               +0.2803
#     mean_sedentary_bout_mean_duration             +0.1916
#     V06AACSM03                                    -0.1200
#     mean_moderate_bout_mean_duration              +0.0786
#     mean_vigorous_bout_total_minutes              +0.0511
#     mean_light_bout_mean_duration                 +0.0307
#     mean_sedentary_bout_max_duration              +0.0217
#     V06ADHHSD8                                    +0.0072
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.2020
#   RMSE : 16.7192
#   MAE  : 13.0082
#   Optimal alpha    : 0.035135
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1160
#   RMSE : 17.5967
#   MAE  : 13.8806
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1663
#     V06BMI                                        0.0975
#     wake_minute_sd                                0.0577
#     V06CESD11                                     0.0512
#     mean_sedentary_bout_total_minutes             0.0469
#     sleep_minute_sd                               0.0446
#     wake_minute_mean                              0.0420
#     V06AGE                                        0.0370
#     mean_sedentary_bout_mean_duration             0.0277
#     sleep_minute_mean                             0.0264
#
# ============================================================
# Modelling outcome: icoap_total_symptomatic_side
# ============================================================
# Complete cases for 'icoap_total_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1782 (96.6 %)
#   Dropped (missing): 63
# Train/test split (stratified by KL grade):
#   Training set : 1425 patients
#   Test set     : 357 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0871
#   Full R² (covariates + activity, 10-fold CV): 0.1313
#   Incremental R² (activity block)           : 0.0441
#   Optimal LASSO alpha                       : 0.213417
#   Activity predictors selected (non-zero)   : 10 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +1.9361
#     mean_sedentary_bout_total_minutes             -1.1382
#     mean_moderate_bout_count                      -0.7077
#     V06ADHHS8                                     -0.4783
#     wake_minute_sd                                +0.4727
#     V06ANVDAYS                                    -0.4517
#     mean_moderate_bout_max_duration               -0.3539
#     wake_minute_mean                              -0.1904
#     mean_light_bout_mean_duration                 -0.1821
#     mean_vigorous_bout_count                      -0.1054
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1125
#   RMSE : 11.8653
#   MAE  : 8.5999
#   Optimal alpha    : 0.221148
#   Optimal l1 ratio : 0.90
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0819
#   RMSE : 12.0686
#   MAE  : 8.8480
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1175
#     V06BMI                                        0.0798
#     V06CESD11                                     0.0758
#     mean_sedentary_bout_total_minutes             0.0638
#     wake_minute_sd                                0.0567
#     V06AGE                                        0.0513
#     wear_duration_mean                            0.0476
#     mean_sedentary_bout_max_duration              0.0428
#     V06COMORB                                     0.0401
#     wake_minute_mean                              0.0321
#
# ============================================================
# Modelling outcome: pain_7day_symptomatic_side
# ============================================================
# Complete cases for 'pain_7day_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1804 (97.8 %)
#   Dropped (missing): 41
# Train/test split (stratified by KL grade):
#   Training set : 1443 patients
#   Test set     : 361 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0797
#   Full R² (covariates + activity, 10-fold CV): 0.1047
#   Incremental R² (activity block)           : 0.0249
#   Optimal LASSO alpha                       : 0.050477
#   Activity predictors selected (non-zero)   : 10 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.2558
#     V06CESD11                                     +0.2515
#     mean_mvpa_bout_count                          -0.1576
#     V06ADHHS8                                     -0.1223
#     wake_minute_sd                                +0.0848
#     mean_moderate_bout_max_duration               -0.0805
#     V06ANVDAYS                                    -0.0382
#     mean_vigorous_bout_max_duration               +0.0376
#     wake_minute_mean                              -0.0152
#     mean_sedentary_bout_mean_duration             -0.0126
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1446
#   RMSE : 2.6378
#   MAE  : 2.1857
#   Optimal alpha    : 0.056086
#   Optimal l1 ratio : 0.90
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0821
#   RMSE : 2.7326
#   MAE  : 2.2555
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1305
#     V06BMI                                        0.0911
#     mean_sedentary_bout_total_minutes             0.0619
#     wake_minute_sd                                0.0512
#     sleep_minute_sd                               0.0482
#     wake_minute_mean                              0.0409
#     sleep_minute_mean                             0.0360
#     V06AGE                                        0.0339
#     mean_sedentary_bout_mean_duration             0.0318
#     mean_sedentary_bout_max_duration              0.0313
#
# ============================================================
# Modelling outcome: pain_bed_symptomatic_side
# ============================================================
# Complete cases for 'pain_bed_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1810 (98.1 %)
#   Dropped (missing): 35
# Train/test split (stratified by KL grade):
#   Training set : 1448 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0252
#   Full R² (covariates + activity, 10-fold CV): 0.0536
#   Incremental R² (activity block)           : 0.0284
#   Optimal LASSO alpha                       : 0.013341
#   Activity predictors selected (non-zero)   : 10 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0947
#     mean_sedentary_bout_total_minutes             -0.0746
#     mean_moderate_bout_count                      -0.0508
#     V06ADHHSD8                                    -0.0314
#     wake_minute_sd                                +0.0130
#     V06ANVDAYS                                    -0.0122
#     sleep_minute_sd                               -0.0115
#     V06AALTMNT                                    +0.0110
#     mean_sedentary_bout_count                     +0.0084
#     mean_moderate_bout_max_duration               -0.0065
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.0991
#   RMSE : 0.8337
#   MAE  : 0.5755
#   Optimal alpha    : 0.044470
#   Optimal l1 ratio : 0.30
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0592
#   RMSE : 0.8520
#   MAE  : 0.5931
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.0847
#     mean_sedentary_bout_total_minutes             0.0746
#     V06BMI                                        0.0730
#     wake_minute_sd                                0.0573
#     wake_minute_mean                              0.0457
#     mean_light_bout_max_duration                  0.0411
#     V06CESD11                                     0.0391
#     sleep_minute_sd                               0.0390
#     mean_sedentary_bout_mean_duration             0.0368
#     wear_duration_mean                            0.0348
#
# ============================================================
# Modelling outcome: global_rating_symptomatic_side
# ============================================================
# Complete cases for 'global_rating_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1810 (98.1 %)
#   Dropped (missing): 35
# Train/test split (stratified by KL grade):
#   Training set : 1448 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0762
#   Full R² (covariates + activity, 10-fold CV): 0.1052
#   Incremental R² (activity block)           : 0.0290
#   Optimal LASSO alpha                       : 0.033314
#   Activity predictors selected (non-zero)   : 11 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.2143
#     mean_moderate_bout_count                      -0.1175
#     V06ANVDAYS                                    -0.0720
#     mean_moderate_bout_max_duration               -0.0668
#     wake_minute_sd                                +0.0540
#     mean_sedentary_bout_total_minutes             -0.0458
#     V06ADHHS8                                     -0.0438
#     mean_vigorous_bout_count                      -0.0170
#     mean_light_bout_mean_duration                 -0.0167
#     mean_mvpa_bout_mean_duration                  -0.0098
#     mean_mvpa_bout_max_duration                   -0.0024
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1515
#   RMSE : 1.8629
#   MAE  : 1.3962
#   Optimal alpha    : 0.033314
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1016
#   RMSE : 1.9168
#   MAE  : 1.4394
#
#   Top 10 feature importances:
#     V06BMI                                        0.0776
#     kl_grade_index_knee                           0.0694
#     V06COMORB                                     0.0576
#     wake_minute_sd                                0.0486
#     V06CESD11                                     0.0451
#     wake_minute_mean                              0.0386
#     mean_sedentary_bout_total_minutes             0.0376
#     wear_duration_mean                            0.0371
#     mean_sedentary_bout_max_duration              0.0365
#     mean_moderate_bout_mean_duration              0.0355
#
# Group 'pain' complete — 5 outcomes modelled. Results saved to: modelling_results_pain.csv

# %% [markdown]
# ### 1.2.2. Results for function outcomes

# %%
function_results = run_pipeline_for_outcome_group(
    group_name="function",
    merged_dataframe=merged_dataframe,
    merged_dataframe_with_symptomatic_side=merged_dataframe_with_symptomatic_side, activity_predictor_columns=ACTIVITY_PREDICTOR_COLUMNS,
    output_path=output_path,
)
# Out:
# Running pipeline for group 'function' (4 outcome variables)
#
# ============================================================
# Modelling outcome: V0620MPACE
# ============================================================
# Complete cases for 'V0620MPACE':
#   Total patients  : 1845
#   Complete cases  : 1767 (95.8 %)
#   Dropped (missing): 78
# Train/test split (stratified by KL grade):
#   Training set : 1413 patients
#   Test set     : 354 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.1910
#   Full R² (covariates + activity, 10-fold CV): 0.2520
#   Incremental R² (activity block)           : 0.0609
#   Optimal LASSO alpha                       : 0.005160
#   Activity predictors selected (non-zero)   : 8 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_moderate_bout_count                      +0.0288
#     mean_mvpa_bout_max_duration                   +0.0184
#     mean_moderate_bout_max_duration               +0.0100
#     V06ANVDAYS                                    +0.0098
#     V06CESD11                                     -0.0054
#     mean_vigorous_bout_count                      +0.0028
#     mean_sedentary_bout_total_minutes             +0.0024
#     mean_sedentary_bout_mean_duration             +0.0001
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.3139
#   RMSE : 0.1722
#   MAE  : 0.1342
#   Optimal alpha    : 0.017202
#   Optimal l1 ratio : 0.30
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.3383
#   RMSE : 0.1691
#   MAE  : 0.1341
#
#   Top 10 feature importances:
#     mean_moderate_bout_count                      0.1362
#     mean_mvpa_bout_total_minutes                  0.0927
#     V06BMI                                        0.0595
#     mean_mvpa_bout_max_duration                   0.0524
#     V06AACNT                                      0.0464
#     weekly_guideline_gap_minutes                  0.0453
#     V06AGE                                        0.0444
#     mean_mvpa_bout_mean_duration                  0.0309
#     mean_mvpa_bout_count                          0.0253
#     mean_moderate_bout_total_minutes              0.0252
#
# ============================================================
# Modelling outcome: V06CSPACE
# ============================================================
# Complete cases for 'V06CSPACE':
#   Total patients  : 1845
#   Complete cases  : 1707 (92.5 %)
#   Dropped (missing): 138
# Train/test split (stratified by KL grade):
#   Training set : 1365 patients
#   Test set     : 342 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0969
#   Full R² (covariates + activity, 10-fold CV): 0.1039
#   Incremental R² (activity block)           : 0.0070
#   Optimal LASSO alpha                       : 0.003120
#   Activity predictors selected (non-zero)   : 8 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_vigorous_bout_count                      +0.0096
#     mean_moderate_bout_max_duration               +0.0092
#     V06CESD11                                     -0.0061
#     wake_minute_sd                                -0.0053
#     mean_sedentary_bout_mean_duration             +0.0036
#     wake_minute_mean                              -0.0015
#     mean_sedentary_bout_total_minutes             +0.0014
#     V06ANVDAYS                                    +0.0010
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1717
#   RMSE : 0.1323
#   MAE  : 0.1040
#   Optimal alpha    : 0.003120
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1328
#   RMSE : 0.1354
#   MAE  : 0.1059
#
#   Top 10 feature importances:
#     V06AGE                                        0.1033
#     V06BMI                                        0.1003
#     mean_mvpa_bout_mean_duration                  0.0395
#     sleep_minute_sd                               0.0383
#     wear_duration_mean                            0.0381
#     wake_minute_sd                                0.0369
#     wake_minute_mean                              0.0332
#     mean_active_bout_max_duration                 0.0331
#     mean_light_bout_mean_duration                 0.0312
#     V06AACNT                                      0.0308
#
# ============================================================
# Modelling outcome: V06STEPST1
# ============================================================
# Complete cases for 'V06STEPST1':
#   Total patients  : 1845
#   Complete cases  : 1767 (95.8 %)
#   Dropped (missing): 78
# Train/test split (stratified by KL grade):
#   Training set : 1413 patients
#   Test set     : 354 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.2130
#   Full R² (covariates + activity, 10-fold CV): 0.2970
#   Incremental R² (activity block)           : 0.0840
#   Optimal LASSO alpha                       : 0.013083
#   Activity predictors selected (non-zero)   : 24 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_moderate_bout_count                      -1.3329
#     mean_light_bout_mean_duration                 -0.7926
#     mean_active_bout_total_minutes                +0.7319
#     mean_mvpa_bout_max_duration                   -0.5331
#     mean_sedentary_bout_total_minutes             -0.4606
#     mean_active_bout_max_duration                 +0.4491
#     V06AACNT                                      -0.3880
#     mean_sedentary_bout_max_duration              +0.2302
#     mean_moderate_bout_total_minutes              +0.1634
#     mean_mvpa_bout_mean_duration                  -0.1547
#     mean_active_bout_mean_duration                +0.1174
#     mean_moderate_bout_mean_duration              -0.1138
#     V06CESD11                                     +0.1022
#     wear_duration_mean                            +0.0958
#     mean_light_bout_max_duration                  +0.0953
#     mean_sedentary_bout_mean_duration             -0.0857
#     sleep_minute_sd                               +0.0747
#     mean_vigorous_bout_mean_duration              +0.0642
#     V06AACSM03                                    +0.0618
#     V06ANVDAYS                                    -0.0552
#     wake_minute_sd                                -0.0394
#     V06AAVBMT                                     +0.0392
#     valid_days                                    +0.0196
#     mean_vigorous_bout_count                      -0.0085
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.3613
#   RMSE : 3.1634
#   MAE  : 2.3940
#   Optimal alpha    : 0.013083
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.3826
#   RMSE : 3.1102
#   MAE  : 2.3836
#
#   Top 10 feature importances:
#     mean_moderate_bout_count                      0.3005
#     mean_mvpa_bout_count                          0.0868
#     V06AGE                                        0.0538
#     V06BMI                                        0.0510
#     weekly_guideline_gap_minutes                  0.0392
#     V06AACNT                                      0.0345
#     mean_mvpa_bout_total_minutes                  0.0290
#     mean_sedentary_bout_mean_duration             0.0287
#     wake_minute_sd                                0.0260
#     mean_light_bout_mean_duration                 0.0220
#
# ============================================================
# Modelling outcome: V06400MTIM
# ============================================================
# Complete cases for 'V06400MTIM':
#   Total patients  : 1845
#   Complete cases  : 1612 (87.4 %)
#   Dropped (missing): 233
# Train/test split (stratified by KL grade):
#   Training set : 1289 patients
#   Test set     : 323 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.1529
#   Full R² (covariates + activity, 10-fold CV): 0.2139
#   Incremental R² (activity block)           : 0.0610
#   Optimal LASSO alpha                       : 1.184769
#   Activity predictors selected (non-zero)   : 8 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_moderate_bout_count                      -8.7750
#     mean_mvpa_bout_max_duration                   -5.9325
#     mean_mvpa_bout_mean_duration                  -1.8435
#     V06CESD11                                     +1.2423
#     mean_light_bout_max_duration                  -0.8271
#     V06ANVDAYS                                    -0.2792
#     mean_vigorous_bout_count                      -0.1661
#     mean_sedentary_bout_count                     +0.1476
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.2737
#   RMSE : 44.4256
#   MAE  : 32.1105
#   Optimal alpha    : 1.184769
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.2767
#   RMSE : 44.3334
#   MAE  : 32.2081
#
#   Top 10 feature importances:
#     mean_moderate_bout_count                      0.1384
#     mean_mvpa_bout_total_minutes                  0.0939
#     weekly_guideline_gap_minutes                  0.0753
#     V06BMI                                        0.0599
#     V06AACNT                                      0.0515
#     mean_mvpa_bout_count                          0.0425
#     V06AAMVMNT                                    0.0396
#     V06AGE                                        0.0381
#     wake_minute_mean                              0.0277
#     wake_minute_sd                                0.0267
#
# Group 'function' complete — 4 outcomes modelled. Results saved to: modelling_results_function.csv

# %% [markdown]
# ### 1.2.3. Results for ADL outcomes

# %%
adl_results = run_pipeline_for_outcome_group(
    group_name="adl",
    merged_dataframe=merged_dataframe,
    merged_dataframe_with_symptomatic_side=merged_dataframe_with_symptomatic_side,
    activity_predictor_columns=ACTIVITY_PREDICTOR_COLUMNS,
    output_path=output_path,
)
# Out:
# Running pipeline for group 'adl' (4 outcome variables)
#
# ============================================================
# Modelling outcome: V06LLD6B
# ============================================================
# Complete cases for 'V06LLD6B':
#   Total patients  : 1845
#   Complete cases  : 1801 (97.6 %)
#   Dropped (missing): 44
# Train/test split (stratified by KL grade):
#   Training set : 1440 patients
#   Test set     : 361 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0396
#   Full R² (covariates + activity, 10-fold CV): 0.1355
#   Incremental R² (activity block)           : 0.0959
#   Optimal LASSO alpha                       : 0.003032
#   Activity predictors selected (non-zero)   : 23 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     -0.2892
#     V06AACNT                                      +0.2691
#     mean_active_bout_total_minutes                -0.2042
#     V06AAMVBMT                                    -0.1156
#     V06AAVBMT                                     -0.0934
#     mean_mvpa_bout_max_duration                   +0.0921
#     mean_light_bout_max_duration                  +0.0698
#     V06AACSM03                                    -0.0685
#     V06ADHHS8                                     +0.0650
#     sleep_minute_mean                             -0.0628
#     mean_moderate_bout_mean_duration              +0.0599
#     mean_vigorous_bout_count                      +0.0581
#     V06AALTMNT                                    +0.0574
#     V06ANVDAYS                                    +0.0569
#     sleep_minute_sd                               -0.0474
#     mean_sedentary_bout_max_duration              -0.0458
#     mean_vigorous_bout_max_duration               +0.0433
#     mean_sedentary_bout_total_minutes             +0.0375
#     mean_sedentary_bout_mean_duration             -0.0266
#     mean_active_bout_mean_duration                -0.0247
#     wake_minute_mean                              -0.0212
#     mean_light_bout_mean_duration                 +0.0098
#     wake_minute_sd                                +0.0046
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1284
#   RMSE : 0.9991
#   MAE  : 0.8268
#   Optimal alpha    : 0.011416
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1027
#   RMSE : 1.0138
#   MAE  : 0.8400
#
#   Top 10 feature importances:
#     V06CESD11                                     0.1409
#     mean_mvpa_bout_mean_duration                  0.0614
#     V06BMI                                        0.0473
#     mean_sedentary_bout_max_duration              0.0425
#     mean_active_bout_max_duration                 0.0406
#     wake_minute_sd                                0.0377
#     sleep_minute_mean                             0.0332
#     V06AGE                                        0.0330
#     sleep_minute_sd                               0.0330
#     wake_minute_mean                              0.0327
#
# ============================================================
# Modelling outcome: V06LLD6A
# ============================================================
# Complete cases for 'V06LLD6A':
#   Total patients  : 1845
#   Complete cases  : 1807 (97.9 %)
#   Dropped (missing): 38
# Train/test split (stratified by KL grade):
#   Training set : 1445 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0425
#   Full R² (covariates + activity, 10-fold CV): 0.1387
#   Incremental R² (activity block)           : 0.0962
#   Optimal LASSO alpha                       : 0.027676
#   Activity predictors selected (non-zero)   : 12 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_max_duration                   +0.2051
#     V06CESD11                                     -0.1116
#     mean_moderate_bout_count                      +0.0871
#     mean_sedentary_bout_count                     -0.0809
#     mean_active_bout_mean_duration                +0.0655
#     mean_active_bout_max_duration                 +0.0526
#     V06ANVDAYS                                    +0.0493
#     mean_sedentary_bout_total_minutes             +0.0419
#     mean_vigorous_bout_count                      +0.0413
#     sleep_minute_sd                               -0.0203
#     valid_days                                    -0.0162
#     wake_minute_sd                                -0.0071
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1811
#   RMSE : 1.0685
#   MAE  : 0.8575
#   Optimal alpha    : 0.027676
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.2104
#   RMSE : 1.0493
#   MAE  : 0.8501
#
#   Top 10 feature importances:
#     mean_mvpa_bout_max_duration                   0.1107
#     mean_mvpa_bout_mean_duration                  0.0622
#     V06BMI                                        0.0441
#     mean_active_bout_max_duration                 0.0416
#     V06CESD11                                     0.0391
#     sleep_minute_sd                               0.0387
#     mean_mvpa_bout_total_minutes                  0.0386
#     wake_minute_sd                                0.0348
#     mean_sedentary_bout_max_duration              0.0328
#     mean_sedentary_bout_mean_duration             0.0323
#
# ============================================================
# Modelling outcome: V06LLDILST
# ============================================================
# Complete cases for 'V06LLDILST':
#   Total patients  : 1845
#   Complete cases  : 1764 (95.6 %)
#   Dropped (missing): 81
# Train/test split (stratified by KL grade):
#   Training set : 1411 patients
#   Test set     : 353 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0363
#   Full R² (covariates + activity, 10-fold CV): 0.1483
#   Incremental R² (activity block)           : 0.1120
#   Optimal LASSO alpha                       : 0.135662
#   Activity predictors selected (non-zero)   : 16 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     -4.2714
#     mean_moderate_bout_max_duration               +1.2053
#     mean_sedentary_bout_count                     -0.9891
#     valid_days                                    -0.8581
#     mean_sedentary_bout_max_duration              -0.8528
#     wake_minute_sd                                -0.7940
#     mean_light_bout_mean_duration                 +0.6824
#     mean_vigorous_bout_mean_duration              +0.4267
#     V06ADHHS8                                     +0.4166
#     V06AALTMNT                                    -0.3489
#     V06ANVDAYS                                    +0.3202
#     mean_vigorous_bout_max_duration               +0.2965
#     mean_mvpa_bout_count                          +0.1593
#     mean_sedentary_bout_mean_duration             -0.1238
#     mean_sedentary_bout_total_minutes             +0.1153
#     mean_moderate_bout_mean_duration              +0.0691
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1446
#   RMSE : 14.1314
#   MAE  : 11.9924
#   Optimal alpha    : 0.140577
#   Optimal l1 ratio : 0.90
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1211
#   RMSE : 14.3247
#   MAE  : 12.2040
#
#   Top 10 feature importances:
#     V06CESD11                                     0.1629
#     wake_minute_sd                                0.0462
#     sleep_minute_mean                             0.0393
#     V06BMI                                        0.0375
#     sleep_minute_sd                               0.0371
#     wake_minute_mean                              0.0357
#     mean_mvpa_bout_mean_duration                  0.0343
#     mean_light_bout_mean_duration                 0.0323
#     V06AACNT                                      0.0316
#     mean_active_bout_mean_duration                0.0302
#
# ============================================================
# Modelling outcome: V06LLD10B
# ============================================================
# Complete cases for 'V06LLD10B':
#   Total patients  : 1845
#   Complete cases  : 1806 (97.9 %)
#   Dropped (missing): 39
# Train/test split (stratified by KL grade):
#   Training set : 1444 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0428
#   Full R² (covariates + activity, 10-fold CV): 0.1344
#   Incremental R² (activity block)           : 0.0916
#   Optimal LASSO alpha                       : 0.009905
#   Activity predictors selected (non-zero)   : 15 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     -0.2491
#     mean_mvpa_bout_max_duration                   +0.0567
#     mean_moderate_bout_count                      +0.0560
#     V06ADHHS8                                     +0.0461
#     sleep_minute_mean                             -0.0362
#     V06ANVDAYS                                    +0.0335
#     mean_sedentary_bout_count                     -0.0320
#     mean_vigorous_bout_count                      +0.0304
#     V06AACSM03                                    -0.0260
#     mean_moderate_bout_max_duration               +0.0220
#     mean_light_bout_max_duration                  +0.0220
#     wake_minute_sd                                -0.0216
#     mean_sedentary_bout_max_duration              -0.0172
#     wear_duration_mean                            -0.0139
#     mean_vigorous_bout_max_duration               +0.0056
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1156
#   RMSE : 0.8581
#   MAE  : 0.7070
#   Optimal alpha    : 0.028717
#   Optimal l1 ratio : 0.30
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1016
#   RMSE : 0.8648
#   MAE  : 0.7167
#
#   Top 10 feature importances:
#     V06CESD11                                     0.1541
#     V06BMI                                        0.0559
#     mean_active_bout_max_duration                 0.0441
#     V06AGE                                        0.0421
#     wake_minute_sd                                0.0410
#     mean_mvpa_bout_mean_duration                  0.0388
#     sleep_minute_mean                             0.0386
#     mean_sedentary_bout_max_duration              0.0364
#     V06AAMVBMT                                    0.0333
#     mean_sedentary_bout_total_minutes             0.0314
#
# Group 'adl' complete — 4 outcomes modelled. Results saved to: modelling_results_adl.csv

# %% [markdown]
# ### 1.2.4. Results for self-reported function outcomes

# %%
self_reported_function_results = run_pipeline_for_outcome_group(
    group_name="self_reported_function",
    merged_dataframe=merged_dataframe,
    merged_dataframe_with_symptomatic_side=merged_dataframe_with_symptomatic_side,
    activity_predictor_columns=ACTIVITY_PREDICTOR_COLUMNS,
    output_path=output_path,
)
# Out:
# Running pipeline for group 'self_reported_function' (19 outcome variables)
#
# ============================================================
# Modelling outcome: dirkn1_symptomatic_side
# ============================================================
# Complete cases for 'dirkn1_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1804 (97.8 %)
#   Dropped (missing): 41
# Train/test split (stratified by KL grade):
#   Training set : 1443 patients
#   Test set     : 361 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0959
#   Full R² (covariates + activity, 10-fold CV): 0.1167
#   Incremental R² (activity block)           : 0.0208
#   Optimal LASSO alpha                       : 0.017740
#   Activity predictors selected (non-zero)   : 9 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0761
#     mean_mvpa_bout_count                          -0.0466
#     wake_minute_sd                                +0.0463
#     mean_moderate_bout_max_duration               -0.0327
#     mean_moderate_bout_mean_duration              -0.0247
#     V06ANVDAYS                                    -0.0202
#     mean_light_bout_max_duration                  -0.0050
#     sleep_minute_mean                             +0.0046
#     mean_sedentary_bout_mean_duration             -0.0011
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1726
#   RMSE : 0.8568
#   MAE  : 0.6754
#   Optimal alpha    : 0.017740
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1829
#   RMSE : 0.8514
#   MAE  : 0.6929
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1166
#     V06BMI                                        0.1017
#     wake_minute_sd                                0.0611
#     wake_minute_mean                              0.0478
#     sleep_minute_mean                             0.0397
#     V06COMORB                                     0.0392
#     sleep_minute_sd                               0.0387
#     mean_moderate_bout_mean_duration              0.0375
#     mean_sedentary_bout_total_minutes             0.0372
#     wear_duration_mean                            0.0371
#
# ============================================================
# Modelling outcome: dirkn2_symptomatic_side
# ============================================================
# Complete cases for 'dirkn2_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1803 (97.7 %)
#   Dropped (missing): 42
# Train/test split (stratified by KL grade):
#   Training set : 1442 patients
#   Test set     : 361 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0969
#   Full R² (covariates + activity, 10-fold CV): 0.1125
#   Incremental R² (activity block)           : 0.0156
#   Optimal LASSO alpha                       : 0.027911
#   Activity predictors selected (non-zero)   : 8 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0654
#     mean_mvpa_bout_max_duration                   -0.0482
#     mean_moderate_bout_count                      -0.0415
#     wake_minute_sd                                +0.0302
#     mean_moderate_bout_max_duration               -0.0191
#     mean_sedentary_bout_total_minutes             -0.0084
#     V06ANVDAYS                                    -0.0083
#     mean_mvpa_bout_mean_duration                  -0.0019
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1781
#   RMSE : 0.8566
#   MAE  : 0.7154
#   Optimal alpha    : 0.027911
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1499
#   RMSE : 0.8711
#   MAE  : 0.7318
#
#   Top 10 feature importances:
#     V06BMI                                        0.1352
#     kl_grade_index_knee                           0.0707
#     wake_minute_mean                              0.0630
#     wake_minute_sd                                0.0555
#     V06COMORB                                     0.0528
#     mean_mvpa_bout_mean_duration                  0.0383
#     mean_sedentary_bout_total_minutes             0.0381
#     mean_moderate_bout_mean_duration              0.0371
#     sleep_minute_sd                               0.0357
#     wear_duration_mean                            0.0341
#
# ============================================================
# Modelling outcome: dirkn3_symptomatic_side
# ============================================================
# Complete cases for 'dirkn3_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1810 (98.1 %)
#   Dropped (missing): 35
# Train/test split (stratified by KL grade):
#   Training set : 1448 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0931
#   Full R² (covariates + activity, 10-fold CV): 0.1314
#   Incremental R² (activity block)           : 0.0384
#   Optimal LASSO alpha                       : 0.000893
#   Activity predictors selected (non-zero)   : 29 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          -0.4616
#     mean_moderate_bout_total_minutes              +0.3236
#     V06AACNT                                      +0.2203
#     mean_vigorous_bout_total_minutes              -0.1948
#     mean_moderate_bout_max_duration               -0.1896
#     V06AAMVBMT                                    -0.1860
#     mean_active_bout_mean_duration                +0.1733
#     V06AAVBMT                                     +0.1550
#     mean_light_bout_mean_duration                 -0.1340
#     V06CESD11                                     +0.1171
#     mean_light_bout_count                         +0.1147
#     mean_sedentary_bout_total_minutes             -0.1022
#     mean_light_bout_total_minutes                 -0.0988
#     mean_sedentary_bout_max_duration              +0.0682
#     V06ADHHSD8                                    -0.0621
#     V06AACSM03                                    +0.0600
#     mean_light_bout_max_duration                  -0.0457
#     mean_moderate_bout_mean_duration              -0.0414
#     mean_sedentary_bout_mean_duration             -0.0323
#     wake_minute_sd                                +0.0310
#     V06ANVDAYS                                    -0.0288
#     mean_mvpa_bout_max_duration                   +0.0272
#     mean_vigorous_bout_mean_duration              -0.0203
#     valid_days                                    -0.0195
#     sleep_minute_mean                             +0.0164
#     mean_mvpa_bout_mean_duration                  +0.0155
#     sleep_minute_sd                               -0.0144
#     wear_duration_mean                            +0.0091
#     mean_vigorous_bout_count                      -0.0028
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1325
#   RMSE : 0.8941
#   MAE  : 0.7276
#   Optimal alpha    : 0.001190
#   Optimal l1 ratio : 0.70
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1105
#   RMSE : 0.9054
#   MAE  : 0.7475
#
#   Top 10 feature importances:
#     V06BMI                                        0.0900
#     kl_grade_index_knee                           0.0781
#     V06COMORB                                     0.0645
#     mean_mvpa_bout_mean_duration                  0.0534
#     wake_minute_sd                                0.0485
#     V06CESD11                                     0.0435
#     wake_minute_mean                              0.0394
#     sleep_minute_sd                               0.0359
#     mean_sedentary_bout_total_minutes             0.0322
#     mean_sedentary_bout_max_duration              0.0319
#
# ============================================================
# Modelling outcome: dirkn4_symptomatic_side
# ============================================================
# Complete cases for 'dirkn4_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1810 (98.1 %)
#   Dropped (missing): 35
# Train/test split (stratified by KL grade):
#   Training set : 1448 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0780
#   Full R² (covariates + activity, 10-fold CV): 0.0915
#   Incremental R² (activity block)           : 0.0135
#   Optimal LASSO alpha                       : 0.010216
#   Activity predictors selected (non-zero)   : 14 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0957
#     V06ANVDAYS                                    -0.0580
#     mean_moderate_bout_max_duration               -0.0386
#     mean_sedentary_bout_count                     +0.0281
#     wake_minute_sd                                +0.0205
#     valid_days                                    +0.0200
#     mean_sedentary_bout_total_minutes             -0.0188
#     V06ADHHS8                                     -0.0162
#     mean_moderate_bout_count                      -0.0150
#     sleep_minute_sd                               -0.0141
#     mean_mvpa_bout_count                          -0.0087
#     mean_vigorous_bout_mean_duration              +0.0071
#     V06AACSM03                                    +0.0067
#     mean_vigorous_bout_count                      -0.0060
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1869
#   RMSE : 0.6395
#   MAE  : 0.4823
#   Optimal alpha    : 0.010216
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1563
#   RMSE : 0.6514
#   MAE  : 0.4895
#
#   Top 10 feature importances:
#     V06BMI                                        0.1150
#     kl_grade_index_knee                           0.0922
#     mean_sedentary_bout_total_minutes             0.0587
#     V06CESD11                                     0.0503
#     wake_minute_mean                              0.0463
#     V06AGE                                        0.0433
#     sleep_minute_sd                               0.0416
#     wake_minute_sd                                0.0414
#     mean_mvpa_bout_mean_duration                  0.0364
#     wear_duration_mean                            0.0314
#
# ============================================================
# Modelling outcome: dirkn5_symptomatic_side
# ============================================================
# Complete cases for 'dirkn5_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1746 (94.6 %)
#   Dropped (missing): 99
# Train/test split (stratified by KL grade):
#   Training set : 1396 patients
#   Test set     : 350 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0831
#   Full R² (covariates + activity, 10-fold CV): 0.0949
#   Incremental R² (activity block)           : 0.0119
#   Optimal LASSO alpha                       : 0.010308
#   Activity predictors selected (non-zero)   : 13 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0967
#     mean_sedentary_bout_total_minutes             -0.0952
#     mean_mvpa_bout_count                          -0.0575
#     mean_moderate_bout_max_duration               -0.0541
#     wear_duration_mean                            +0.0320
#     mean_sedentary_bout_mean_duration             -0.0257
#     mean_vigorous_bout_count                      -0.0256
#     valid_days                                    +0.0164
#     V06ADHHS8                                     -0.0122
#     sleep_minute_sd                               +0.0103
#     V06ANVDAYS                                    -0.0094
#     mean_active_bout_max_duration                 -0.0082
#     wake_minute_sd                                +0.0078
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1745
#   RMSE : 0.9165
#   MAE  : 0.7525
#   Optimal alpha    : 0.010308
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1349
#   RMSE : 0.9382
#   MAE  : 0.7798
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1004
#     V06BMI                                        0.0846
#     mean_sedentary_bout_total_minutes             0.0631
#     V06AGE                                        0.0580
#     wake_minute_mean                              0.0485
#     wear_duration_mean                            0.0423
#     sleep_minute_sd                               0.0420
#     wake_minute_sd                                0.0409
#     sleep_minute_mean                             0.0350
#     mean_sedentary_bout_mean_duration             0.0306
#
# ============================================================
# Modelling outcome: dirkn6_symptomatic_side
# ============================================================
# Complete cases for 'dirkn6_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1810 (98.1 %)
#   Dropped (missing): 35
# Train/test split (stratified by KL grade):
#   Training set : 1448 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0798
#   Full R² (covariates + activity, 10-fold CV): 0.1069
#   Incremental R² (activity block)           : 0.0271
#   Optimal LASSO alpha                       : 0.008951
#   Activity predictors selected (non-zero)   : 14 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.1042
#     mean_sedentary_bout_total_minutes             -0.0447
#     mean_mvpa_bout_count                          -0.0340
#     mean_moderate_bout_max_duration               -0.0283
#     mean_sedentary_bout_count                     +0.0248
#     V06ANVDAYS                                    -0.0200
#     wake_minute_mean                              +0.0187
#     V06ADHHS8                                     -0.0096
#     V06AACSM03                                    +0.0091
#     mean_mvpa_bout_max_duration                   -0.0091
#     mean_light_bout_mean_duration                 -0.0089
#     mean_vigorous_bout_count                      -0.0079
#     wake_minute_sd                                +0.0048
#     valid_days                                    +0.0024
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1585
#   RMSE : 0.6180
#   MAE  : 0.4698
#   Optimal alpha    : 0.077853
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1284
#   RMSE : 0.6290
#   MAE  : 0.4808
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1313
#     V06CESD11                                     0.0776
#     V06BMI                                        0.0684
#     wake_minute_mean                              0.0513
#     mean_sedentary_bout_total_minutes             0.0423
#     V06AGE                                        0.0421
#     wake_minute_sd                                0.0396
#     wear_duration_mean                            0.0382
#     sleep_minute_sd                               0.0369
#     mean_sedentary_bout_max_duration              0.0313
#
# ============================================================
# Modelling outcome: dirkn7_symptomatic_side
# ============================================================
# Complete cases for 'dirkn7_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1809 (98.0 %)
#   Dropped (missing): 36
# Train/test split (stratified by KL grade):
#   Training set : 1447 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0705
#   Full R² (covariates + activity, 10-fold CV): 0.0942
#   Incremental R² (activity block)           : 0.0237
#   Optimal LASSO alpha                       : 0.020645
#   Activity predictors selected (non-zero)   : 9 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0607
#     mean_moderate_bout_count                      -0.0461
#     wake_minute_sd                                +0.0438
#     mean_moderate_bout_max_duration               -0.0376
#     V06ANVDAYS                                    -0.0325
#     mean_sedentary_bout_total_minutes             -0.0276
#     V06ADHHS8                                     -0.0220
#     mean_light_bout_max_duration                  -0.0020
#     mean_sedentary_bout_mean_duration             -0.0011
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1318
#   RMSE : 0.7971
#   MAE  : 0.6608
#   Optimal alpha    : 0.022939
#   Optimal l1 ratio : 0.90
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0822
#   RMSE : 0.8195
#   MAE  : 0.6831
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.0943
#     V06BMI                                        0.0729
#     wake_minute_sd                                0.0613
#     mean_mvpa_bout_mean_duration                  0.0611
#     wake_minute_mean                              0.0564
#     mean_sedentary_bout_total_minutes             0.0432
#     sleep_minute_mean                             0.0394
#     sleep_minute_sd                               0.0385
#     mean_sedentary_bout_mean_duration             0.0384
#     mean_sedentary_bout_max_duration              0.0352
#
# ============================================================
# Modelling outcome: dirkn8_symptomatic_side
# ============================================================
# Complete cases for 'dirkn8_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1802 (97.7 %)
#   Dropped (missing): 43
# Train/test split (stratified by KL grade):
#   Training set : 1441 patients
#   Test set     : 361 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0765
#   Full R² (covariates + activity, 10-fold CV): 0.1075
#   Incremental R² (activity block)           : 0.0310
#   Optimal LASSO alpha                       : 0.013207
#   Activity predictors selected (non-zero)   : 9 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0775
#     mean_mvpa_bout_count                          -0.0395
#     mean_sedentary_bout_total_minutes             -0.0356
#     mean_moderate_bout_max_duration               -0.0352
#     wake_minute_sd                                +0.0258
#     V06AAMDMNT                                    -0.0156
#     V06ADHHSD8                                    -0.0109
#     valid_days                                    +0.0106
#     V06ANVDAYS                                    -0.0053
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1619
#   RMSE : 0.7462
#   MAE  : 0.5389
#   Optimal alpha    : 0.018867
#   Optimal l1 ratio : 0.70
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1373
#   RMSE : 0.7571
#   MAE  : 0.5510
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1264
#     V06BMI                                        0.0700
#     mean_sedentary_bout_total_minutes             0.0576
#     mean_mvpa_bout_mean_duration                  0.0523
#     mean_moderate_bout_mean_duration              0.0512
#     V06COMORB                                     0.0511
#     wake_minute_sd                                0.0491
#     wake_minute_mean                              0.0411
#     V06CESD11                                     0.0401
#     V06AGE                                        0.0340
#
# ============================================================
# Modelling outcome: dirkn9_symptomatic_side
# ============================================================
# Complete cases for 'dirkn9_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1809 (98.0 %)
#   Dropped (missing): 36
# Train/test split (stratified by KL grade):
#   Training set : 1447 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0541
#   Full R² (covariates + activity, 10-fold CV): 0.0773
#   Incremental R² (activity block)           : 0.0232
#   Optimal LASSO alpha                       : 0.014925
#   Activity predictors selected (non-zero)   : 10 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0454
#     mean_moderate_bout_max_duration               -0.0385
#     mean_sedentary_bout_total_minutes             -0.0328
#     wake_minute_sd                                +0.0321
#     mean_moderate_bout_count                      -0.0312
#     V06ADHHSD8                                    -0.0238
#     wear_duration_mean                            -0.0135
#     V06AACNT                                      -0.0070
#     V06ANVDAYS                                    -0.0030
#     mean_sedentary_bout_mean_duration             -0.0026
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1188
#   RMSE : 0.7147
#   MAE  : 0.5144
#   Optimal alpha    : 0.021321
#   Optimal l1 ratio : 0.70
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0943
#   RMSE : 0.7246
#   MAE  : 0.5190
#
#   Top 10 feature importances:
#     V06BMI                                        0.0685
#     kl_grade_index_knee                           0.0660
#     wake_minute_mean                              0.0540
#     wake_minute_sd                                0.0505
#     mean_sedentary_bout_total_minutes             0.0497
#     wear_duration_mean                            0.0414
#     V06COMORB                                     0.0393
#     sleep_minute_mean                             0.0374
#     mean_sedentary_bout_max_duration              0.0371
#     sleep_minute_sd                               0.0360
#
# ============================================================
# Modelling outcome: dirkn13_symptomatic_side
# ============================================================
# Complete cases for 'dirkn13_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1493 (80.9 %)
#   Dropped (missing): 352
# Train/test split (stratified by KL grade):
#   Training set : 1194 patients
#   Test set     : 299 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0564
#   Full R² (covariates + activity, 10-fold CV): 0.0860
#   Incremental R² (activity block)           : 0.0295
#   Optimal LASSO alpha                       : 0.015614
#   Activity predictors selected (non-zero)   : 12 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06ANVDAYS                                    -0.0642
#     V06CESD11                                     +0.0439
#     mean_sedentary_bout_total_minutes             -0.0387
#     V06AAMDMNT                                    -0.0356
#     wake_minute_sd                                +0.0324
#     mean_mvpa_bout_count                          -0.0283
#     mean_sedentary_bout_count                     +0.0220
#     mean_sedentary_bout_mean_duration             -0.0184
#     V06ADHHS8                                     -0.0141
#     mean_moderate_bout_max_duration               -0.0102
#     mean_active_bout_max_duration                 -0.0057
#     mean_sedentary_bout_max_duration              -0.0042
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.0970
#   RMSE : 0.7181
#   MAE  : 0.5204
#   Optimal alpha    : 0.048538
#   Optimal l1 ratio : 0.30
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1305
#   RMSE : 0.7047
#   MAE  : 0.5141
#
#   Top 10 feature importances:
#     V06BMI                                        0.0965
#     wake_minute_mean                              0.0662
#     wake_minute_sd                                0.0646
#     sleep_minute_sd                               0.0581
#     kl_grade_index_knee                           0.0512
#     mean_sedentary_bout_total_minutes             0.0505
#     V06COMORB                                     0.0457
#     wear_duration_mean                            0.0450
#     mean_sedentary_bout_max_duration              0.0427
#     mean_sedentary_bout_mean_duration             0.0394
#
# ============================================================
# Modelling outcome: dirkn15_symptomatic_side
# ============================================================
# Complete cases for 'dirkn15_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1809 (98.0 %)
#   Dropped (missing): 36
# Train/test split (stratified by KL grade):
#   Training set : 1447 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0573
#   Full R² (covariates + activity, 10-fold CV): 0.0579
#   Incremental R² (activity block)           : 0.0006
#   Optimal LASSO alpha                       : 0.012505
#   Activity predictors selected (non-zero)   : 13 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.0444
#     V06CESD11                                     +0.0440
#     wake_minute_sd                                +0.0397
#     V06ADHHSD8                                    -0.0394
#     mean_mvpa_bout_count                          -0.0261
#     mean_moderate_bout_max_duration               -0.0234
#     mean_light_bout_max_duration                  -0.0191
#     mean_vigorous_bout_mean_duration              +0.0094
#     V06ANVDAYS                                    -0.0081
#     mean_sedentary_bout_count                     +0.0073
#     mean_sedentary_bout_mean_duration             -0.0046
#     V06ADHHS8                                     -0.0038
#     mean_moderate_bout_mean_duration              -0.0023
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1499
#   RMSE : 0.6875
#   MAE  : 0.5365
#   Optimal alpha    : 0.094598
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1208
#   RMSE : 0.6992
#   MAE  : 0.5516
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.0843
#     V06BMI                                        0.0726
#     wake_minute_sd                                0.0518
#     V06COMORB                                     0.0477
#     sleep_minute_sd                               0.0468
#     mean_sedentary_bout_mean_duration             0.0446
#     mean_sedentary_bout_total_minutes             0.0439
#     sleep_minute_mean                             0.0371
#     wear_duration_mean                            0.0370
#     wake_minute_mean                              0.0365
#
# ============================================================
# Modelling outcome: dirkn16_symptomatic_side
# ============================================================
# Complete cases for 'dirkn16_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1706 (92.5 %)
#   Dropped (missing): 139
# Train/test split (stratified by KL grade):
#   Training set : 1364 patients
#   Test set     : 342 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0811
#   Full R² (covariates + activity, 10-fold CV): 0.1006
#   Incremental R² (activity block)           : 0.0195
#   Optimal LASSO alpha                       : 0.017236
#   Activity predictors selected (non-zero)   : 12 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0870
#     valid_days                                    +0.0360
#     wake_minute_sd                                +0.0333
#     mean_mvpa_bout_max_duration                   -0.0255
#     mean_mvpa_bout_mean_duration                  -0.0227
#     wake_minute_mean                              +0.0197
#     V06AALTMNT                                    +0.0119
#     mean_mvpa_bout_count                          -0.0110
#     mean_light_bout_mean_duration                 +0.0079
#     mean_sedentary_bout_total_minutes             -0.0043
#     mean_moderate_bout_mean_duration              -0.0016
#     V06ANVDAYS                                    -0.0002
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1106
#   RMSE : 0.8164
#   MAE  : 0.6523
#   Optimal alpha    : 0.017236
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0707
#   RMSE : 0.8346
#   MAE  : 0.6708
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1083
#     wake_minute_mean                              0.0757
#     V06BMI                                        0.0677
#     wake_minute_sd                                0.0615
#     V06COMORB                                     0.0446
#     wear_duration_mean                            0.0417
#     V06AGE                                        0.0366
#     sleep_minute_mean                             0.0363
#     mean_sedentary_bout_total_minutes             0.0362
#     sleep_minute_sd                               0.0356
#
# ============================================================
# Modelling outcome: dirkn17_symptomatic_side
# ============================================================
# Complete cases for 'dirkn17_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1807 (97.9 %)
#   Dropped (missing): 38
# Train/test split (stratified by KL grade):
#   Training set : 1445 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0550
#   Full R² (covariates + activity, 10-fold CV): 0.0764
#   Incremental R² (activity block)           : 0.0214
#   Optimal LASSO alpha                       : 0.012499
#   Activity predictors selected (non-zero)   : 9 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0531
#     wake_minute_sd                                +0.0397
#     mean_sedentary_bout_total_minutes             -0.0246
#     mean_mvpa_bout_count                          -0.0228
#     V06ADHHS8                                     -0.0165
#     mean_moderate_bout_max_duration               -0.0165
#     mean_mvpa_bout_mean_duration                  -0.0147
#     V06ANVDAYS                                    -0.0110
#     mean_light_bout_mean_duration                 +0.0006
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1618
#   RMSE : 0.6033
#   MAE  : 0.4407
#   Optimal alpha    : 0.041663
#   Optimal l1 ratio : 0.30
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1173
#   RMSE : 0.6191
#   MAE  : 0.4526
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.0871
#     V06BMI                                        0.0797
#     wake_minute_sd                                0.0679
#     mean_sedentary_bout_total_minutes             0.0539
#     V06COMORB                                     0.0529
#     wake_minute_mean                              0.0438
#     sleep_minute_sd                               0.0438
#     mean_mvpa_bout_mean_duration                  0.0381
#     sleep_minute_mean                             0.0375
#     wear_duration_mean                            0.0372
#
# ============================================================
# Modelling outcome: dilkn10_symptomatic_side
# ============================================================
# Complete cases for 'dilkn10_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1809 (98.0 %)
#   Dropped (missing): 36
# Train/test split (stratified by KL grade):
#   Training set : 1447 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0366
#   Full R² (covariates + activity, 10-fold CV): 0.0622
#   Incremental R² (activity block)           : 0.0256
#   Optimal LASSO alpha                       : 0.016385
#   Activity predictors selected (non-zero)   : 6 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0672
#     mean_sedentary_bout_total_minutes             -0.0459
#     wake_minute_sd                                +0.0274
#     mean_mvpa_bout_count                          -0.0267
#     V06ADHHS8                                     -0.0199
#     mean_moderate_bout_mean_duration              -0.0114
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.0601
#   RMSE : 0.6476
#   MAE  : 0.4615
#   Optimal alpha    : 0.016385
#   Optimal l1 ratio : 1.00
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0338
#   RMSE : 0.6566
#   MAE  : 0.4760
#
#   Top 10 feature importances:
#     V06BMI                                        0.1135
#     mean_sedentary_bout_total_minutes             0.0747
#     wake_minute_sd                                0.0533
#     wake_minute_mean                              0.0528
#     sleep_minute_sd                               0.0453
#     wear_duration_mean                            0.0428
#     mean_sedentary_bout_max_duration              0.0418
#     kl_grade_index_knee                           0.0403
#     V06CESD11                                     0.0370
#     V06AGE                                        0.0369
#
# ============================================================
# Modelling outcome: dilkn12_symptomatic_side
# ============================================================
# Complete cases for 'dilkn12_symptomatic_side':
#   Total patients  : 1845
#   Complete cases  : 1809 (98.0 %)
#   Dropped (missing): 36
# Train/test split (stratified by KL grade):
#   Training set : 1447 patients
#   Test set     : 362 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0252
#   Full R² (covariates + activity, 10-fold CV): 0.0532
#   Incremental R² (activity block)           : 0.0281
#   Optimal LASSO alpha                       : 0.008896
#   Activity predictors selected (non-zero)   : 12 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0723
#     mean_sedentary_bout_total_minutes             -0.0517
#     mean_moderate_bout_count                      -0.0269
#     mean_sedentary_bout_count                     +0.0243
#     wake_minute_sd                                +0.0235
#     V06ADHHS8                                     -0.0198
#     sleep_minute_sd                               -0.0185
#     V06ANVDAYS                                    -0.0150
#     mean_mvpa_bout_mean_duration                  -0.0084
#     mean_light_bout_mean_duration                 -0.0072
#     mean_light_bout_max_duration                  -0.0059
#     wake_minute_mean                              -0.0052
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.0543
#   RMSE : 0.6290
#   MAE  : 0.3861
#   Optimal alpha    : 0.082963
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0334
#   RMSE : 0.6360
#   MAE  : 0.3909
#
#   Top 10 feature importances:
#     V06BMI                                        0.0819
#     mean_sedentary_bout_mean_duration             0.0748
#     mean_sedentary_bout_total_minutes             0.0700
#     wake_minute_sd                                0.0698
#     sleep_minute_mean                             0.0464
#     V06CESD11                                     0.0439
#     kl_grade_index_knee                           0.0436
#     wake_minute_mean                              0.0389
#     V06AGE                                        0.0375
#     mean_sedentary_bout_max_duration              0.0356
#
# ============================================================
# Modelling outcome: V06KOOSFX1
# ============================================================
# Complete cases for 'V06KOOSFX1':
#   Total patients  : 1845
#   Complete cases  : 1493 (80.9 %)
#   Dropped (missing): 352
# Train/test split (stratified by KL grade):
#   Training set : 1194 patients
#   Test set     : 299 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0758
#   Full R² (covariates + activity, 10-fold CV): 0.1027
#   Incremental R² (activity block)           : 0.0269
#   Optimal LASSO alpha                       : 0.018083
#   Activity predictors selected (non-zero)   : 15 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.1319
#     mean_sedentary_bout_total_minutes             -0.0586
#     valid_days                                    +0.0486
#     V06ADHHS8                                     -0.0374
#     mean_sedentary_bout_mean_duration             -0.0373
#     mean_vigorous_bout_count                      -0.0354
#     wake_minute_sd                                +0.0313
#     mean_moderate_bout_count                      -0.0301
#     mean_moderate_bout_max_duration               -0.0262
#     mean_moderate_bout_total_minutes              -0.0243
#     V06AALTMNT                                    +0.0188
#     sleep_minute_mean                             +0.0172
#     wear_duration_mean                            +0.0148
#     mean_vigorous_bout_mean_duration              +0.0123
#     sleep_minute_sd                               -0.0046
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.0947
#   RMSE : 0.9854
#   MAE  : 0.8196
#   Optimal alpha    : 0.127574
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0658
#   RMSE : 1.0010
#   MAE  : 0.8442
#
#   Top 10 feature importances:
#     V06BMI                                        0.1099
#     kl_grade_index_knee                           0.0714
#     V06AGE                                        0.0502
#     wake_minute_sd                                0.0485
#     mean_sedentary_bout_total_minutes             0.0479
#     wear_duration_mean                            0.0431
#     wake_minute_mean                              0.0365
#     mean_sedentary_bout_mean_duration             0.0347
#     sleep_minute_sd                               0.0343
#     sleep_minute_mean                             0.0315
#
# ============================================================
# Modelling outcome: V06KOOSFX2
# ============================================================
# Complete cases for 'V06KOOSFX2':
#   Total patients  : 1845
#   Complete cases  : 849 (46.0 %)
#   Dropped (missing): 996
# Train/test split (stratified by KL grade):
#   Training set : 679 patients
#   Test set     : 170 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.1278
#   Full R² (covariates + activity, 10-fold CV): 0.1296
#   Incremental R² (activity block)           : 0.0018
#   Optimal LASSO alpha                       : 0.048383
#   Activity predictors selected (non-zero)   : 4 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0853
#     V06AAMVMNT                                    -0.0253
#     sleep_minute_mean                             -0.0095
#     mean_active_bout_max_duration                 -0.0046
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1447
#   RMSE : 1.0114
#   MAE  : 0.7827
#   Optimal alpha    : 0.158432
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1420
#   RMSE : 1.0131
#   MAE  : 0.7944
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.2324
#     sleep_minute_mean                             0.0728
#     V06BMI                                        0.0658
#     V06AGE                                        0.0551
#     sleep_minute_sd                               0.0431
#     mean_sedentary_bout_mean_duration             0.0395
#     V06CESD11                                     0.0337
#     mean_sedentary_bout_max_duration              0.0316
#     mean_light_bout_mean_duration                 0.0268
#     wear_duration_mean                            0.0267
#
# ============================================================
# Modelling outcome: V06KOOSFX4
# ============================================================
# Complete cases for 'V06KOOSFX4':
#   Total patients  : 1845
#   Complete cases  : 1489 (80.7 %)
#   Dropped (missing): 356
# Train/test split (stratified by KL grade):
#   Training set : 1191 patients
#   Test set     : 298 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0702
#   Full R² (covariates + activity, 10-fold CV): 0.0790
#   Incremental R² (activity block)           : 0.0088
#   Optimal LASSO alpha                       : 0.010541
#   Activity predictors selected (non-zero)   : 17 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.0848
#     mean_moderate_bout_max_duration               -0.0751
#     wake_minute_sd                                +0.0377
#     mean_moderate_bout_count                      -0.0376
#     V06ADHHSD8                                    -0.0375
#     mean_active_bout_mean_duration                +0.0370
#     mean_vigorous_bout_count                      -0.0314
#     sleep_minute_sd                               +0.0305
#     mean_vigorous_bout_mean_duration              +0.0298
#     wake_minute_mean                              +0.0279
#     mean_mvpa_bout_mean_duration                  +0.0268
#     mean_sedentary_bout_mean_duration             -0.0258
#     mean_active_bout_count                        -0.0231
#     V06AAVBMT                                     +0.0202
#     V06ANVDAYS                                    -0.0178
#     mean_sedentary_bout_max_duration              +0.0154
#     V06AALTMNT                                    +0.0052
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1476
#   RMSE : 0.9549
#   MAE  : 0.7418
#   Optimal alpha    : 0.079741
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.1180
#   RMSE : 0.9713
#   MAE  : 0.7749
#
#   Top 10 feature importances:
#     kl_grade_index_knee                           0.1528
#     V06AGE                                        0.0635
#     V06BMI                                        0.0572
#     wake_minute_mean                              0.0540
#     sleep_minute_sd                               0.0510
#     mean_sedentary_bout_total_minutes             0.0455
#     wake_minute_sd                                0.0412
#     sleep_minute_mean                             0.0371
#     mean_sedentary_bout_mean_duration             0.0362
#     mean_sedentary_bout_max_duration              0.0332
#
# ============================================================
# Modelling outcome: V06KOOSFX5
# ============================================================
# Complete cases for 'V06KOOSFX5':
#   Total patients  : 1845
#   Complete cases  : 1577 (85.5 %)
#   Dropped (missing): 268
# Train/test split (stratified by KL grade):
#   Training set : 1261 patients
#   Test set     : 316 patients
#
# --- Stage 1: Explanatory LASSO model ---
#   Baseline R² (covariates only, 10-fold CV) : 0.0601
#   Full R² (covariates + activity, 10-fold CV): 0.0784
#   Incremental R² (activity block)           : 0.0183
#   Optimal LASSO alpha                       : 0.024371
#   Activity predictors selected (non-zero)   : 10 / 43
#
#   Non-zero LASSO coefficients (ranked by absolute magnitude):
#     V06CESD11                                     +0.1189
#     mean_sedentary_bout_total_minutes             -0.0466
#     mean_moderate_bout_count                      -0.0452
#     V06ADHHS8                                     -0.0429
#     mean_sedentary_bout_mean_duration             -0.0392
#     valid_days                                    +0.0258
#     mean_moderate_bout_max_duration               -0.0184
#     V06ANVDAYS                                    -0.0080
#     mean_light_bout_mean_duration                 +0.0049
#     sleep_minute_sd                               -0.0002
#
# --- Stage 2a: Elastic Net (held-out test set) ---
#   R²   : 0.1119
#   RMSE : 0.9826
#   MAE  : 0.8384
#   Optimal alpha    : 0.139461
#   Optimal l1 ratio : 0.10
#
# --- Stage 2b: Random Forest (held-out test set) ---
#   R²   : 0.0785
#   RMSE : 1.0009
#   MAE  : 0.8484
#
#   Top 10 feature importances:
#     V06BMI                                        0.1087
#     mean_sedentary_bout_total_minutes             0.0564
#     kl_grade_index_knee                           0.0548
#     mean_sedentary_bout_mean_duration             0.0484
#     mean_sedentary_bout_max_duration              0.0481
#     V06AGE                                        0.0422
#     wake_minute_mean                              0.0404
#     wear_duration_mean                            0.0390
#     sleep_minute_sd                               0.0382
#     wake_minute_sd                                0.0380
#
# Group 'self_reported_function' complete — 19 outcomes modelled. Results saved to: modelling_results_self_reported_function.csv

# %% [markdown]
# ### 1.2.5. Summary table across all outcome groups

# %%
def build_combined_summary_table(
        *,
        group_result_frames: dict[str, pd.DataFrame],
        sort_by_column: str = "stage_1_incremental_r2",
) -> pd.DataFrame:
    """
    Concatenate the per-group result frames into a single summary table,
    tagging each row with the outcome group it belongs to.

    Each input frame is the return value of
    ``run_pipeline_for_outcome_group`` and already contains one row per
    outcome variable with all Stage 1 and Stage 2 metrics. This function
    prepends an ``outcome_group`` column, stacks the frames, and sorts the
    result so the strongest activity signal appears first.

    :param group_result_frames: Mapping of outcome group name to the
        result frame returned for that group.
    :param sort_by_column: Column to sort the combined table by, in
        descending order. Defaults to the Stage 1 incremental R², which
        quantifies the unique variance explained by the activity block.
    :returns: Combined DataFrame with one row per outcome variable across
        all groups, sorted by ``sort_by_column`` descending.
    """
    labelled_frames = []

    for group_name, result_frame in group_result_frames.items():
        labelled_frame = result_frame.copy()
        labelled_frame.insert(loc=0, column="outcome_group", value=group_name)
        labelled_frames.append(labelled_frame)

    combined_table = pd.concat(labelled_frames, ignore_index=True)

    combined_table = combined_table.sort_values(
        by=sort_by_column,
        ascending=False,
    ).reset_index(drop=True)

    return combined_table


combined_summary_table = build_combined_summary_table(
    group_result_frames={
        "pain": pain_results,
        "function": function_results,
        "adl": adl_results,
        "self_reported_function": self_reported_function_results,
    },
    sort_by_column="stage_1_incremental_r2",
)

combined_summary_table.to_csv(
    output_path / "modelling_results_combined.csv",
    index=False,
)

print(
    f"Combined summary table: {len(combined_summary_table)} outcomes "
    f"across {combined_summary_table['outcome_group'].nunique()} groups"
)
print(combined_summary_table.to_string(index=False))
# Out:
# Combined summary table: 32 outcomes across 4 groups
#          outcome_group               outcome_variable  stage_1_baseline_r2_cv  stage_1_full_r2_cv  stage_1_incremental_r2  stage_1_selected_predictor_count  stage_2_elastic_net_r2_test  stage_2_elastic_net_rmse_test  stage_2_elastic_net_mae_test  stage_2_random_forest_r2_test  stage_2_random_forest_rmse_test  stage_2_random_forest_mae_test
#                    adl                     V06LLDILST                0.036322            0.148350                0.112028                                16                     0.144614                      14.131429                     11.992375                       0.121052                        14.324733                       12.204049
#                    adl                       V06LLD6A                0.042488            0.138653                0.096165                                12                     0.181084                       1.068538                      0.857534                       0.210367                         1.049259                        0.850138
#                    adl                       V06LLD6B                0.039593            0.135538                0.095945                                23                     0.128379                       0.999138                      0.826757                       0.102676                         1.013762                        0.839984
#                    adl                      V06LLD10B                0.042815            0.134384                0.091569                                15                     0.115561                       0.858052                      0.706966                       0.101621                         0.864788                        0.716670
#               function                     V06STEPST1                0.213020            0.297027                0.084007                                24                     0.361305                       3.163440                      2.394029                       0.382616                         3.110214                        2.383639
#               function                     V06400MTIM                0.152879            0.213853                0.060974                                 8                     0.273718                      44.425619                     32.110549                       0.276732                        44.333358                       32.208095
#               function                     V0620MPACE                0.191013            0.251956                0.060943                                 8                     0.313880                       0.172196                      0.134219                       0.338268                         0.169108                        0.134076
#                   pain   icoap_total_symptomatic_side                0.087136            0.131251                0.044115                                10                     0.112546                      11.865265                      8.599893                       0.081862                        12.068646                        8.847991
# self_reported_function        dirkn3_symptomatic_side                0.093081            0.131439                0.038358                                29                     0.132458                       0.894096                      0.727575                       0.110462                         0.905359                        0.747537
# self_reported_function        dirkn8_symptomatic_side                0.076524            0.107529                0.031004                                 9                     0.161919                       0.746190                      0.538859                       0.137340                         0.757053                        0.550980
# self_reported_function       dirkn13_symptomatic_side                0.056414            0.085953                0.029539                                12                     0.097035                       0.718133                      0.520384                       0.130511                         0.704695                        0.514115
#                   pain global_rating_symptomatic_side                0.076230            0.105205                0.028975                                11                     0.151470                       1.862873                      1.396180                       0.101590                         1.916844                        1.439371
#                   pain      pain_bed_symptomatic_side                0.025185            0.053617                0.028432                                10                     0.099069                       0.833706                      0.575462                       0.059205                         0.851951                        0.593144
# self_reported_function       dilkn12_symptomatic_side                0.025167            0.053232                0.028065                                12                     0.054311                       0.629046                      0.386114                       0.033422                         0.635956                        0.390850
# self_reported_function        dirkn6_symptomatic_side                0.079832            0.106884                0.027052                                14                     0.158500                       0.618001                      0.469783                       0.128407                         0.628954                        0.480753
# self_reported_function                     V06KOOSFX1                0.075832            0.102724                0.026893                                15                     0.094743                       0.985416                      0.819604                       0.065793                         1.001049                        0.844194
# self_reported_function       dilkn10_symptomatic_side                0.036635            0.062219                0.025584                                 6                     0.060095                       0.647623                      0.461509                       0.033765                         0.656631                        0.476002
#                   pain     pain_7day_symptomatic_side                0.079746            0.104685                0.024939                                10                     0.144637                       2.637798                      2.185721                       0.082080                         2.732552                        2.255512
#                   pain     koos_pain_symptomatic_side                0.102437            0.126783                0.024346                                27                     0.202006                      16.719247                     13.008202                       0.116048                        17.596697                       13.880580
# self_reported_function        dirkn7_symptomatic_side                0.070461            0.094173                0.023712                                 9                     0.131762                       0.797097                      0.660820                       0.082167                         0.819546                        0.683064
# self_reported_function        dirkn9_symptomatic_side                0.054109            0.077306                0.023198                                10                     0.118817                       0.714726                      0.514391                       0.094278                         0.724610                        0.518979
# self_reported_function       dirkn17_symptomatic_side                0.055023            0.076445                0.021422                                 9                     0.161794                       0.603291                      0.440730                       0.117339                         0.619082                        0.452574
# self_reported_function        dirkn1_symptomatic_side                0.095922            0.116721                0.020799                                 9                     0.172609                       0.856800                      0.675435                       0.182942                         0.851433                        0.692893
# self_reported_function       dirkn16_symptomatic_side                0.081095            0.100615                0.019520                                12                     0.110641                       0.816442                      0.652326                       0.070700                         0.834574                        0.670843
# self_reported_function                     V06KOOSFX5                0.060128            0.078410                0.018282                                10                     0.111924                       0.982591                      0.838399                       0.078494                         1.000914                        0.848380
# self_reported_function        dirkn2_symptomatic_side                0.096918            0.112476                0.015558                                 8                     0.178146                       0.856554                      0.715423                       0.149936                         0.871130                        0.731758
# self_reported_function        dirkn4_symptomatic_side                0.077970            0.091454                0.013484                                14                     0.186921                       0.639504                      0.482317                       0.156322                         0.651426                        0.489517
# self_reported_function        dirkn5_symptomatic_side                0.083076            0.094938                0.011862                                13                     0.174461                       0.916497                      0.752510                       0.134923                         0.938188                        0.779816
# self_reported_function                     V06KOOSFX4                0.070153            0.078989                0.008836                                17                     0.147603                       0.954864                      0.741799                       0.117977                         0.971315                        0.774914
#               function                      V06CSPACE                0.096877            0.103872                0.006995                                 8                     0.171707                       0.132318                      0.104023                       0.132800                         0.135390                        0.105919
# self_reported_function                     V06KOOSFX2                0.127838            0.129647                0.001809                                 4                     0.144750                       1.011442                      0.782721                       0.141979                         1.013079                        0.794426
# self_reported_function       dirkn15_symptomatic_side                0.057340            0.057939                0.000599                                13                     0.149948                       0.687497                      0.536536                       0.120821                         0.699176                        0.551603

# %% [markdown]
# # 2. Predictive models with harmonic features and IV

# %% [markdown]
# ## 2.1. Prepare modeling dataframe
# Derives the columns required by the modeling pipeline from the summary_metrics_06 dataframe.
#
# Derivations:
# - kl_grade_index_knee: worse-knee KL grade, used as structural, covariate and train/test stratification key in every stage.
# - employment_working: binary working indicator derived from V06CEMPLOY, used as a demographic covariate.
# - Symptomatic-side outcome columns: for bilateral knee variables, the more symptomatic knee is selected based on the outcome value. Lower = worse for KOOS-type scales; higher = worse for pain severity and ICOAP scales.

# %%
# Constants

DEMOGRAPHIC_COVARIATE_COLUMNS = [
    "V06AGE",
    "V06BMI",
    "V06COMORB",
    "employment_working",
]

STRUCTURAL_COVARIATE_COLUMN = "kl_grade_index_knee"

FINAL_PREDICTOR_COLUMNS = [
    # Sleep / wear
    "wake_minute_mean",                # Mean wake time across valid days
    "wake_minute_sd",                  # Standard deviation of wake time
    "wear_duration_mean",              # Mean daily wear duration in minutes

    # Bout structure: sedentary
    "mean_sedentary_bout_count",
    "mean_sedentary_bout_mean_duration",
    "mean_sedentary_bout_max_duration",
    "mean_sedentary_bout_total_minutes",

    # Bout structure: light
    "mean_light_bout_max_duration",

    # Bout structure: MVPA
    "mean_mvpa_bout_count",
    "mean_mvpa_bout_mean_duration",

    # Bout structure: active
    "mean_active_bout_mean_duration",
    "mean_active_bout_max_duration",
    "mean_active_bout_total_minutes",

    # Harmonic features: overall
    "acrophase",                       # Overall acrophase retained — not involved in any redundant pair
    "interdaily_stability",            # IS retained as overall only — day-split not meaningful

    # Harmonic features: day-type specific
    "mesor_mean_curve_weekday",        # Mean activity level on weekdays
    "mesor_mean_curve_weekend",        # Mean activity level on weekends
    "amplitude_mean_curve_weekday",    # Peak-to-mean swing on weekdays
    "amplitude_mean_curve_weekend",    # Peak-to-mean swing on weekends
    "acrophase_mean_curve_weekday",    # Timing of activity peak on weekdays
    "acrophase_mean_curve_weekend",    # Timing of activity peak on weekends

    # IV: day-type specific
    "iv_weekday",                      # Within-day fragmentation on weekdays
    "iv_weekend",                      # Within-day fragmentation on weekends
    "iv_contrast",                     # iv_weekday - iv_weekend: work-related fragmentation burden
]

OUTCOME_GROUPS: dict[str, list[str]] = {
    "pain": [
        "koos_pain_symptomatic_side",      # V06KOOSKPR / V06KOOSKPL — lower is worse
        "icoap_total_symptomatic_side",    # V06ICPTSKR / V06ICPTSKL — higher is worse
        "pain_7day_symptomatic_side",      # V06P7RKRCV / V06P7LKRCV — higher is worse
        "pain_bed_symptomatic_side",       # V06WPRKN3  / V06WPLKN3  — higher is worse
        "global_rating_symptomatic_side",  # V06KGLRS only (right side) — higher is worse
    ],
    "function": [
        "V0620MPACE",    # 20m walk pace (m/s)
        "V06CSPACE",     # repeated chair stand pace (stands/sec)
        "V06STEPST1",    # 20m walk trial 1 number of steps
        "V06400MTIM",    # 400m walk total time at 400m or at stop
    ],
    "adl": [
        "V06LLD6B",      # LLDI: extent feel limited in taking part in active recreation
        "V06LLD6A",      # LLDI: how often take part in active recreation
        "V06LLDILST",    # LLDI: limitation dimension total score (calculated)
        "V06LLD10B",     # LLDI: extent feel limited in taking part in regular fitness program
    ],
    "self_reported_function": [
        "dirkn1_symptomatic_side",    # down stairs
        "dirkn2_symptomatic_side",    # up stairs
        "dirkn3_symptomatic_side",    # stand from sitting
        "dirkn4_symptomatic_side",    # standing
        "dirkn5_symptomatic_side",    # bending
        "dirkn6_symptomatic_side",    # walking
        "dirkn7_symptomatic_side",    # in car / out of car
        "dirkn8_symptomatic_side",    # shopping
        "dirkn9_symptomatic_side",    # socks on
        "dirkn13_symptomatic_side",   # get in / out of bathtub
        "dirkn15_symptomatic_side",   # on / off toilet
        "dirkn16_symptomatic_side",   # heavy chores
        "dirkn17_symptomatic_side",   # light chores
        "dilkn10_symptomatic_side",   # get out of bed (left only)
        # dilkn12_symptomatic_side dropped: LASSO incremental R² -0.0008,
        # Ridge test R² 0.02 — no signal across both stages
        "V06KOOSFX1",                 # either knee: squatting
        "V06KOOSFX2",                 # either knee: running — keep, 44% complete cases
        "V06KOOSFX4",                 # either knee: twisting / pivoting
        "V06KOOSFX5",                 # either knee: kneeling
    ],
}

# Execution

"""
Copy summary_metrics_06 into the modelling dataframe.
summary_metrics_06 has ID set as the index at this point in the notebook
from the harmonic regression merge. Reset it to a regular column so that
prepare_modelling_dataset can use it for joins and stratification.
"""

summary_metrics_06 = summary_metrics_06.copy()
summary_metrics_06 = summary_metrics_06.reset_index()

print(
    f"Loaded from memory:  {summary_metrics_06.shape[0]:,} participants, "
    f"{summary_metrics_06.shape[1]} columns"
)

kl_missing = summary_metrics_06[STRUCTURAL_COVARIATE_COLUMN].isna().sum()
print(f"kl_grade_index_knee ready — missing in {kl_missing} participants")

# employment_group string labels "working" and "not working". A numeric binary column employment_working (1 = working, 0 = not working) is derived

summary_metrics_06["employment_working"] = summary_metrics_06["employment_group"].map(
    {"working": 1.0, "not working": 0.0}
)

employment_counts = summary_metrics_06["employment_working"].value_counts(dropna=False)
print(
    f"employment_working derived:\n"
    f"  Working     : {employment_counts.get(1.0, 0)}\n"
    f"  Not working : {employment_counts.get(0.0, 0)}\n"
    f"  Missing     : {summary_metrics_06['employment_working'].isna().sum()}"
)

# Derive symptomatic-side outcome columns. Derive_symptomatic_side_outcome is defined earlier in this notebook.
for output_column, (right_column, left_column) in BILATERAL_PAIRS_LOWER_IS_WORSE.items():
    summary_metrics_06 = derive_symptomatic_side_outcome(
        dataframe=summary_metrics_06,
        output_column=output_column,
        right_column=right_column,
        left_column=left_column,
        higher_is_worse=False,
    )

for output_column, (right_column, left_column) in BILATERAL_PAIRS_HIGHER_IS_WORSE.items():
    summary_metrics_06 = derive_symptomatic_side_outcome(
        dataframe=summary_metrics_06,
        output_column=output_column,
        right_column=right_column,
        left_column=left_column,
        higher_is_worse=True,
    )

print(
    f"Symptomatic-side outcomes derived: "
    f"{len(BILATERAL_PAIRS_LOWER_IS_WORSE) + len(BILATERAL_PAIRS_HIGHER_IS_WORSE)}"
)

# Verify that all predictor columns are present. Missing columns here will cause silent NaN propagation or KeyErrors in later stages, so fail loudly now.
missing_predictors = [
    column for column in FINAL_PREDICTOR_COLUMNS
    if column not in summary_metrics_06.columns
]

if missing_predictors:
    print(
        f"WARNING — the following predictor columns are missing from the "
        f"dataframe and will cause errors in later stages:\n"
        f"  {missing_predictors}"
    )
else:
    print(f"All {len(FINAL_PREDICTOR_COLUMNS)} predictor columns present.")

# Final shape and missingness summary.
print(
    f"\nModelling dataframe ready:\n"
    f"  Shape         : {summary_metrics_06.shape}\n"
    f"  Participants  : {len(summary_metrics_06):,}"
)

predictor_missingness = (
    summary_metrics_06[FINAL_PREDICTOR_COLUMNS]
    .isna()
    .sum()
    .sort_values(ascending=False)
)
predictors_with_missing = predictor_missingness[predictor_missingness > 0]

if predictors_with_missing.empty:
    print("  Predictor missingness: none")
else:
    print("  Predictor missingness (columns with any NaN):")
    for column_name, missing_count in predictors_with_missing.items():
        print(
            f"    {column_name:<45} {missing_count:>4} "
            f"({100 * missing_count / len(summary_metrics_06):.1f} %)"
        )
# Out:
# Loaded from memory:  1,845 participants, 126 columns
# kl_grade_index_knee ready — missing in 1 participants
# employment_working derived:
#   Working     : 984
#   Not working : 813
#   Missing     : 48
# Symptomatic-side outcomes derived: 20
# All 24 predictor columns present.
#
# Modelling dataframe ready:
#   Shape         : (1845, 147)
#   Participants  : 1,845
#   Predictor missingness (columns with any NaN):
#     iv_contrast                                     41 (2.2 %)
#     iv_weekend                                      41 (2.2 %)
#     acrophase_mean_curve_weekend                    41 (2.2 %)
#     amplitude_mean_curve_weekend                    41 (2.2 %)
#     mesor_mean_curve_weekend                        41 (2.2 %)

# %% [markdown]
# ## 2.2. Models

# %% [markdown]
# ### 2.2.1. LASSO
#
# **Purpose**
# LASSO (Least Absolute Shrinkage and Selection Operator) is used here in its explanatory role rather than as a pure predictive model. The key result is the incremental R² — how much additional variance in each outcome is explained by the activity predictor block on top of the demographic and structural covariates alone.
#
# **Why LASSO for the explanatory stage**
# LASSO applies L1 regularisation, which shrinks the coefficients of weak or redundant predictors exactly to zero. This produces a sparse solution that identifies which activity features carry independent signal after the covariate block is accounted for. The sparsity is methodologically useful for a thesis: it forces explicit feature selection rather than distributing signal across all predictors, and the selected predictors can be reported and interpreted directly.
#
# **Two-block design**
# The model is fitted in two blocks: Block 1 (baseline): demographic covariates only (age, BMI, comorbidity count, employment status), fitted with plain OLS. Block 2 (full): covariates (unregularised) + activity predictors (standardised and L1-regularised via LassoCV).
# The incremental R² (full minus baseline, both evaluated via 10-fold cross-validation on the training set) is the primary reported metric. It quantifies the unique contribution of the accelerometry-derived activity features independent of clinical background characteristics.
#
# KL grade is included as an additional structural covariate for all non-structural outcomes. It is excluded only when KL grade is itself the outcome (Stage 6).
#
# **What is NOT reported here**
# Held-out test set performance is not the focus of this stage. The predictive model families (Ridge, Elastic Net, Random Forest, XGBoost) in Stages 2–5 are evaluated on the held-out test set. LASSO is evaluated on the training set via cross-validation to preserve its explanatory interpretation.
#
# **Output**
# lasso_results: dict mapping outcome_group_name -> list of per-outcome result dicts. Each result dict contains:
#    - outcome_column
#    - baseline_r2_cv
#    - full_r2_cv
#    - incremental_r2
#    - selected_predictors (list of non-zero activity predictors)
#    - lasso_coefficients (Series ranked by absolute magnitude)
#    - optimal_alpha

# %%
def prepare_modelling_dataset_for_stage(
    *,
    dataframe: pd.DataFrame,
    outcome_column: str,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    include_structural_covariate: bool = True,
    test_set_fraction: float = 0.20,
    cross_validation_folds: int = 10,
    random_state: int = 42,
) -> tuple[pd.DataFrame, pd.Series, pd.DataFrame, pd.Series]:
    """
    Prepare a clean train/test split for a single outcome variable.

    Rows with any missing value in the covariate, predictor, or outcome
    columns are dropped before splitting. The split is stratified on KL
    grade (binned into three groups: 0–1, 2–3, 4) to preserve the
    severity distribution across both sets.

    :param dataframe: Modelling dataframe with one row per participant.
    :param outcome_column: Name of the outcome variable to predict.
    :param activity_predictor_columns: Activity predictor column names.
    :param demographic_covariate_columns: Demographic covariate column
        names included without regularisation.
    :param structural_covariate_column: KL grade column name.
    :param include_structural_covariate: Whether to include KL grade in
        the covariate block. Set to False only when KL grade is the
        outcome (Stage 6).
    :param test_set_fraction: Proportion of data held out for testing.
    :param cross_validation_folds: Number of folds for cross-validation.
    :param random_state: Random seed for reproducibility.
    :returns: Tuple of (training_predictors, training_outcome,
        test_predictors, test_outcome).
    :raises ValueError: If fewer than 100 complete cases remain after
        dropping missing values.
    """
    covariate_columns = list(demographic_covariate_columns)
    if include_structural_covariate:
        covariate_columns.append(structural_covariate_column)

    all_required_columns = covariate_columns + activity_predictor_columns + [outcome_column]
    complete_cases = dataframe[all_required_columns].dropna()

    complete_case_count = len(complete_cases)
    total_count = len(dataframe)

    print(
        f"  Complete cases : {complete_case_count:,} of {total_count:,} "
        f"({100 * complete_case_count / total_count:.1f} %)"
    )

    if complete_case_count < 100:
        raise ValueError(
            f"Only {complete_case_count} complete cases remain for "
            f"'{outcome_column}'. Modelling would be unreliable."
        )

    outcome_series = complete_cases[outcome_column]
    predictor_dataframe = complete_cases[covariate_columns + activity_predictor_columns]

    kl_grade_bins = pd.cut(
        complete_cases[structural_covariate_column],
        bins=[-0.5, 1.5, 3.5, 4.5],
        labels=["kl_0_1", "kl_2_3", "kl_4"],
    )

    (
        training_predictors,
        test_predictors,
        training_outcome,
        test_outcome,
    ) = train_test_split(
        predictor_dataframe,
        outcome_series,
        test_size=test_set_fraction,
        random_state=random_state,
        stratify=kl_grade_bins,
    )

    print(
        f"  Training set   : {len(training_predictors):,} participants\n"
        f"  Test set       : {len(test_predictors):,} participants"
    )

    return training_predictors, training_outcome, test_predictors, test_outcome


def run_lasso_for_outcome(
    *,
    outcome_column: str,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    include_structural_covariate: bool = True,
    cross_validation_folds: int = 10,
    random_state: int = 42,
) -> dict:
    """
    Fit the two-block explanatory LASSO model for a single outcome and
    return all metrics in a result dictionary.

    Block 1 (baseline): demographic covariates only, plain OLS, evaluated
    via cross-validation to produce baseline_r2_cv.

    Block 2 (full): covariates (unregularised) concatenated with
    standardised activity predictors, regularised via LassoCV.
    Cross-validated R² on the training set produces full_r2_cv.

    The incremental R² (full_r2_cv minus baseline_r2_cv) is the primary
    reported metric: it quantifies the unique variance explained by the
    activity block after controlling for demographic and structural
    covariates.

    :param outcome_column: Name of the outcome variable to model.
    :param dataframe: Modelling dataframe with one row per participant.
    :param activity_predictor_columns: Activity predictor column names
        (standardised and regularised).
    :param demographic_covariate_columns: Demographic covariate column
        names (included unregularised in both blocks).
    :param structural_covariate_column: KL grade column name.
    :param include_structural_covariate: Whether to include KL grade as
        a covariate. Always True except for Stage 6.
    :param cross_validation_folds: Number of CV folds (default 10).
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys baseline_r2_cv, full_r2_cv,
        incremental_r2, selected_predictors, lasso_coefficients,
        optimal_alpha, outcome_column, n_training, n_test.
    """
    covariate_columns = list(demographic_covariate_columns)
    if include_structural_covariate:
        covariate_columns.append(structural_covariate_column)

    (
        training_predictors,
        training_outcome,
        test_predictors,
        test_outcome,
    ) = prepare_modelling_dataset_for_stage(
        dataframe=dataframe,
        outcome_column=outcome_column,
        activity_predictor_columns=activity_predictor_columns,
        demographic_covariate_columns=demographic_covariate_columns,
        structural_covariate_column=structural_covariate_column,
        include_structural_covariate=include_structural_covariate,
    )

    covariate_training = training_predictors[covariate_columns]
    activity_training = training_predictors[activity_predictor_columns]

    # Block 1 — baseline: covariates only, plain OLS
    kfold = KFold(
        n_splits=cross_validation_folds,
        shuffle=True,
        random_state=random_state,
    )

    baseline_scores = cross_val_score(
        estimator=LinearRegression(),
        X=covariate_training,
        y=training_outcome,
        cv=kfold,
        scoring="r2",
    )
    baseline_r2_cv = float(baseline_scores.mean())

    # Block 2 — full: covariates (unscaled) + standardised activity predictors
    scaler = StandardScaler()
    activity_training_scaled = scaler.fit_transform(activity_training)

    full_training_matrix = np.hstack(
        [covariate_training.values, activity_training_scaled]
    )

    lasso_model = LassoCV(
        cv=cross_validation_folds,
        random_state=random_state,
        max_iter=50_000,
    )

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        lasso_model.fit(full_training_matrix, training_outcome)

    full_scores = cross_val_score(
        estimator=lasso_model,
        X=full_training_matrix,
        y=training_outcome,
        cv=KFold(
            n_splits=cross_validation_folds,
            shuffle=True,
            random_state=random_state,
        ),
        scoring="r2",
    )
    full_r2_cv = float(full_scores.mean())
    incremental_r2 = full_r2_cv - baseline_r2_cv

    # Extract non-zero activity predictor coefficients
    # The covariate block occupies the first len(covariate_columns) positions.
    # Activity coefficients start immediately after.
    number_of_covariates = len(covariate_columns)
    activity_coefficients = lasso_model.coef_[number_of_covariates:]
    non_zero_mask = activity_coefficients != 0

    selected_predictors = [
        column
        for column, is_selected in zip(activity_predictor_columns, non_zero_mask)
        if is_selected
    ]

    lasso_coefficients = pd.Series(
        data=activity_coefficients[non_zero_mask],
        index=selected_predictors,
        name="lasso_coefficient",
    ).sort_values(key=abs, ascending=False)

    print(
        f"\n  Baseline R² (covariates only, {cross_validation_folds}-fold CV) : "
        f"{baseline_r2_cv:.4f}\n"
        f"  Full R²     (covariates + activity)            : "
        f"{full_r2_cv:.4f}\n"
        f"  Incremental R² (activity block)                : "
        f"{incremental_r2:.4f}\n"
        f"  Optimal alpha                                  : "
        f"{lasso_model.alpha_:.6f}\n"
        f"  Predictors selected (non-zero)                 : "
        f"{len(selected_predictors)} / {len(activity_predictor_columns)}"
    )

    if selected_predictors:
        print("\n  Non-zero coefficients (ranked by absolute magnitude):")
        for predictor_name, coefficient_value in lasso_coefficients.items():
            print(f"    {predictor_name:<45} {coefficient_value:+.4f}")

    return {
        "outcome_column": outcome_column,
        "n_training": len(training_predictors),
        "n_test": len(test_predictors),
        "baseline_r2_cv": baseline_r2_cv,
        "full_r2_cv": full_r2_cv,
        "incremental_r2": incremental_r2,
        "selected_predictors": selected_predictors,
        "lasso_coefficients": lasso_coefficients,
        "optimal_alpha": float(lasso_model.alpha_),
    }

# %% [markdown]
# #### Execute LASSO for all outcomes

# %%
RANDOM_STATE = 42
CROSS_VALIDATION_FOLDS = 10

lasso_results: dict[str, list[dict]] = {}

for group_name, outcome_columns in OUTCOME_GROUPS.items():
    print(f"\n{'=' * 70}")
    print(f"Group: {group_name}  ({len(outcome_columns)} outcomes)")
    print(f"{'=' * 70}")

    group_results = []

    for outcome_column in outcome_columns:
        print(f"\n  Outcome: {outcome_column}")
        print(f"  {'-' * 50}")

        try:
            result = run_lasso_for_outcome(
                outcome_column=outcome_column,
                dataframe=summary_metrics_06,
                activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
                demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
                structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
                include_structural_covariate=True,
                cross_validation_folds=CROSS_VALIDATION_FOLDS,
                random_state=RANDOM_STATE,
            )
            group_results.append(result)

        except ValueError as error:
            print(f"  Skipped: {error}")

    lasso_results[group_name] = group_results
# Out:
# ======================================================================
# Group: pain  (5 outcomes)
# ======================================================================
#
#   Outcome: koos_pain_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.1201
#   Full R²     (covariates + activity)            : 0.1354
#   Incremental R² (activity block)                : 0.0153
#   Optimal alpha                                  : 0.336356
#   Predictors selected (non-zero)                 : 8 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          +1.4730
#     mean_sedentary_bout_total_minutes             +1.1071
#     wake_minute_sd                                -0.8628
#     iv_weekend                                    -0.7125
#     interdaily_stability                          -0.5365
#     mean_mvpa_bout_mean_duration                  +0.3174
#     amplitude_mean_curve_weekday                  +0.1041
#     iv_weekday                                    -0.0728
#
#   Outcome: icoap_total_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0765
#   Full R²     (covariates + activity)            : 0.0835
#   Incremental R² (activity block)                : 0.0069
#   Optimal alpha                                  : 0.208561
#   Predictors selected (non-zero)                 : 10 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.7867
#     mean_mvpa_bout_count                          -0.5705
#     wake_minute_sd                                +0.4576
#     mesor_mean_curve_weekday                      -0.3951
#     iv_weekend                                    +0.3709
#     iv_weekday                                    +0.2560
#     amplitude_mean_curve_weekend                  +0.2265
#     interdaily_stability                          +0.2233
#     mean_mvpa_bout_mean_duration                  -0.1322
#     acrophase                                     +0.0416
#
#   Outcome: pain_7day_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0702
#   Full R²     (covariates + activity)            : 0.0928
#   Incremental R² (activity block)                : 0.0226
#   Optimal alpha                                  : 0.045609
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          -0.2299
#     mean_sedentary_bout_total_minutes             -0.2146
#     interdaily_stability                          +0.1976
#     iv_weekend                                    +0.1276
#     mean_mvpa_bout_mean_duration                  -0.1048
#     amplitude_mean_curve_weekday                  -0.0817
#     wake_minute_sd                                +0.0666
#     mean_sedentary_bout_mean_duration             -0.0455
#     acrophase                                     +0.0449
#
#   Outcome: pain_bed_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0434
#   Full R²     (covariates + activity)            : 0.0468
#   Incremental R² (activity block)                : 0.0034
#   Optimal alpha                                  : 0.019795
#   Predictors selected (non-zero)                 : 4 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.0575
#     mean_mvpa_bout_count                          -0.0323
#     iv_weekend                                    +0.0285
#     wake_minute_sd                                +0.0187
#
#   Outcome: global_rating_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0805
#   Full R²     (covariates + activity)            : 0.0942
#   Incremental R² (activity block)                : 0.0137
#   Optimal alpha                                  : 0.028161
#   Predictors selected (non-zero)                 : 12 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.0965
#     wake_minute_sd                                +0.0947
#     mean_mvpa_bout_count                          -0.0923
#     iv_weekend                                    +0.0863
#     interdaily_stability                          +0.0826
#     acrophase_mean_curve_weekday                  +0.0767
#     iv_weekday                                    +0.0671
#     mean_sedentary_bout_max_duration              +0.0613
#     acrophase_mean_curve_weekend                  +0.0367
#     mean_active_bout_total_minutes                -0.0302
#     mean_mvpa_bout_mean_duration                  -0.0262
#     mesor_mean_curve_weekday                      -0.0120
#
# ======================================================================
# Group: function  (4 outcomes)
# ======================================================================
#
#   Outcome: V0620MPACE
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.1726
#   Full R²     (covariates + activity)            : 0.2258
#   Incremental R² (activity block)                : 0.0531
#   Optimal alpha                                  : 0.002958
#   Predictors selected (non-zero)                 : 12 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mesor_mean_curve_weekday                      +0.0169
#     mean_mvpa_bout_count                          +0.0169
#     iv_weekday                                    -0.0168
#     mean_sedentary_bout_total_minutes             +0.0144
#     interdaily_stability                          -0.0118
#     iv_weekend                                    -0.0101
#     mean_mvpa_bout_mean_duration                  +0.0070
#     amplitude_mean_curve_weekend                  +0.0060
#     mean_sedentary_bout_max_duration              -0.0035
#     acrophase_mean_curve_weekend                  +0.0020
#     mean_light_bout_max_duration                  -0.0013
#     mean_sedentary_bout_count                     +0.0005
#
#   Outcome: V06CSPACE
#   --------------------------------------------------
#   Complete cases : 1,638 of 1,845 (88.8 %)
#   Training set   : 1,310 participants
#   Test set       : 328 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.1180
#   Full R²     (covariates + activity)            : 0.1195
#   Incremental R² (activity block)                : 0.0015
#   Optimal alpha                                  : 0.002647
#   Predictors selected (non-zero)                 : 11 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_mean_duration                  +0.0079
#     mesor_mean_curve_weekend                      +0.0067
#     iv_weekend                                    -0.0045
#     wake_minute_sd                                -0.0033
#     interdaily_stability                          -0.0033
#     mean_sedentary_bout_mean_duration             +0.0031
#     mean_mvpa_bout_count                          +0.0027
#     amplitude_mean_curve_weekday                  +0.0025
#     wake_minute_mean                              -0.0014
#     mean_light_bout_max_duration                  +0.0012
#     acrophase                                     -0.0006
#
#   Outcome: V06STEPST1
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.1831
#   Full R²     (covariates + activity)            : 0.2747
#   Incremental R² (activity block)                : 0.0916
#   Optimal alpha                                  : 0.031829
#   Predictors selected (non-zero)                 : 14 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          -0.6535
#     mean_sedentary_bout_total_minutes             -0.5516
#     amplitude_mean_curve_weekday                  -0.4318
#     iv_weekend                                    +0.2714
#     interdaily_stability                          +0.2602
#     mean_active_bout_max_duration                 +0.2443
#     mean_mvpa_bout_mean_duration                  -0.2314
#     mean_sedentary_bout_max_duration              +0.2205
#     mean_sedentary_bout_count                     +0.1879
#     amplitude_mean_curve_weekend                  -0.1488
#     iv_weekday                                    +0.1305
#     acrophase_mean_curve_weekend                  -0.1137
#     mean_active_bout_mean_duration                -0.0965
#     wake_minute_sd                                +0.0372
#
#   Outcome: V06400MTIM
#   --------------------------------------------------
#   Complete cases : 1,560 of 1,845 (84.6 %)
#   Training set   : 1,248 participants
#   Test set       : 312 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.1783
#   Full R²     (covariates + activity)            : 0.2285
#   Incremental R² (activity block)                : 0.0501
#   Optimal alpha                                  : 0.698085
#   Predictors selected (non-zero)                 : 12 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          -6.6222
#     iv_weekend                                    +3.8190
#     mean_mvpa_bout_mean_duration                  -3.7460
#     iv_weekday                                    +3.1240
#     interdaily_stability                          +2.6337
#     amplitude_mean_curve_weekday                  -2.1575
#     mesor_mean_curve_weekday                      -1.9109
#     mean_sedentary_bout_total_minutes             -1.7933
#     wear_duration_mean                            +1.2228
#     mean_active_bout_mean_duration                +0.8340
#     mean_sedentary_bout_max_duration              +0.3201
#     acrophase                                     +0.0230
#
# ======================================================================
# Group: adl  (4 outcomes)
# ======================================================================
#
#   Outcome: V06LLD6B
#   --------------------------------------------------
#   Complete cases : 1,727 of 1,845 (93.6 %)
#   Training set   : 1,381 participants
#   Test set       : 346 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0432
#   Full R²     (covariates + activity)            : 0.0777
#   Incremental R² (activity block)                : 0.0345
#   Optimal alpha                                  : 0.016236
#   Predictors selected (non-zero)                 : 10 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     amplitude_mean_curve_weekday                  +0.0901
#     iv_weekday                                    -0.0862
#     mean_sedentary_bout_total_minutes             +0.0585
#     mean_sedentary_bout_max_duration              -0.0535
#     iv_weekend                                    -0.0418
#     mean_mvpa_bout_mean_duration                  +0.0347
#     acrophase_mean_curve_weekend                  -0.0330
#     mean_sedentary_bout_mean_duration             -0.0207
#     wake_minute_sd                                -0.0121
#     mean_mvpa_bout_count                          +0.0077
#
#   Outcome: V06LLD6A
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0474
#   Full R²     (covariates + activity)            : 0.1440
#   Incremental R² (activity block)                : 0.0965
#   Optimal alpha                                  : 0.004237
#   Predictors selected (non-zero)                 : 20 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mesor_mean_curve_weekday                      +0.2071
#     mean_active_bout_total_minutes                -0.2028
#     wear_duration_mean                            +0.1299
#     mean_light_bout_max_duration                  +0.1117
#     mean_mvpa_bout_mean_duration                  +0.1025
#     wake_minute_sd                                -0.1010
#     mean_mvpa_bout_count                          +0.0968
#     iv_weekday                                    -0.0943
#     iv_weekend                                    -0.0937
#     mesor_mean_curve_weekend                      -0.0883
#     amplitude_mean_curve_weekend                  +0.0791
#     wake_minute_mean                              +0.0750
#     mean_sedentary_bout_total_minutes             +0.0595
#     interdaily_stability                          -0.0566
#     acrophase_mean_curve_weekend                  -0.0401
#     mean_sedentary_bout_mean_duration             -0.0239
#     amplitude_mean_curve_weekday                  +0.0179
#     mean_sedentary_bout_max_duration              -0.0118
#     acrophase_mean_curve_weekday                  -0.0098
#     acrophase                                     -0.0002
#
#   Outcome: V06LLDILST
#   --------------------------------------------------
#   Complete cases : 1,691 of 1,845 (91.7 %)
#   Training set   : 1,352 participants
#   Test set       : 339 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0243
#   Full R²     (covariates + activity)            : 0.0600
#   Incremental R² (activity block)                : 0.0358
#   Optimal alpha                                  : 0.148915
#   Predictors selected (non-zero)                 : 15 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             +1.6426
#     mean_sedentary_bout_max_duration              -1.5232
#     mean_sedentary_bout_count                     -1.2187
#     amplitude_mean_curve_weekday                  +0.9628
#     wake_minute_sd                                -0.7957
#     acrophase                                     -0.7690
#     iv_weekend                                    -0.6576
#     iv_weekday                                    -0.6278
#     mean_sedentary_bout_mean_duration             -0.5574
#     mean_mvpa_bout_mean_duration                  +0.5235
#     mean_mvpa_bout_count                          +0.4798
#     mesor_mean_curve_weekend                      -0.2575
#     wear_duration_mean                            +0.2323
#     mean_active_bout_mean_duration                +0.0640
#     acrophase_mean_curve_weekend                  -0.0411
#
#   Outcome: V06LLD10B
#   --------------------------------------------------
#   Complete cases : 1,732 of 1,845 (93.9 %)
#   Training set   : 1,385 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0514
#   Full R²     (covariates + activity)            : 0.0711
#   Incremental R² (activity block)                : 0.0197
#   Optimal alpha                                  : 0.009546
#   Predictors selected (non-zero)                 : 15 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     iv_weekday                                    -0.1146
#     mesor_mean_curve_weekday                      +0.0749
#     mean_active_bout_total_minutes                -0.0498
#     mean_sedentary_bout_max_duration              -0.0458
#     wake_minute_sd                                -0.0388
#     interdaily_stability                          -0.0298
#     mean_sedentary_bout_total_minutes             +0.0195
#     iv_weekend                                    -0.0168
#     amplitude_mean_curve_weekday                  +0.0158
#     acrophase_mean_curve_weekday                  -0.0137
#     mean_mvpa_bout_count                          +0.0121
#     mean_sedentary_bout_mean_duration             -0.0095
#     wake_minute_mean                              +0.0094
#     wear_duration_mean                            -0.0040
#     acrophase_mean_curve_weekend                  -0.0004
#
# ======================================================================
# Group: self_reported_function  (18 outcomes)
# ======================================================================
#
#   Outcome: dirkn1_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0792
#   Full R²     (covariates + activity)            : 0.0943
#   Incremental R² (activity block)                : 0.0151
#   Optimal alpha                                  : 0.013982
#   Predictors selected (non-zero)                 : 7 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          -0.0824
#     mean_mvpa_bout_mean_duration                  -0.0704
#     wake_minute_sd                                +0.0509
#     interdaily_stability                          +0.0336
#     mean_sedentary_bout_mean_duration             -0.0109
#     acrophase_mean_curve_weekend                  -0.0040
#     iv_weekend                                    +0.0037
#
#   Outcome: dirkn2_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0911
#   Full R²     (covariates + activity)            : 0.1122
#   Incremental R² (activity block)                : 0.0211
#   Optimal alpha                                  : 0.016934
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     amplitude_mean_curve_weekday                  -0.0741
#     interdaily_stability                          +0.0713
#     iv_weekend                                    +0.0575
#     wake_minute_sd                                +0.0463
#     mean_sedentary_bout_total_minutes             -0.0340
#     mean_mvpa_bout_mean_duration                  -0.0284
#     acrophase_mean_curve_weekday                  +0.0220
#     mean_mvpa_bout_count                          -0.0201
#     wake_minute_mean                              -0.0017
#
#   Outcome: dirkn3_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0981
#   Full R²     (covariates + activity)            : 0.1118
#   Incremental R² (activity block)                : 0.0137
#   Optimal alpha                                  : 0.006357
#   Predictors selected (non-zero)                 : 16 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.1105
#     mean_mvpa_bout_count                          -0.0832
#     interdaily_stability                          +0.0512
#     mean_light_bout_max_duration                  -0.0463
#     mean_sedentary_bout_max_duration              +0.0428
#     iv_weekend                                    +0.0414
#     mean_mvpa_bout_mean_duration                  -0.0377
#     wear_duration_mean                            +0.0334
#     wake_minute_sd                                +0.0314
#     amplitude_mean_curve_weekday                  -0.0312
#     mean_sedentary_bout_mean_duration             -0.0243
#     mesor_mean_curve_weekend                      +0.0185
#     acrophase                                     +0.0163
#     iv_weekday                                    +0.0119
#     mean_sedentary_bout_count                     +0.0119
#     amplitude_mean_curve_weekend                  +0.0035
#
#   Outcome: dirkn4_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0900
#   Full R²     (covariates + activity)            : 0.0959
#   Incremental R² (activity block)                : 0.0059
#   Optimal alpha                                  : 0.014973
#   Predictors selected (non-zero)                 : 7 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.0381
#     iv_weekday                                    +0.0323
#     wake_minute_sd                                +0.0263
#     interdaily_stability                          +0.0192
#     mean_mvpa_bout_count                          -0.0167
#     iv_weekend                                    +0.0131
#     mean_mvpa_bout_mean_duration                  -0.0113
#
#   Outcome: dirkn5_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,677 of 1,845 (90.9 %)
#   Training set   : 1,341 participants
#   Test set       : 336 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0743
#   Full R²     (covariates + activity)            : 0.0900
#   Incremental R² (activity block)                : 0.0157
#   Optimal alpha                                  : 0.010254
#   Predictors selected (non-zero)                 : 12 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     amplitude_mean_curve_weekday                  -0.0940
#     interdaily_stability                          +0.0938
#     mean_sedentary_bout_total_minutes             -0.0923
#     iv_weekend                                    +0.0388
#     mean_mvpa_bout_mean_duration                  -0.0363
#     acrophase                                     +0.0336
#     mean_sedentary_bout_count                     +0.0314
#     mean_sedentary_bout_max_duration              +0.0279
#     mean_mvpa_bout_count                          -0.0188
#     acrophase_mean_curve_weekday                  +0.0143
#     mean_sedentary_bout_mean_duration             -0.0080
#     iv_weekday                                    +0.0027
#
#   Outcome: dirkn6_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0902
#   Full R²     (covariates + activity)            : 0.1030
#   Incremental R² (activity block)                : 0.0128
#   Optimal alpha                                  : 0.012626
#   Predictors selected (non-zero)                 : 7 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.0634
#     amplitude_mean_curve_weekday                  -0.0383
#     iv_weekend                                    +0.0301
#     mean_mvpa_bout_count                          -0.0270
#     wake_minute_sd                                +0.0173
#     interdaily_stability                          +0.0102
#     iv_weekday                                    +0.0004
#
#   Outcome: dirkn7_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0628
#   Full R²     (covariates + activity)            : 0.0765
#   Incremental R² (activity block)                : 0.0137
#   Optimal alpha                                  : 0.014586
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0708
#     mean_sedentary_bout_total_minutes             -0.0477
#     mean_mvpa_bout_count                          -0.0436
#     iv_weekend                                    +0.0433
#     interdaily_stability                          +0.0302
#     amplitude_mean_curve_weekday                  -0.0219
#     wear_duration_mean                            +0.0216
#     acrophase_mean_curve_weekday                  -0.0048
#     mean_mvpa_bout_mean_duration                  -0.0038
#
#   Outcome: dirkn8_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0860
#   Full R²     (covariates + activity)            : 0.1077
#   Incremental R² (activity block)                : 0.0216
#   Optimal alpha                                  : 0.015109
#   Predictors selected (non-zero)                 : 8 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_mvpa_bout_count                          -0.0478
#     mean_sedentary_bout_total_minutes             -0.0435
#     iv_weekend                                    +0.0324
#     wake_minute_sd                                +0.0283
#     mean_mvpa_bout_mean_duration                  -0.0190
#     amplitude_mean_curve_weekday                  -0.0153
#     interdaily_stability                          +0.0120
#     iv_weekday                                    +0.0027
#
#   Outcome: dirkn9_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0595
#   Full R²     (covariates + activity)            : 0.0689
#   Incremental R² (activity block)                : 0.0095
#   Optimal alpha                                  : 0.011521
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0436
#     iv_weekend                                    +0.0430
#     mesor_mean_curve_weekday                      -0.0344
#     mean_sedentary_bout_total_minutes             -0.0293
#     interdaily_stability                          +0.0181
#     mean_mvpa_bout_count                          -0.0146
#     mean_mvpa_bout_mean_duration                  -0.0059
#     acrophase_mean_curve_weekend                  -0.0056
#     mean_sedentary_bout_mean_duration             -0.0053
#
#   Outcome: dirkn13_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,437 of 1,845 (77.9 %)
#   Training set   : 1,149 participants
#   Test set       : 288 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0525
#   Full R²     (covariates + activity)            : 0.0689
#   Incremental R² (activity block)                : 0.0164
#   Optimal alpha                                  : 0.011005
#   Predictors selected (non-zero)                 : 12 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0536
#     iv_weekday                                    +0.0498
#     mean_mvpa_bout_count                          -0.0497
#     mean_sedentary_bout_total_minutes             -0.0497
#     interdaily_stability                          +0.0403
#     mean_mvpa_bout_mean_duration                  -0.0183
#     amplitude_mean_curve_weekday                  -0.0108
#     mean_active_bout_mean_duration                -0.0107
#     mean_sedentary_bout_mean_duration             -0.0082
#     acrophase_mean_curve_weekday                  -0.0075
#     iv_weekend                                    +0.0052
#     mean_sedentary_bout_count                     +0.0009
#
#   Outcome: dirkn15_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0446
#   Full R²     (covariates + activity)            : 0.0529
#   Incremental R² (activity block)                : 0.0083
#   Optimal alpha                                  : 0.011865
#   Predictors selected (non-zero)                 : 10 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0520
#     mean_mvpa_bout_count                          -0.0351
#     interdaily_stability                          +0.0304
#     mean_mvpa_bout_mean_duration                  -0.0289
#     iv_weekend                                    +0.0258
#     mean_sedentary_bout_total_minutes             -0.0162
#     mean_sedentary_bout_count                     +0.0085
#     iv_weekday                                    +0.0084
#     mean_light_bout_max_duration                  -0.0081
#     mean_sedentary_bout_mean_duration             -0.0014
#
#   Outcome: dirkn16_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,640 of 1,845 (88.9 %)
#   Training set   : 1,312 participants
#   Test set       : 328 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0698
#   Full R²     (covariates + activity)            : 0.0766
#   Incremental R² (activity block)                : 0.0069
#   Optimal alpha                                  : 0.014794
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0504
#     amplitude_mean_curve_weekday                  -0.0420
#     mean_sedentary_bout_total_minutes             -0.0392
#     iv_contrast                                   -0.0254
#     mean_mvpa_bout_mean_duration                  -0.0239
#     acrophase                                     +0.0188
#     mean_sedentary_bout_max_duration              +0.0095
#     mean_active_bout_total_minutes                +0.0023
#     iv_weekend                                    +0.0005
#
#   Outcome: dirkn17_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0507
#   Full R²     (covariates + activity)            : 0.0752
#   Incremental R² (activity block)                : 0.0245
#   Optimal alpha                                  : 0.009176
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0533
#     mean_sedentary_bout_total_minutes             -0.0378
#     amplitude_mean_curve_weekday                  -0.0330
#     iv_weekend                                    +0.0269
#     mean_mvpa_bout_mean_duration                  -0.0223
#     interdaily_stability                          +0.0206
#     mean_mvpa_bout_count                          -0.0174
#     wake_minute_mean                              +0.0009
#     iv_weekday                                    +0.0000
#
#   Outcome: dilkn10_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0283
#   Full R²     (covariates + activity)            : 0.0367
#   Incremental R² (activity block)                : 0.0084
#   Optimal alpha                                  : 0.014857
#   Predictors selected (non-zero)                 : 7 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     mean_sedentary_bout_total_minutes             -0.0370
#     wake_minute_sd                                +0.0315
#     mean_mvpa_bout_count                          -0.0270
#     iv_weekend                                    +0.0212
#     acrophase_mean_curve_weekday                  -0.0081
#     mean_mvpa_bout_mean_duration                  -0.0023
#     interdaily_stability                          +0.0002
#
#   Outcome: V06KOOSFX1
#   --------------------------------------------------
#   Complete cases : 1,434 of 1,845 (77.7 %)
#   Training set   : 1,147 participants
#   Test set       : 287 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0517
#   Full R²     (covariates + activity)            : 0.0623
#   Incremental R² (activity block)                : 0.0106
#   Optimal alpha                                  : 0.030345
#   Predictors selected (non-zero)                 : 8 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0657
#     iv_weekday                                    +0.0591
#     mean_active_bout_total_minutes                +0.0344
#     mean_sedentary_bout_mean_duration             -0.0288
#     mean_mvpa_bout_mean_duration                  -0.0156
#     iv_weekend                                    +0.0135
#     amplitude_mean_curve_weekday                  -0.0095
#     mean_sedentary_bout_total_minutes             -0.0063
#
#   Outcome: V06KOOSFX2
#   --------------------------------------------------
#   Complete cases : 810 of 1,845 (43.9 %)
#   Training set   : 648 participants
#   Test set       : 162 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.1279
#   Full R²     (covariates + activity)            : 0.1237
#   Incremental R² (activity block)                : -0.0042
#   Optimal alpha                                  : 0.037280
#   Predictors selected (non-zero)                 : 6 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     acrophase                                     +0.0251
#     amplitude_mean_curve_weekday                  -0.0228
#     iv_weekend                                    +0.0191
#     mean_sedentary_bout_mean_duration             -0.0100
#     acrophase_mean_curve_weekday                  +0.0029
#     acrophase_mean_curve_weekend                  -0.0027
#
#   Outcome: V06KOOSFX4
#   --------------------------------------------------
#   Complete cases : 1,430 of 1,845 (77.5 %)
#   Training set   : 1,144 participants
#   Test set       : 286 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0872
#   Full R²     (covariates + activity)            : 0.0762
#   Incremental R² (activity block)                : -0.0110
#   Optimal alpha                                  : 0.043348
#   Predictors selected (non-zero)                 : 2 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     wake_minute_sd                                +0.0254
#     iv_weekend                                    +0.0107
#
#   Outcome: V06KOOSFX5
#   --------------------------------------------------
#   Complete cases : 1,515 of 1,845 (82.1 %)
#   Training set   : 1,212 participants
#   Test set       : 303 participants
#
#   Baseline R² (covariates only, 10-fold CV) : 0.0412
#   Full R²     (covariates + activity)            : 0.0581
#   Incremental R² (activity block)                : 0.0169
#   Optimal alpha                                  : 0.021105
#   Predictors selected (non-zero)                 : 9 / 24
#
#   Non-zero coefficients (ranked by absolute magnitude):
#     amplitude_mean_curve_weekday                  -0.0761
#     mean_sedentary_bout_total_minutes             -0.0717
#     iv_weekend                                    +0.0667
#     interdaily_stability                          +0.0510
#     mean_mvpa_bout_count                          -0.0450
#     mean_sedentary_bout_mean_duration             -0.0268
#     mean_light_bout_max_duration                  +0.0241
#     iv_weekday                                    +0.0164
#     acrophase_mean_curve_weekday                  +0.0113

# %% [markdown]
# #### Lasso summary table

# %%
summary_rows = []

for group_name, group_results in lasso_results.items():
    for result in group_results:
        summary_rows.append({
            "group": group_name,
            "outcome": result["outcome_column"],
            "n_training": result["n_training"],
            "baseline_r2_cv": round(result["baseline_r2_cv"], 4),
            "full_r2_cv": round(result["full_r2_cv"], 4),
            "incremental_r2": round(result["incremental_r2"], 4),
            "n_selected_predictors": len(result["selected_predictors"]),
            "optimal_alpha": round(result["optimal_alpha"], 6),
        })

lasso_summary_table = pd.DataFrame(summary_rows)

print("\nStage 1 — LASSO summary (sorted by incremental R²):")
print(
    lasso_summary_table
    .sort_values("incremental_r2", ascending=False)
    .to_string(index=False)
)
# Out:
# Stage 1 — LASSO summary (sorted by incremental R²):
#                  group                        outcome  n_training  baseline_r2_cv  full_r2_cv  incremental_r2  n_selected_predictors  optimal_alpha
#                    adl                       V06LLD6A        1386          0.0474      0.1440          0.0965                     20       0.004237
#               function                     V06STEPST1        1364          0.1831      0.2747          0.0916                     14       0.031829
#               function                     V0620MPACE        1364          0.1726      0.2258          0.0531                     12       0.002958
#               function                     V06400MTIM        1248          0.1783      0.2285          0.0501                     12       0.698085
#                    adl                     V06LLDILST        1352          0.0243      0.0600          0.0358                     15       0.148915
#                    adl                       V06LLD6B        1381          0.0432      0.0777          0.0345                     10       0.016236
# self_reported_function       dirkn17_symptomatic_side        1386          0.0507      0.0752          0.0245                      9       0.009176
#                   pain     pain_7day_symptomatic_side        1383          0.0702      0.0928          0.0226                      9       0.045609
# self_reported_function        dirkn8_symptomatic_side        1384          0.0860      0.1077          0.0216                      8       0.015109
# self_reported_function        dirkn2_symptomatic_side        1383          0.0911      0.1122          0.0211                      9       0.016934
#                    adl                      V06LLD10B        1385          0.0514      0.0711          0.0197                     15       0.009546
# self_reported_function                     V06KOOSFX5        1212          0.0412      0.0581          0.0169                      9       0.021105
# self_reported_function       dirkn13_symptomatic_side        1149          0.0525      0.0689          0.0164                     12       0.011005
# self_reported_function        dirkn5_symptomatic_side        1341          0.0743      0.0900          0.0157                     12       0.010254
#                   pain     koos_pain_symptomatic_side        1388          0.1201      0.1354          0.0153                      8       0.336356
# self_reported_function        dirkn1_symptomatic_side        1384          0.0792      0.0943          0.0151                      7       0.013982
# self_reported_function        dirkn7_symptomatic_side        1388          0.0628      0.0765          0.0137                      9       0.014586
#                   pain global_rating_symptomatic_side        1388          0.0805      0.0942          0.0137                     12       0.028161
# self_reported_function        dirkn3_symptomatic_side        1388          0.0981      0.1118          0.0137                     16       0.006357
# self_reported_function        dirkn6_symptomatic_side        1388          0.0902      0.1030          0.0128                      7       0.012626
# self_reported_function                     V06KOOSFX1        1147          0.0517      0.0623          0.0106                      8       0.030345
# self_reported_function        dirkn9_symptomatic_side        1388          0.0595      0.0689          0.0095                      9       0.011521
# self_reported_function       dilkn10_symptomatic_side        1388          0.0283      0.0367          0.0084                      7       0.014857
# self_reported_function       dirkn15_symptomatic_side        1388          0.0446      0.0529          0.0083                     10       0.011865
#                   pain   icoap_total_symptomatic_side        1386          0.0765      0.0835          0.0069                     10       0.208561
# self_reported_function       dirkn16_symptomatic_side        1312          0.0698      0.0766          0.0069                      9       0.014794
# self_reported_function        dirkn4_symptomatic_side        1388          0.0900      0.0959          0.0059                      7       0.014973
#                   pain      pain_bed_symptomatic_side        1388          0.0434      0.0468          0.0034                      4       0.019795
#               function                      V06CSPACE        1310          0.1180      0.1195          0.0015                     11       0.002647
# self_reported_function                     V06KOOSFX2         648          0.1279      0.1237         -0.0042                      6       0.037280
# self_reported_function                     V06KOOSFX4        1144          0.0872      0.0762         -0.0110                      2       0.043348

# %% [markdown]
# ### 2.2.2. Ridge regression
#
# **Purpose**
#
# Ridge regression is the first purely predictive model in the pipeline.Unlike Stage 1 LASSO, the goal here is not feature selection or incremental explanation — it is to assess how well the full predictor set predicts each outcome on unseen data, evaluated on the held-out test set.
#
# **Why Ridge after LASSO**
#  LASSO (L1) shrinks weak coefficients to exactly zero, producing a sparse solution. Ridge (L2) shrinks all coefficients continuously toward zero but retains every predictor in the model. This means Ridge can outperform LASSO when many predictors each carry a small amount of genuine signal — a situation that is plausible here given the moderate intercorrelations among bout-structure and harmonic features. Comparing Ridge test R² against LASSO full_r2_cv gives a first indication of whether sparsity or dense shrinkage better fits the data for each outcome.
#
#  **Regularisation**
#  The regularisation strength alpha is selected via RidgeCV using 10-fold cross-validation on the training set across a log-spaced grid from 0.001 to 1000. Activity predictors are standardised on the training set; the same scaler is applied to the test set. Covariates are passed through unscaled, consistent with the convention used in Stage 1.
#
#  **Output**
#
#  ridge_results: dict mapping outcome_group_name -> list of per-outcome result dicts. Each result dict contains:
#    - outcome_column
#    - n_training, n_test
#    - cross_validated_r2 (training set, 10-fold CV)
#    - test_r2
#    - test_rmse
#    - test_mae
#    - optimal_alpha

# %%
def run_ridge_for_outcome(
    *,
    outcome_column: str,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    include_structural_covariate: bool = True,
    cross_validation_folds: int = 10,
    random_state: int = 42,
) -> dict:
    """
    Fit a Ridge regression model with cross-validated alpha selection
    for a single outcome and return held-out test set metrics.

    Activity predictors are standardised on the training set; the same
    scaler is applied to the test set without refitting. Covariates are
    passed through unscaled. Alpha is selected from a log-spaced grid
    of 25 values between 0.001 and 1000 using RidgeCV with 10-fold CV
    on the training set.

    A second cross-validation pass using the selected alpha is run on
    the full training matrix to produce a cross_validated_r2 that is
    directly comparable to the baseline_r2_cv and full_r2_cv from
    Stage 1.

    :param outcome_column: Name of the outcome variable to model.
    :param dataframe: Modelling dataframe with one row per participant.
    :param activity_predictor_columns: Activity predictor column names
        (standardised before fitting).
    :param demographic_covariate_columns: Demographic covariate column
        names (passed through unscaled).
    :param structural_covariate_column: KL grade column name.
    :param include_structural_covariate: Whether to include KL grade as
        a covariate. Always True except for Stage 6.
    :param cross_validation_folds: Number of CV folds (default 10).
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys outcome_column, n_training, n_test,
        cross_validated_r2, test_r2, test_rmse, test_mae, optimal_alpha.
    """
    covariate_columns = list(demographic_covariate_columns)
    if include_structural_covariate:
        covariate_columns.append(structural_covariate_column)

    (
        training_predictors,
        training_outcome,
        test_predictors,
        test_outcome,
    ) = prepare_modelling_dataset_for_stage(
        dataframe=dataframe,
        outcome_column=outcome_column,
        activity_predictor_columns=activity_predictor_columns,
        demographic_covariate_columns=demographic_covariate_columns,
        structural_covariate_column=structural_covariate_column,
        include_structural_covariate=include_structural_covariate,
    )

    scaler = StandardScaler()
    activity_training_scaled = scaler.fit_transform(
        training_predictors[activity_predictor_columns]
    )
    activity_test_scaled = scaler.transform(
        test_predictors[activity_predictor_columns]
    )

    full_training_matrix = np.hstack([
        training_predictors[covariate_columns].values,
        activity_training_scaled,
    ])
    full_test_matrix = np.hstack([
        test_predictors[covariate_columns].values,
        activity_test_scaled,
    ])

    # Alpha selection via RidgeCV on the training set
    ridge_model = RidgeCV(
        alphas=np.logspace(-3, 3, 25),
        cv=cross_validation_folds,
    )
    ridge_model.fit(full_training_matrix, training_outcome)

    # Cross-validated R² on the training set using the selected alpha
    cross_validation_scores = cross_val_score(
        estimator=RidgeCV(
            alphas=np.logspace(-3, 3, 25),
            cv=cross_validation_folds,
        ),
        X=full_training_matrix,
        y=training_outcome,
        cv=KFold(
            n_splits=cross_validation_folds,
            shuffle=True,
            random_state=random_state,
        ),
        scoring="r2",
    )

    test_predictions = ridge_model.predict(full_test_matrix)
    test_r2 = r2_score(test_outcome, test_predictions)
    test_rmse = float(np.sqrt(mean_squared_error(test_outcome, test_predictions)))
    test_mae = float(mean_absolute_error(test_outcome, test_predictions))

    print(
        f"\n  Cross-validated R² (train, 10-fold) : "
        f"{cross_validation_scores.mean():.4f}\n"
        f"  Test R²                             : {test_r2:.4f}\n"
        f"  Test RMSE                           : {test_rmse:.4f}\n"
        f"  Test MAE                            : {test_mae:.4f}\n"
        f"  Optimal alpha                       : {ridge_model.alpha_:.6f}"
    )

    return {
        "outcome_column": outcome_column,
        "n_training": len(training_predictors),
        "n_test": len(test_predictors),
        "cross_validated_r2": float(cross_validation_scores.mean()),
        "test_r2": test_r2,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "optimal_alpha": float(ridge_model.alpha_),
    }

# %% [markdown]
# #### Execute Ridge for all outcomes

# %%
ridge_results: dict[str, list[dict]] = {}

for group_name, outcome_columns in OUTCOME_GROUPS.items():
    print(f"\n{'=' * 70}")
    print(f"Group: {group_name}  ({len(outcome_columns)} outcomes)")
    print(f"{'=' * 70}")

    group_results = []

    for outcome_column in outcome_columns:
        print(f"\n  Outcome: {outcome_column}")
        print(f"  {'-' * 50}")

        try:
            result = run_ridge_for_outcome(
                outcome_column=outcome_column,
                dataframe=summary_metrics_06,
                activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
                demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
                structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
                include_structural_covariate=True,
                cross_validation_folds=CROSS_VALIDATION_FOLDS,
                random_state=RANDOM_STATE,
            )
            group_results.append(result)

        except ValueError as error:
            print(f"  Skipped: {error}")

    ridge_results[group_name] = group_results
# Out:
# ======================================================================
# Group: pain  (5 outcomes)
# ======================================================================
#
#   Outcome: koos_pain_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1301
#   Test R²                             : 0.1368
#   Test RMSE                           : 16.2789
#   Test MAE                            : 12.9739
#   Optimal alpha                       : 562.341325
#
#   Outcome: icoap_total_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0798
#   Test R²                             : 0.1308
#   Test RMSE                           : 12.8644
#   Test MAE                            : 9.1322
#   Optimal alpha                       : 316.227766
#
#   Outcome: pain_7day_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0890
#   Test R²                             : 0.1245
#   Test RMSE                           : 2.6022
#   Test MAE                            : 2.2005
#   Optimal alpha                       : 316.227766
#
#   Outcome: pain_bed_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0414
#   Test R²                             : 0.0674
#   Test RMSE                           : 0.8418
#   Test MAE                            : 0.5918
#   Optimal alpha                       : 1000.000000
#
#   Outcome: global_rating_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0960
#   Test R²                             : 0.0889
#   Test RMSE                           : 1.8100
#   Test MAE                            : 1.4249
#   Optimal alpha                       : 316.227766
#
# ======================================================================
# Group: function  (4 outcomes)
# ======================================================================
#
#   Outcome: V0620MPACE
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2269
#   Test R²                             : 0.3361
#   Test RMSE                           : 0.1814
#   Test MAE                            : 0.1424
#   Optimal alpha                       : 316.227766
#
#   Outcome: V06CSPACE
#   --------------------------------------------------
#   Complete cases : 1,638 of 1,845 (88.8 %)
#   Training set   : 1,310 participants
#   Test set       : 328 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1261
#   Test R²                             : 0.0729
#   Test RMSE                           : 0.1406
#   Test MAE                            : 0.1058
#   Optimal alpha                       : 1000.000000
#
#   Outcome: V06STEPST1
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2755
#   Test R²                             : 0.3350
#   Test RMSE                           : 3.5847
#   Test MAE                            : 2.6960
#   Optimal alpha                       : 177.827941
#
#   Outcome: V06400MTIM
#   --------------------------------------------------
#   Complete cases : 1,560 of 1,845 (84.6 %)
#   Training set   : 1,248 participants
#   Test set       : 312 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2345
#   Test R²                             : 0.2117
#   Test RMSE                           : 49.8131
#   Test MAE                            : 33.9983
#   Optimal alpha                       : 316.227766
#
# ======================================================================
# Group: adl  (4 outcomes)
# ======================================================================
#
#   Outcome: V06LLD6B
#   --------------------------------------------------
#   Complete cases : 1,727 of 1,845 (93.6 %)
#   Training set   : 1,381 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0773
#   Test R²                             : 0.0358
#   Test RMSE                           : 1.0566
#   Test MAE                            : 0.8926
#   Optimal alpha                       : 316.227766
#
#   Outcome: V06LLD6A
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1457
#   Test R²                             : 0.1264
#   Test RMSE                           : 1.1007
#   Test MAE                            : 0.9069
#   Optimal alpha                       : 316.227766
#
#   Outcome: V06LLDILST
#   --------------------------------------------------
#   Complete cases : 1,691 of 1,845 (91.7 %)
#   Training set   : 1,352 participants
#   Test set       : 339 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0585
#   Test R²                             : 0.0665
#   Test RMSE                           : 15.0057
#   Test MAE                            : 13.0308
#   Optimal alpha                       : 316.227766
#
#   Outcome: V06LLD10B
#   --------------------------------------------------
#   Complete cases : 1,732 of 1,845 (93.9 %)
#   Training set   : 1,385 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0708
#   Test R²                             : 0.1093
#   Test RMSE                           : 0.8823
#   Test MAE                            : 0.7375
#   Optimal alpha                       : 562.341325
#
# ======================================================================
# Group: self_reported_function  (18 outcomes)
# ======================================================================
#
#   Outcome: dirkn1_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0888
#   Test R²                             : 0.1712
#   Test RMSE                           : 0.8247
#   Test MAE                            : 0.6729
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn2_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1073
#   Test R²                             : 0.1469
#   Test RMSE                           : 0.8664
#   Test MAE                            : 0.7112
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn3_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1147
#   Test R²                             : 0.1281
#   Test RMSE                           : 0.8311
#   Test MAE                            : 0.6856
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn4_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0925
#   Test R²                             : 0.1124
#   Test RMSE                           : 0.6707
#   Test MAE                            : 0.5092
#   Optimal alpha                       : 562.341325
#
#   Outcome: dirkn5_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,677 of 1,845 (90.9 %)
#   Training set   : 1,341 participants
#   Test set       : 336 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0881
#   Test R²                             : 0.1621
#   Test RMSE                           : 0.9650
#   Test MAE                            : 0.7967
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn6_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1001
#   Test R²                             : 0.1008
#   Test RMSE                           : 0.6275
#   Test MAE                            : 0.4936
#   Optimal alpha                       : 562.341325
#
#   Outcome: dirkn7_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0784
#   Test R²                             : 0.0622
#   Test RMSE                           : 0.8052
#   Test MAE                            : 0.6669
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn8_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1066
#   Test R²                             : 0.1305
#   Test RMSE                           : 0.7630
#   Test MAE                            : 0.5596
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn9_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0684
#   Test R²                             : 0.0838
#   Test RMSE                           : 0.7104
#   Test MAE                            : 0.5312
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn13_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,437 of 1,845 (77.9 %)
#   Training set   : 1,149 participants
#   Test set       : 288 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0676
#   Test R²                             : 0.1399
#   Test RMSE                           : 0.6803
#   Test MAE                            : 0.5062
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn15_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0535
#   Test R²                             : 0.1161
#   Test RMSE                           : 0.6588
#   Test MAE                            : 0.5364
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn16_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,640 of 1,845 (88.9 %)
#   Training set   : 1,312 participants
#   Test set       : 328 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0716
#   Test R²                             : 0.0999
#   Test RMSE                           : 0.8205
#   Test MAE                            : 0.6543
#   Optimal alpha                       : 316.227766
#
#   Outcome: dirkn17_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0698
#   Test R²                             : 0.1006
#   Test RMSE                           : 0.6014
#   Test MAE                            : 0.4523
#   Optimal alpha                       : 316.227766
#
#   Outcome: dilkn10_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0360
#   Test R²                             : 0.0599
#   Test RMSE                           : 0.5955
#   Test MAE                            : 0.4598
#   Optimal alpha                       : 1000.000000
#
#   Outcome: V06KOOSFX1
#   --------------------------------------------------
#   Complete cases : 1,434 of 1,845 (77.7 %)
#   Training set   : 1,147 participants
#   Test set       : 287 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0660
#   Test R²                             : 0.1044
#   Test RMSE                           : 1.0467
#   Test MAE                            : 0.8858
#   Optimal alpha                       : 562.341325
#
#   Outcome: V06KOOSFX2
#   --------------------------------------------------
#   Complete cases : 810 of 1,845 (43.9 %)
#   Training set   : 648 participants
#   Test set       : 162 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1261
#   Test R²                             : 0.0657
#   Test RMSE                           : 1.0091
#   Test MAE                            : 0.7693
#   Optimal alpha                       : 316.227766
#
#   Outcome: V06KOOSFX4
#   --------------------------------------------------
#   Complete cases : 1,430 of 1,845 (77.5 %)
#   Training set   : 1,144 participants
#   Test set       : 286 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0805
#   Test R²                             : 0.1246
#   Test RMSE                           : 0.8874
#   Test MAE                            : 0.7196
#   Optimal alpha                       : 316.227766
#
#   Outcome: V06KOOSFX5
#   --------------------------------------------------
#   Complete cases : 1,515 of 1,845 (82.1 %)
#   Training set   : 1,212 participants
#   Test set       : 303 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0587
#   Test R²                             : 0.0898
#   Test RMSE                           : 1.0026
#   Test MAE                            : 0.8480
#   Optimal alpha                       : 562.341325

# %% [markdown]
# #### Ridge summary table

# %%
summary_rows = []

for group_name, group_results in ridge_results.items():
    for result in group_results:
        summary_rows.append({
            "group": group_name,
            "outcome": result["outcome_column"],
            "n_training": result["n_training"],
            "cv_r2_train": round(result["cross_validated_r2"], 4),
            "test_r2": round(result["test_r2"], 4),
            "test_rmse": round(result["test_rmse"], 4),
            "test_mae": round(result["test_mae"], 4),
            "optimal_alpha": round(result["optimal_alpha"], 6),
        })

ridge_summary_table = pd.DataFrame(summary_rows)

print("\nStage 2 — Ridge summary (sorted by test R²):")
print(
    ridge_summary_table
    .sort_values("test_r2", ascending=False)
    .to_string(index=False)
)
# Out:
# Stage 2 — Ridge summary (sorted by test R²):
#                  group                        outcome  n_training  cv_r2_train  test_r2  test_rmse  test_mae  optimal_alpha
#               function                     V0620MPACE        1364       0.2269   0.3361     0.1814    0.1424     316.227766
#               function                     V06STEPST1        1364       0.2755   0.3350     3.5847    2.6960     177.827941
#               function                     V06400MTIM        1248       0.2345   0.2117    49.8131   33.9983     316.227766
# self_reported_function        dirkn1_symptomatic_side        1384       0.0888   0.1712     0.8247    0.6729     316.227766
# self_reported_function        dirkn5_symptomatic_side        1341       0.0881   0.1621     0.9650    0.7967     316.227766
# self_reported_function        dirkn2_symptomatic_side        1383       0.1073   0.1469     0.8664    0.7112     316.227766
# self_reported_function       dirkn13_symptomatic_side        1149       0.0676   0.1399     0.6803    0.5062     316.227766
#                   pain     koos_pain_symptomatic_side        1388       0.1301   0.1368    16.2789   12.9739     562.341325
#                   pain   icoap_total_symptomatic_side        1386       0.0798   0.1308    12.8644    9.1322     316.227766
# self_reported_function        dirkn8_symptomatic_side        1384       0.1066   0.1305     0.7630    0.5596     316.227766
# self_reported_function        dirkn3_symptomatic_side        1388       0.1147   0.1281     0.8311    0.6856     316.227766
#                    adl                       V06LLD6A        1386       0.1457   0.1264     1.1007    0.9069     316.227766
# self_reported_function                     V06KOOSFX4        1144       0.0805   0.1246     0.8874    0.7196     316.227766
#                   pain     pain_7day_symptomatic_side        1383       0.0890   0.1245     2.6022    2.2005     316.227766
# self_reported_function       dirkn15_symptomatic_side        1388       0.0535   0.1161     0.6588    0.5364     316.227766
# self_reported_function        dirkn4_symptomatic_side        1388       0.0925   0.1124     0.6707    0.5092     562.341325
#                    adl                      V06LLD10B        1385       0.0708   0.1093     0.8823    0.7375     562.341325
# self_reported_function                     V06KOOSFX1        1147       0.0660   0.1044     1.0467    0.8858     562.341325
# self_reported_function        dirkn6_symptomatic_side        1388       0.1001   0.1008     0.6275    0.4936     562.341325
# self_reported_function       dirkn17_symptomatic_side        1386       0.0698   0.1006     0.6014    0.4523     316.227766
# self_reported_function       dirkn16_symptomatic_side        1312       0.0716   0.0999     0.8205    0.6543     316.227766
# self_reported_function                     V06KOOSFX5        1212       0.0587   0.0898     1.0026    0.8480     562.341325
#                   pain global_rating_symptomatic_side        1388       0.0960   0.0889     1.8100    1.4249     316.227766
# self_reported_function        dirkn9_symptomatic_side        1388       0.0684   0.0838     0.7104    0.5312     316.227766
#               function                      V06CSPACE        1310       0.1261   0.0729     0.1406    0.1058    1000.000000
#                   pain      pain_bed_symptomatic_side        1388       0.0414   0.0674     0.8418    0.5918    1000.000000
#                    adl                     V06LLDILST        1352       0.0585   0.0665    15.0057   13.0308     316.227766
# self_reported_function                     V06KOOSFX2         648       0.1261   0.0657     1.0091    0.7693     316.227766
# self_reported_function        dirkn7_symptomatic_side        1388       0.0784   0.0622     0.8052    0.6669     316.227766
# self_reported_function       dilkn10_symptomatic_side        1388       0.0360   0.0599     0.5955    0.4598    1000.000000
#                    adl                       V06LLD6B        1381       0.0773   0.0358     1.0566    0.8926     316.227766

# %% [markdown]
# ### 2.2.3. Elastic Net
#
# ## Purpose
#
# Elastic Net is the second predictive model in the pipeline and serves
# as the bridge between LASSO (Stage 1) and Ridge (Stage 2). It combines
# L1 and L2 regularisation in a single penalty term controlled by two
# hyperparameters: alpha (overall regularisation strength) and l1_ratio
# (the balance between L1 and L2).
#
# ## Why Elastic Net after LASSO and Ridge
#
# LASSO produces sparse solutions but struggles when predictors are
# correlated — it tends to arbitrarily select one from a correlated
# group and zero out the rest. Ridge retains all predictors but cannot
# perform selection. Elastic Net inherits the selection property of
# LASSO while using the L2 component to stabilise coefficient estimates
# across correlated predictors. Given the moderate intercorrelations
# among bout-structure and harmonic features in this predictor set,
# Elastic Net may outperform both pure L1 and pure L2 models for some
# outcomes.
#
# ## Hyperparameter tuning
#
# Both alpha and l1_ratio are tuned jointly via ElasticNetCV using
# 10-fold cross-validation on the training set. The l1_ratio grid
# covers the full spectrum from predominantly Ridge (0.1) to pure
# LASSO (1.0), with denser coverage in the sparser region:
# [0.1, 0.3, 0.5, 0.7, 0.9, 0.95, 1.0]. This allows the model to
# select pure LASSO behaviour when sparsity is optimal, or a blend
# when correlated predictors benefit from joint shrinkage.
#
# Activity predictors are standardised on the training set; the same
# scaler is applied to the test set. Covariates are passed through
# unscaled, consistent with Stages 1 and 2.
#
# ## Output
#
# elastic_net_results: dict mapping outcome_group_name -> list of
# per-outcome result dicts. Each result dict contains:
# - outcome_column
# - n_training, n_test
# - cross_validated_r2 (training set, 10-fold CV)
# - test_r2
# - test_rmse
# - test_mae
# - optimal_alpha
# - optimal_l1_ratio

# %%
def run_elastic_net_for_outcome(
    *,
    outcome_column: str,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    include_structural_covariate: bool = True,
    cross_validation_folds: int = 10,
    random_state: int = 42,
) -> dict:
    """
    Fit an Elastic Net model with jointly tuned alpha and l1_ratio for
    a single outcome and return held-out test set metrics.

    Alpha and l1_ratio are selected jointly via ElasticNetCV using
    10-fold cross-validation on the training set. The l1_ratio grid
    covers [0.1, 0.3, 0.5, 0.7, 0.9, 0.95, 1.0], allowing the model
    to select anywhere from predominantly Ridge to pure LASSO behaviour.

    Activity predictors are standardised on the training set; the same
    scaler is applied to the test set without refitting. Covariates are
    passed through unscaled, consistent with Stages 1 and 2.

    A cross-validated R² on the training set is computed after fitting
    to provide a training-set estimate directly comparable across stages.

    :param outcome_column: Name of the outcome variable to model.
    :param dataframe: Modelling dataframe with one row per participant.
    :param activity_predictor_columns: Activity predictor column names
        (standardised before fitting).
    :param demographic_covariate_columns: Demographic covariate column
        names (passed through unscaled).
    :param structural_covariate_column: KL grade column name.
    :param include_structural_covariate: Whether to include KL grade as
        a covariate. Always True except for Stage 6.
    :param cross_validation_folds: Number of CV folds (default 10).
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys outcome_column, n_training, n_test,
        cross_validated_r2, test_r2, test_rmse, test_mae,
        optimal_alpha, optimal_l1_ratio.
    """
    covariate_columns = list(demographic_covariate_columns)
    if include_structural_covariate:
        covariate_columns.append(structural_covariate_column)

    (
        training_predictors,
        training_outcome,
        test_predictors,
        test_outcome,
    ) = prepare_modelling_dataset_for_stage(
        dataframe=dataframe,
        outcome_column=outcome_column,
        activity_predictor_columns=activity_predictor_columns,
        demographic_covariate_columns=demographic_covariate_columns,
        structural_covariate_column=structural_covariate_column,
        include_structural_covariate=include_structural_covariate,
    )

    scaler = StandardScaler()
    activity_training_scaled = scaler.fit_transform(
        training_predictors[activity_predictor_columns]
    )
    activity_test_scaled = scaler.transform(
        test_predictors[activity_predictor_columns]
    )

    full_training_matrix = np.hstack([
        training_predictors[covariate_columns].values,
        activity_training_scaled,
    ])
    full_test_matrix = np.hstack([
        test_predictors[covariate_columns].values,
        activity_test_scaled,
    ])

    elastic_net_model = ElasticNetCV(
        l1_ratio=[0.1, 0.3, 0.5, 0.7, 0.9, 0.95, 1.0],
        cv=cross_validation_folds,
        random_state=random_state,
        max_iter=50_000,
    )

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        elastic_net_model.fit(full_training_matrix, training_outcome)

    cross_validation_scores = cross_val_score(
        estimator=ElasticNetCV(
            l1_ratio=[0.1, 0.3, 0.5, 0.7, 0.9, 0.95, 1.0],
            cv=cross_validation_folds,
            random_state=random_state,
            max_iter=50_000,
        ),
        X=full_training_matrix,
        y=training_outcome,
        cv=KFold(
            n_splits=cross_validation_folds,
            shuffle=True,
            random_state=random_state,
        ),
        scoring="r2",
    )

    test_predictions = elastic_net_model.predict(full_test_matrix)
    test_r2 = r2_score(test_outcome, test_predictions)
    test_rmse = float(np.sqrt(mean_squared_error(test_outcome, test_predictions)))
    test_mae = float(mean_absolute_error(test_outcome, test_predictions))

    print(
        f"\n  Cross-validated R² (train, 10-fold) : "
        f"{cross_validation_scores.mean():.4f}\n"
        f"  Test R²                             : {test_r2:.4f}\n"
        f"  Test RMSE                           : {test_rmse:.4f}\n"
        f"  Test MAE                            : {test_mae:.4f}\n"
        f"  Optimal alpha                       : "
        f"{elastic_net_model.alpha_:.6f}\n"
        f"  Optimal l1_ratio                    : "
        f"{elastic_net_model.l1_ratio_:.2f}"
    )

    return {
        "outcome_column": outcome_column,
        "n_training": len(training_predictors),
        "n_test": len(test_predictors),
        "cross_validated_r2": float(cross_validation_scores.mean()),
        "test_r2": test_r2,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "optimal_alpha": float(elastic_net_model.alpha_),
        "optimal_l1_ratio": float(elastic_net_model.l1_ratio_),
    }

# %% [markdown]
# #### Execute Elastic Net for all outcomes

# %%
elastic_net_results: dict[str, list[dict]] = {}

for group_name, outcome_columns in OUTCOME_GROUPS.items():
    print(f"\n{'=' * 70}")
    print(f"Group: {group_name}  ({len(outcome_columns)} outcomes)")
    print(f"{'=' * 70}")

    group_results = []

    for outcome_column in outcome_columns:
        print(f"\n  Outcome: {outcome_column}")
        print(f"  {'-' * 50}")

        try:
            result = run_elastic_net_for_outcome(
                outcome_column=outcome_column,
                dataframe=summary_metrics_06,
                activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
                demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
                structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
                include_structural_covariate=True,
                cross_validation_folds=CROSS_VALIDATION_FOLDS,
                random_state=RANDOM_STATE,
            )
            group_results.append(result)

        except ValueError as error:
            print(f"  Skipped: {error}")

    elastic_net_results[group_name] = group_results
# Out:
# ======================================================================
# Group: pain  (5 outcomes)
# ======================================================================
#
#   Outcome: koos_pain_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1355
#   Test R²                             : 0.1426
#   Test RMSE                           : 16.2236
#   Test MAE                            : 12.9090
#   Optimal alpha                       : 0.336356
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: icoap_total_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0782
#   Test R²                             : 0.1330
#   Test RMSE                           : 12.8485
#   Test MAE                            : 9.0903
#   Optimal alpha                       : 0.259137
#   Optimal l1_ratio                    : 0.70
#
#   Outcome: pain_7day_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0915
#   Test R²                             : 0.1315
#   Test RMSE                           : 2.5918
#   Test MAE                            : 2.1890
#   Optimal alpha                       : 0.060765
#   Optimal l1_ratio                    : 0.70
#
#   Outcome: pain_bed_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0466
#   Test R²                             : 0.0761
#   Test RMSE                           : 0.8379
#   Test MAE                            : 0.5865
#   Optimal alpha                       : 0.019795
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: global_rating_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0946
#   Test R²                             : 0.0903
#   Test RMSE                           : 1.8086
#   Test MAE                            : 1.4190
#   Optimal alpha                       : 0.081644
#   Optimal l1_ratio                    : 0.30
#
# ======================================================================
# Group: function  (4 outcomes)
# ======================================================================
#
#   Outcome: V0620MPACE
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2248
#   Test R²                             : 0.3400
#   Test RMSE                           : 0.1809
#   Test MAE                            : 0.1419
#   Optimal alpha                       : 0.029585
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: V06CSPACE
#   --------------------------------------------------
#   Complete cases : 1,638 of 1,845 (88.8 %)
#   Training set   : 1,310 participants
#   Test set       : 328 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1203
#   Test R²                             : 0.0731
#   Test RMSE                           : 0.1406
#   Test MAE                            : 0.1058
#   Optimal alpha                       : 0.026475
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: V06STEPST1
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2769
#   Test R²                             : 0.3354
#   Test RMSE                           : 3.5838
#   Test MAE                            : 2.6980
#   Optimal alpha                       : 0.080257
#   Optimal l1_ratio                    : 0.30
#
#   Outcome: V06400MTIM
#   --------------------------------------------------
#   Complete cases : 1,560 of 1,845 (84.6 %)
#   Training set   : 1,248 participants
#   Test set       : 312 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2339
#   Test R²                             : 0.2133
#   Test RMSE                           : 49.7633
#   Test MAE                            : 33.9261
#   Optimal alpha                       : 0.629154
#   Optimal l1_ratio                    : 0.90
#
# ======================================================================
# Group: adl  (4 outcomes)
# ======================================================================
#
#   Outcome: V06LLD6B
#   --------------------------------------------------
#   Complete cases : 1,727 of 1,845 (93.6 %)
#   Training set   : 1,381 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0760
#   Test R²                             : 0.0290
#   Test RMSE                           : 1.0604
#   Test MAE                            : 0.8955
#   Optimal alpha                       : 0.070282
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: V06LLD6A
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1432
#   Test R²                             : 0.1141
#   Test RMSE                           : 1.1085
#   Test MAE                            : 0.9130
#   Optimal alpha                       : 0.029891
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: V06LLDILST
#   --------------------------------------------------
#   Complete cases : 1,691 of 1,845 (91.7 %)
#   Training set   : 1,352 participants
#   Test set       : 339 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0595
#   Test R²                             : 0.0680
#   Test RMSE                           : 14.9934
#   Test MAE                            : 13.0031
#   Optimal alpha                       : 0.154310
#   Optimal l1_ratio                    : 0.90
#
#   Outcome: V06LLD10B
#   --------------------------------------------------
#   Complete cases : 1,732 of 1,845 (93.9 %)
#   Training set   : 1,385 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0703
#   Test R²                             : 0.1159
#   Test RMSE                           : 0.8790
#   Test MAE                            : 0.7335
#   Optimal alpha                       : 0.083027
#   Optimal l1_ratio                    : 0.10
#
# ======================================================================
# Group: self_reported_function  (18 outcomes)
# ======================================================================
#
#   Outcome: dirkn1_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0943
#   Test R²                             : 0.1687
#   Test RMSE                           : 0.8260
#   Test MAE                            : 0.6728
#   Optimal alpha                       : 0.013982
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: dirkn2_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1111
#   Test R²                             : 0.1521
#   Test RMSE                           : 0.8638
#   Test MAE                            : 0.7096
#   Optimal alpha                       : 0.056448
#   Optimal l1_ratio                    : 0.30
#
#   Outcome: dirkn3_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1129
#   Test R²                             : 0.1284
#   Test RMSE                           : 0.8310
#   Test MAE                            : 0.6841
#   Optimal alpha                       : 0.055286
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: dirkn4_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0967
#   Test R²                             : 0.1139
#   Test RMSE                           : 0.6702
#   Test MAE                            : 0.5070
#   Optimal alpha                       : 0.130227
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: dirkn5_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,677 of 1,845 (90.9 %)
#   Training set   : 1,341 participants
#   Test set       : 336 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0893
#   Test R²                             : 0.1682
#   Test RMSE                           : 0.9615
#   Test MAE                            : 0.7909
#   Optimal alpha                       : 0.010254
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: dirkn6_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1022
#   Test R²                             : 0.1049
#   Test RMSE                           : 0.6261
#   Test MAE                            : 0.4897
#   Optimal alpha                       : 0.012626
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: dirkn7_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0762
#   Test R²                             : 0.0605
#   Test RMSE                           : 0.8059
#   Test MAE                            : 0.6674
#   Optimal alpha                       : 0.118308
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: dirkn8_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1073
#   Test R²                             : 0.1281
#   Test RMSE                           : 0.7640
#   Test MAE                            : 0.5567
#   Optimal alpha                       : 0.043805
#   Optimal l1_ratio                    : 0.30
#
#   Outcome: dirkn9_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0689
#   Test R²                             : 0.0843
#   Test RMSE                           : 0.7102
#   Test MAE                            : 0.5293
#   Optimal alpha                       : 0.011521
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: dirkn13_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,437 of 1,845 (77.9 %)
#   Training set   : 1,149 participants
#   Test set       : 288 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0694
#   Test R²                             : 0.1391
#   Test RMSE                           : 0.6806
#   Test MAE                            : 0.5053
#   Optimal alpha                       : 0.102631
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: dirkn15_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0522
#   Test R²                             : 0.1135
#   Test RMSE                           : 0.6597
#   Test MAE                            : 0.5359
#   Optimal alpha                       : 0.039549
#   Optimal l1_ratio                    : 0.30
#
#   Outcome: dirkn16_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,640 of 1,845 (88.9 %)
#   Training set   : 1,312 participants
#   Test set       : 328 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0754
#   Test R²                             : 0.1013
#   Test RMSE                           : 0.8199
#   Test MAE                            : 0.6531
#   Optimal alpha                       : 0.029587
#   Optimal l1_ratio                    : 0.50
#
#   Outcome: dirkn17_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0752
#   Test R²                             : 0.1019
#   Test RMSE                           : 0.6010
#   Test MAE                            : 0.4519
#   Optimal alpha                       : 0.079809
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: dilkn10_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0364
#   Test R²                             : 0.0648
#   Test RMSE                           : 0.5939
#   Test MAE                            : 0.4568
#   Optimal alpha                       : 0.037463
#   Optimal l1_ratio                    : 0.30
#
#   Outcome: V06KOOSFX1
#   --------------------------------------------------
#   Complete cases : 1,434 of 1,845 (77.7 %)
#   Training set   : 1,147 participants
#   Test set       : 287 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0615
#   Test R²                             : 0.1075
#   Test RMSE                           : 1.0449
#   Test MAE                            : 0.8838
#   Optimal alpha                       : 0.186193
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: V06KOOSFX2
#   --------------------------------------------------
#   Complete cases : 810 of 1,845 (43.9 %)
#   Training set   : 648 participants
#   Test set       : 162 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1238
#   Test R²                             : 0.0598
#   Test RMSE                           : 1.0123
#   Test MAE                            : 0.7687
#   Optimal alpha                       : 0.037280
#   Optimal l1_ratio                    : 1.00
#
#   Outcome: V06KOOSFX4
#   --------------------------------------------------
#   Complete cases : 1,430 of 1,845 (77.5 %)
#   Training set   : 1,144 participants
#   Test set       : 286 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0785
#   Test R²                             : 0.1235
#   Test RMSE                           : 0.8880
#   Test MAE                            : 0.7180
#   Optimal alpha                       : 0.107377
#   Optimal l1_ratio                    : 0.10
#
#   Outcome: V06KOOSFX5
#   --------------------------------------------------
#   Complete cases : 1,515 of 1,845 (82.1 %)
#   Training set   : 1,212 participants
#   Test set       : 303 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0593
#   Test R²                             : 0.0975
#   Test RMSE                           : 0.9983
#   Test MAE                            : 0.8432
#   Optimal alpha                       : 0.159650
#   Optimal l1_ratio                    : 0.10

# %% [markdown]
# #### Elastic Net summary table

# %%
summary_rows = []

for group_name, group_results in elastic_net_results.items():
    for result in group_results:
        summary_rows.append({
            "group": group_name,
            "outcome": result["outcome_column"],
            "n_training": result["n_training"],
            "cv_r2_train": round(result["cross_validated_r2"], 4),
            "test_r2": round(result["test_r2"], 4),
            "test_rmse": round(result["test_rmse"], 4),
            "test_mae": round(result["test_mae"], 4),
            "optimal_alpha": round(result["optimal_alpha"], 6),
            "optimal_l1_ratio": round(result["optimal_l1_ratio"], 2),
        })

elastic_net_summary_table = pd.DataFrame(summary_rows)

print("\nStage 3 — Elastic Net summary (sorted by test R²):")
print(
    elastic_net_summary_table
    .sort_values("test_r2", ascending=False)
    .to_string(index=False)
)
# Out:
# Stage 3 — Elastic Net summary (sorted by test R²):
#                  group                        outcome  n_training  cv_r2_train  test_r2  test_rmse  test_mae  optimal_alpha  optimal_l1_ratio
#               function                     V0620MPACE        1364       0.2248   0.3400     0.1809    0.1419       0.029585               0.1
#               function                     V06STEPST1        1364       0.2769   0.3354     3.5838    2.6980       0.080257               0.3
#               function                     V06400MTIM        1248       0.2339   0.2133    49.7633   33.9261       0.629154               0.9
# self_reported_function        dirkn1_symptomatic_side        1384       0.0943   0.1687     0.8260    0.6728       0.013982               1.0
# self_reported_function        dirkn5_symptomatic_side        1341       0.0893   0.1682     0.9615    0.7909       0.010254               1.0
# self_reported_function        dirkn2_symptomatic_side        1383       0.1111   0.1521     0.8638    0.7096       0.056448               0.3
#                   pain     koos_pain_symptomatic_side        1388       0.1355   0.1426    16.2236   12.9090       0.336356               1.0
# self_reported_function       dirkn13_symptomatic_side        1149       0.0694   0.1391     0.6806    0.5053       0.102631               0.1
#                   pain   icoap_total_symptomatic_side        1386       0.0782   0.1330    12.8485    9.0903       0.259137               0.7
#                   pain     pain_7day_symptomatic_side        1383       0.0915   0.1315     2.5918    2.1890       0.060765               0.7
# self_reported_function        dirkn3_symptomatic_side        1388       0.1129   0.1284     0.8310    0.6841       0.055286               0.1
# self_reported_function        dirkn8_symptomatic_side        1384       0.1073   0.1281     0.7640    0.5567       0.043805               0.3
# self_reported_function                     V06KOOSFX4        1144       0.0785   0.1235     0.8880    0.7180       0.107377               0.1
#                    adl                      V06LLD10B        1385       0.0703   0.1159     0.8790    0.7335       0.083027               0.1
#                    adl                       V06LLD6A        1386       0.1432   0.1141     1.1085    0.9130       0.029891               0.1
# self_reported_function        dirkn4_symptomatic_side        1388       0.0967   0.1139     0.6702    0.5070       0.130227               0.1
# self_reported_function       dirkn15_symptomatic_side        1388       0.0522   0.1135     0.6597    0.5359       0.039549               0.3
# self_reported_function                     V06KOOSFX1        1147       0.0615   0.1075     1.0449    0.8838       0.186193               0.1
# self_reported_function        dirkn6_symptomatic_side        1388       0.1022   0.1049     0.6261    0.4897       0.012626               1.0
# self_reported_function       dirkn17_symptomatic_side        1386       0.0752   0.1019     0.6010    0.4519       0.079809               0.1
# self_reported_function       dirkn16_symptomatic_side        1312       0.0754   0.1013     0.8199    0.6531       0.029587               0.5
# self_reported_function                     V06KOOSFX5        1212       0.0593   0.0975     0.9983    0.8432       0.159650               0.1
#                   pain global_rating_symptomatic_side        1388       0.0946   0.0903     1.8086    1.4190       0.081644               0.3
# self_reported_function        dirkn9_symptomatic_side        1388       0.0689   0.0843     0.7102    0.5293       0.011521               1.0
#                   pain      pain_bed_symptomatic_side        1388       0.0466   0.0761     0.8379    0.5865       0.019795               1.0
#               function                      V06CSPACE        1310       0.1203   0.0731     0.1406    0.1058       0.026475               0.1
#                    adl                     V06LLDILST        1352       0.0595   0.0680    14.9934   13.0031       0.154310               0.9
# self_reported_function       dilkn10_symptomatic_side        1388       0.0364   0.0648     0.5939    0.4568       0.037463               0.3
# self_reported_function        dirkn7_symptomatic_side        1388       0.0762   0.0605     0.8059    0.6674       0.118308               0.1
# self_reported_function                     V06KOOSFX2         648       0.1238   0.0598     1.0123    0.7687       0.037280               1.0
#                    adl                       V06LLD6B        1381       0.0760   0.0290     1.0604    0.8955       0.070282               0.1

# %% [markdown]
# ### 2.2.4. Random Forest
#
# ## Purpose
#
# Random Forest is the first non-linear model in the pipeline. Unlike
# the three linear models in Stages 1–3, Random Forest makes no
# assumption about the functional form of the relationship between
# predictors and outcomes. It can capture interactions between
# predictors and non-linear effects that linear regularisation cannot
# represent, making it a useful benchmark for whether the activity-
# outcome relationships in this dataset are adequately described by
# linear models.
#
# ## Why Random Forest at this stage
#
# If Random Forest substantially outperforms the linear models on the
# held-out test set, this indicates that non-linear or interaction
# effects are present and that the linear models are underfitting. If
# performance is comparable, the simpler linear models are sufficient
# and preferable for interpretability. This comparison is one of the
# central methodological questions Stage 7 will answer.
#
# ## Model specification
#
# A single Random Forest regressor is fitted per outcome with the
# following fixed hyperparameters:
#
# - n_estimators = 500: enough trees for stable importance estimates
#   at this sample size without excessive computation time
# - max_depth = None: trees grow until leaves are pure or contain
#   fewer than min_samples_leaf samples, allowing the model to
#   capture deep interactions if they exist
# - min_samples_leaf = 10: minimum 10 participants per leaf node,
#   chosen to prevent overfitting on a dataset of approximately
#   1,300–1,400 training participants
# - No standardisation is applied: tree-based models are scale-
#   invariant and do not require feature scaling
#
# Hyperparameters are not grid-searched here. The fixed specification
# is a deliberate choice for a dataset of this size — grid search over
# Random Forest hyperparameters is computationally expensive and the
# chosen defaults are well-validated for n ≈ 1,000–2,000 in the
# literature.
#
# ## Feature importance
#
# Mean decrease in impurity (MDI) importance is reported for the top
# 10 predictors per outcome. M

# %%
def run_random_forest_for_outcome(
    *,
    outcome_column: str,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    include_structural_covariate: bool = True,
    number_of_trees: int = 500,
    minimum_samples_per_leaf: int = 10,
    random_state: int = 42,
) -> dict:
    """
    Fit a Random Forest regressor for a single outcome and return
    held-out test set metrics and feature importances.

    No standardisation is applied since tree-based models are scale-
    invariant. Hyperparameters are fixed rather than grid-searched:
    500 trees and a minimum of 10 samples per leaf are well-validated
    defaults for datasets of approximately 1,000–2,000 participants.

    Feature importances are mean decrease in impurity (MDI), reported
    for all predictors ranked by importance descending. MDI is biased
    toward high-cardinality continuous predictors; rankings should be
    read as indicative rather than definitive.

    :param outcome_column: Name of the outcome variable to model.
    :param dataframe: Modelling dataframe with one row per participant.
    :param activity_predictor_columns: Activity predictor column names.
    :param demographic_covariate_columns: Demographic covariate column
        names.
    :param structural_covariate_column: KL grade column name.
    :param include_structural_covariate: Whether to include KL grade as
        a covariate. Always True except for Stage 6.
    :param number_of_trees: Number of trees in the forest (default 500).
    :param minimum_samples_per_leaf: Minimum number of participants per
        leaf node (default 10).
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys outcome_column, n_training, n_test,
        test_r2, test_rmse, test_mae, feature_importances.
    """
    covariate_columns = list(demographic_covariate_columns)
    if include_structural_covariate:
        covariate_columns.append(structural_covariate_column)

    all_predictor_columns = covariate_columns + activity_predictor_columns

    (
        training_predictors,
        training_outcome,
        test_predictors,
        test_outcome,
    ) = prepare_modelling_dataset_for_stage(
        dataframe=dataframe,
        outcome_column=outcome_column,
        activity_predictor_columns=activity_predictor_columns,
        demographic_covariate_columns=demographic_covariate_columns,
        structural_covariate_column=structural_covariate_column,
        include_structural_covariate=include_structural_covariate,
    )

    training_matrix = training_predictors[all_predictor_columns].values
    test_matrix = test_predictors[all_predictor_columns].values

    random_forest_model = RandomForestRegressor(
        n_estimators=number_of_trees,
        max_depth=None,
        min_samples_leaf=minimum_samples_per_leaf,
        n_jobs=-1,
        random_state=random_state,
    )
    random_forest_model.fit(training_matrix, training_outcome)

    test_predictions = random_forest_model.predict(test_matrix)
    test_r2 = r2_score(test_outcome, test_predictions)
    test_rmse = float(np.sqrt(mean_squared_error(test_outcome, test_predictions)))
    test_mae = float(mean_absolute_error(test_outcome, test_predictions))

    feature_importances = pd.Series(
        data=random_forest_model.feature_importances_,
        index=all_predictor_columns,
        name="importance",
    ).sort_values(ascending=False)

    print(
        f"\n  Test R²   : {test_r2:.4f}\n"
        f"  Test RMSE : {test_rmse:.4f}\n"
        f"  Test MAE  : {test_mae:.4f}\n"
        f"\n  Top 10 feature importances (MDI):"
    )
    for predictor_name, importance_value in feature_importances.head(10).items():
        print(f"    {predictor_name:<45} {importance_value:.4f}")

    return {
        "outcome_column": outcome_column,
        "n_training": len(training_predictors),
        "n_test": len(test_predictors),
        "test_r2": test_r2,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "feature_importances": feature_importances,
    }

# %% [markdown]
# #### Execute Random Forest for all outcomes

# %%
random_forest_results: dict[str, list[dict]] = {}

for group_name, outcome_columns in OUTCOME_GROUPS.items():
    print(f"\n{'=' * 70}")
    print(f"Group: {group_name}  ({len(outcome_columns)} outcomes)")
    print(f"{'=' * 70}")

    group_results = []

    for outcome_column in outcome_columns:
        print(f"\n  Outcome: {outcome_column}")
        print(f"  {'-' * 50}")

        try:
            result = run_random_forest_for_outcome(
                outcome_column=outcome_column,
                dataframe=summary_metrics_06,
                activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
                demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
                structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
                include_structural_covariate=True,
                number_of_trees=500,
                minimum_samples_per_leaf=10,
                random_state=RANDOM_STATE,
            )
            group_results.append(result)

        except ValueError as error:
            print(f"  Skipped: {error}")

    random_forest_results[group_name] = group_results
# Out:
# ======================================================================
# Group: pain  (5 outcomes)
# ======================================================================
#
#   Outcome: koos_pain_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Test R²   : 0.1078
#   Test RMSE : 16.5498
#   Test MAE  : 12.9491
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1619
#     V06BMI                                        0.0951
#     wake_minute_sd                                0.0619
#     mean_sedentary_bout_total_minutes             0.0534
#     V06AGE                                        0.0415
#     mean_mvpa_bout_mean_duration                  0.0357
#     mean_mvpa_bout_count                          0.0335
#     mean_sedentary_bout_count                     0.0318
#     iv_contrast                                   0.0318
#     interdaily_stability                          0.0314
#
#   Outcome: icoap_total_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.1080
#   Test RMSE : 13.0324
#   Test MAE  : 9.2384
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1258
#     V06BMI                                        0.0856
#     wake_minute_sd                                0.0587
#     V06AGE                                        0.0558
#     mean_sedentary_bout_max_duration              0.0487
#     acrophase_mean_curve_weekday                  0.0429
#     V06COMORB                                     0.0394
#     mean_mvpa_bout_mean_duration                  0.0393
#     mean_sedentary_bout_total_minutes             0.0381
#     mean_sedentary_bout_mean_duration             0.0367
#
#   Outcome: pain_7day_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Test R²   : 0.0764
#   Test RMSE : 2.6728
#   Test MAE  : 2.2769
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1087
#     V06BMI                                        0.0900
#     mean_mvpa_bout_mean_duration                  0.0619
#     mean_sedentary_bout_total_minutes             0.0573
#     wake_minute_sd                                0.0530
#     wear_duration_mean                            0.0399
#     interdaily_stability                          0.0389
#     wake_minute_mean                              0.0348
#     acrophase_mean_curve_weekend                  0.0332
#     acrophase_mean_curve_weekday                  0.0314
#
#   Outcome: pain_bed_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Test R²   : 0.0755
#   Test RMSE : 0.8381
#   Test MAE  : 0.5829
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.0835
#     V06BMI                                        0.0835
#     wake_minute_sd                                0.0569
#     mean_sedentary_bout_total_minutes             0.0555
#     iv_contrast                                   0.0446
#     wear_duration_mean                            0.0402
#     mean_sedentary_bout_mean_duration             0.0396
#     wake_minute_mean                              0.0394
#     mean_sedentary_bout_count                     0.0389
#     mean_mvpa_bout_mean_duration                  0.0381
#
#   Outcome: global_rating_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Test R²   : 0.0457
#   Test RMSE : 1.8524
#   Test MAE  : 1.4415
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.0902
#     kl_grade_index_knee                           0.0870
#     mean_mvpa_bout_mean_duration                  0.0652
#     wake_minute_sd                                0.0523
#     mean_sedentary_bout_total_minutes             0.0451
#     wake_minute_mean                              0.0379
#     acrophase_mean_curve_weekend                  0.0357
#     interdaily_stability                          0.0350
#     wear_duration_mean                            0.0345
#     mean_sedentary_bout_max_duration              0.0339
#
# ======================================================================
# Group: function  (4 outcomes)
# ======================================================================
#
#   Outcome: V0620MPACE
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Test R²   : 0.3468
#   Test RMSE : 0.1799
#   Test MAE  : 0.1403
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_count                          0.2089
#     mean_mvpa_bout_mean_duration                  0.1820
#     V06BMI                                        0.0536
#     mesor_mean_curve_weekday                      0.0452
#     mesor_mean_curve_weekend                      0.0431
#     V06AGE                                        0.0390
#     interdaily_stability                          0.0283
#     iv_weekday                                    0.0278
#     amplitude_mean_curve_weekend                  0.0242
#     mean_active_bout_mean_duration                0.0223
#
#   Outcome: V06CSPACE
#   --------------------------------------------------
#   Complete cases : 1,638 of 1,845 (88.8 %)
#   Training set   : 1,310 participants
#   Test set       : 328 participants
#
#   Test R²   : 0.0346
#   Test RMSE : 0.1435
#   Test MAE  : 0.1066
#
#   Top 10 feature importances (MDI):
#     V06AGE                                        0.1312
#     V06BMI                                        0.0975
#     mean_mvpa_bout_mean_duration                  0.0778
#     mean_mvpa_bout_count                          0.0635
#     mesor_mean_curve_weekend                      0.0500
#     interdaily_stability                          0.0356
#     iv_weekday                                    0.0333
#     mean_active_bout_max_duration                 0.0318
#     wake_minute_sd                                0.0312
#     iv_contrast                                   0.0307
#
#   Outcome: V06STEPST1
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Test R²   : 0.3762
#   Test RMSE : 3.4720
#   Test MAE  : 2.5892
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_count                          0.4220
#     mesor_mean_curve_weekend                      0.0435
#     mean_mvpa_bout_mean_duration                  0.0430
#     V06AGE                                        0.0400
#     V06BMI                                        0.0343
#     mean_sedentary_bout_mean_duration             0.0307
#     mesor_mean_curve_weekday                      0.0296
#     mean_sedentary_bout_total_minutes             0.0269
#     mean_active_bout_mean_duration                0.0264
#     iv_weekday                                    0.0242
#
#   Outcome: V06400MTIM
#   --------------------------------------------------
#   Complete cases : 1,560 of 1,845 (84.6 %)
#   Training set   : 1,248 participants
#   Test set       : 312 participants
#
#   Test R²   : 0.2465
#   Test RMSE : 48.7012
#   Test MAE  : 33.3090
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_count                          0.2588
#     mean_mvpa_bout_mean_duration                  0.1463
#     V06BMI                                        0.0497
#     V06AGE                                        0.0465
#     mesor_mean_curve_weekday                      0.0414
#     mesor_mean_curve_weekend                      0.0395
#     amplitude_mean_curve_weekday                  0.0319
#     iv_weekday                                    0.0272
#     amplitude_mean_curve_weekend                  0.0251
#     acrophase_mean_curve_weekend                  0.0236
#
# ======================================================================
# Group: adl  (4 outcomes)
# ======================================================================
#
#   Outcome: V06LLD6B
#   --------------------------------------------------
#   Complete cases : 1,727 of 1,845 (93.6 %)
#   Training set   : 1,381 participants
#   Test set       : 346 participants
#
#   Test R²   : 0.0552
#   Test RMSE : 1.0460
#   Test MAE  : 0.8834
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_mean_duration                  0.1107
#     mean_active_bout_max_duration                 0.0557
#     V06BMI                                        0.0501
#     iv_weekday                                    0.0468
#     wake_minute_sd                                0.0423
#     acrophase_mean_curve_weekend                  0.0395
#     mean_mvpa_bout_count                          0.0362
#     amplitude_mean_curve_weekend                  0.0359
#     iv_weekend                                    0.0351
#     wake_minute_mean                              0.0334
#
#   Outcome: V06LLD6A
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.1330
#   Test RMSE : 1.0966
#   Test MAE  : 0.8992
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_mean_duration                  0.2222
#     V06BMI                                        0.0466
#     amplitude_mean_curve_weekday                  0.0438
#     mean_active_bout_max_duration                 0.0417
#     mesor_mean_curve_weekday                      0.0400
#     iv_weekday                                    0.0396
#     interdaily_stability                          0.0362
#     wake_minute_sd                                0.0348
#     mean_sedentary_bout_total_minutes             0.0336
#     mean_sedentary_bout_count                     0.0324
#
#   Outcome: V06LLDILST
#   --------------------------------------------------
#   Complete cases : 1,691 of 1,845 (91.7 %)
#   Training set   : 1,352 participants
#   Test set       : 339 participants
#
#   Test R²   : 0.0534
#   Test RMSE : 15.1105
#   Test MAE  : 13.0489
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_count                          0.0688
#     mean_mvpa_bout_mean_duration                  0.0589
#     wake_minute_sd                                0.0576
#     iv_weekday                                    0.0522
#     wake_minute_mean                              0.0501
#     mean_sedentary_bout_count                     0.0480
#     V06BMI                                        0.0467
#     mean_sedentary_bout_max_duration              0.0363
#     acrophase_mean_curve_weekend                  0.0354
#     acrophase                                     0.0341
#
#   Outcome: V06LLD10B
#   --------------------------------------------------
#   Complete cases : 1,732 of 1,845 (93.9 %)
#   Training set   : 1,385 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.0887
#   Test RMSE : 0.8925
#   Test MAE  : 0.7418
#
#   Top 10 feature importances (MDI):
#     mean_mvpa_bout_mean_duration                  0.0806
#     V06BMI                                        0.0679
#     V06AGE                                        0.0559
#     V06COMORB                                     0.0464
#     mean_active_bout_max_duration                 0.0440
#     mean_mvpa_bout_count                          0.0432
#     iv_weekday                                    0.0431
#     wake_minute_sd                                0.0422
#     interdaily_stability                          0.0394
#     mean_sedentary_bout_max_duration              0.0374
#
# ======================================================================
# Group: self_reported_function  (18 outcomes)
# ======================================================================
#
#   Outcome: dirkn1_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Test R²   : 0.1357
#   Test RMSE : 0.8422
#   Test MAE  : 0.6982
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1182
#     V06BMI                                        0.0898
#     mean_mvpa_bout_mean_duration                  0.0691
#     wake_minute_sd                                0.0589
#     amplitude_mean_curve_weekday                  0.0392
#     mean_mvpa_bout_count                          0.0386
#     wake_minute_mean                              0.0368
#     wear_duration_mean                            0.0361
#     iv_contrast                                   0.0355
#     mean_sedentary_bout_total_minutes             0.0335
#
#   Outcome: dirkn2_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Test R²   : 0.1193
#   Test RMSE : 0.8803
#   Test MAE  : 0.7246
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.1338
#     kl_grade_index_knee                           0.0916
#     mean_mvpa_bout_mean_duration                  0.0648
#     wake_minute_sd                                0.0549
#     wake_minute_mean                              0.0401
#     interdaily_stability                          0.0381
#     wear_duration_mean                            0.0350
#     mean_sedentary_bout_total_minutes             0.0340
#     acrophase_mean_curve_weekend                  0.0333
#     iv_contrast                                   0.0323
#
#   Outcome: dirkn3_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Test R²   : 0.0872
#   Test RMSE : 0.8504
#   Test MAE  : 0.7083
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1065
#     mean_mvpa_bout_mean_duration                  0.0883
#     V06BMI                                        0.0799
#     wake_minute_sd                                0.0538
#     mean_sedentary_bout_total_minutes             0.0426
#     mean_mvpa_bout_count                          0.0401
#     mean_sedentary_bout_mean_duration             0.0344
#     wear_duration_mean                            0.0337
#     V06COMORB                                     0.0323
#     iv_weekend                                    0.0318
#
#   Outcome: dirkn4_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Test R²   : 0.0775
#   Test RMSE : 0.6838
#   Test MAE  : 0.5050
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1230
#     V06BMI                                        0.1217
#     mean_sedentary_bout_total_minutes             0.0580
#     mean_mvpa_bout_mean_duration                  0.0505
#     wake_minute_sd                                0.0486
#     V06AGE                                        0.0379
#     iv_weekend                                    0.0335
#     wear_duration_mean                            0.0330
#     iv_weekday                                    0.0300
#     mean_sedentary_bout_mean_duration             0.0299
#
#   Outcome: dirkn5_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,677 of 1,845 (90.9 %)
#   Training set   : 1,341 participants
#   Test set       : 336 participants
#
#   Test R²   : 0.0934
#   Test RMSE : 1.0038
#   Test MAE  : 0.8274
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.1045
#     kl_grade_index_knee                           0.0887
#     mean_sedentary_bout_total_minutes             0.0451
#     mean_sedentary_bout_max_duration              0.0423
#     acrophase                                     0.0423
#     mean_mvpa_bout_mean_duration                  0.0414
#     mean_sedentary_bout_mean_duration             0.0397
#     wake_minute_mean                              0.0394
#     wake_minute_sd                                0.0370
#     wear_duration_mean                            0.0367
#
#   Outcome: dirkn6_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Test R²   : 0.0925
#   Test RMSE : 0.6304
#   Test MAE  : 0.4829
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1451
#     V06BMI                                        0.0841
#     mean_sedentary_bout_total_minutes             0.0648
#     V06AGE                                        0.0466
#     mean_mvpa_bout_mean_duration                  0.0448
#     wake_minute_sd                                0.0448
#     wake_minute_mean                              0.0364
#     mean_mvpa_bout_count                          0.0335
#     V06COMORB                                     0.0332
#     interdaily_stability                          0.0317
#
#   Outcome: dirkn7_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.0310
#   Test RMSE : 0.8184
#   Test MAE  : 0.6836
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.0930
#     wake_minute_sd                                0.0890
#     kl_grade_index_knee                           0.0882
#     mean_mvpa_bout_mean_duration                  0.0603
#     wake_minute_mean                              0.0384
#     mean_sedentary_bout_mean_duration             0.0357
#     mean_mvpa_bout_count                          0.0342
#     iv_weekend                                    0.0327
#     mean_sedentary_bout_total_minutes             0.0325
#     interdaily_stability                          0.0319
#
#   Outcome: dirkn8_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Test R²   : 0.1197
#   Test RMSE : 0.7677
#   Test MAE  : 0.5542
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1264
#     mean_mvpa_bout_mean_duration                  0.0960
#     V06BMI                                        0.0496
#     mean_sedentary_bout_total_minutes             0.0460
#     wake_minute_sd                                0.0456
#     V06COMORB                                     0.0440
#     V06AGE                                        0.0409
#     iv_weekday                                    0.0406
#     wake_minute_mean                              0.0402
#     mean_sedentary_bout_mean_duration             0.0373
#
#   Outcome: dirkn9_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.0761
#   Test RMSE : 0.7133
#   Test MAE  : 0.5325
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1096
#     V06BMI                                        0.0849
#     wake_minute_sd                                0.0589
#     mean_mvpa_bout_count                          0.0552
#     mean_mvpa_bout_mean_duration                  0.0412
#     mean_sedentary_bout_mean_duration             0.0408
#     mean_sedentary_bout_total_minutes             0.0385
#     V06COMORB                                     0.0368
#     iv_contrast                                   0.0368
#     iv_weekend                                    0.0341
#
#   Outcome: dirkn13_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,437 of 1,845 (77.9 %)
#   Training set   : 1,149 participants
#   Test set       : 288 participants
#
#   Test R²   : 0.0961
#   Test RMSE : 0.6974
#   Test MAE  : 0.5102
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.0926
#     wake_minute_mean                              0.0789
#     wake_minute_sd                                0.0739
#     mean_mvpa_bout_mean_duration                  0.0652
#     wear_duration_mean                            0.0513
#     kl_grade_index_knee                           0.0485
#     mean_sedentary_bout_total_minutes             0.0466
#     mean_sedentary_bout_mean_duration             0.0434
#     V06COMORB                                     0.0413
#     acrophase_mean_curve_weekend                  0.0338
#
#   Outcome: dirkn15_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.0793
#   Test RMSE : 0.6723
#   Test MAE  : 0.5442
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1025
#     V06BMI                                        0.0751
#     wake_minute_sd                                0.0694
#     mean_mvpa_bout_mean_duration                  0.0506
#     mean_sedentary_bout_mean_duration             0.0428
#     wear_duration_mean                            0.0414
#     interdaily_stability                          0.0394
#     iv_contrast                                   0.0365
#     mean_sedentary_bout_total_minutes             0.0346
#     acrophase_mean_curve_weekend                  0.0320
#
#   Outcome: dirkn16_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,640 of 1,845 (88.9 %)
#   Training set   : 1,312 participants
#   Test set       : 328 participants
#
#   Test R²   : 0.0861
#   Test RMSE : 0.8268
#   Test MAE  : 0.6663
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.0857
#     V06BMI                                        0.0855
#     wake_minute_sd                                0.0662
#     wake_minute_mean                              0.0619
#     V06COMORB                                     0.0576
#     interdaily_stability                          0.0418
#     wear_duration_mean                            0.0413
#     V06AGE                                        0.0403
#     mean_mvpa_bout_mean_duration                  0.0395
#     acrophase                                     0.0340
#
#   Outcome: dirkn17_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.0557
#   Test RMSE : 0.6163
#   Test MAE  : 0.4481
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.0916
#     wake_minute_sd                                0.0879
#     mean_mvpa_bout_mean_duration                  0.0837
#     V06BMI                                        0.0581
#     wake_minute_mean                              0.0456
#     mean_sedentary_bout_total_minutes             0.0441
#     iv_weekday                                    0.0404
#     wear_duration_mean                            0.0404
#     V06COMORB                                     0.0379
#     iv_contrast                                   0.0370
#
#   Outcome: dilkn10_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Test R²   : 0.0562
#   Test RMSE : 0.5966
#   Test MAE  : 0.4594
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.0941
#     wake_minute_sd                                0.0641
#     mean_sedentary_bout_total_minutes             0.0601
#     wake_minute_mean                              0.0509
#     acrophase_mean_curve_weekend                  0.0409
#     mean_mvpa_bout_mean_duration                  0.0403
#     V06COMORB                                     0.0391
#     kl_grade_index_knee                           0.0380
#     interdaily_stability                          0.0374
#     V06AGE                                        0.0370
#
#   Outcome: V06KOOSFX1
#   --------------------------------------------------
#   Complete cases : 1,434 of 1,845 (77.7 %)
#   Training set   : 1,147 participants
#   Test set       : 287 participants
#
#   Test R²   : 0.0615
#   Test RMSE : 1.0715
#   Test MAE  : 0.9080
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.0863
#     kl_grade_index_knee                           0.0676
#     wake_minute_sd                                0.0560
#     mean_mvpa_bout_mean_duration                  0.0552
#     mean_sedentary_bout_mean_duration             0.0428
#     wake_minute_mean                              0.0409
#     wear_duration_mean                            0.0401
#     acrophase_mean_curve_weekend                  0.0394
#     V06AGE                                        0.0375
#     interdaily_stability                          0.0354
#
#   Outcome: V06KOOSFX2
#   --------------------------------------------------
#   Complete cases : 810 of 1,845 (43.9 %)
#   Training set   : 648 participants
#   Test set       : 162 participants
#
#   Test R²   : 0.0553
#   Test RMSE : 1.0147
#   Test MAE  : 0.7777
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.2749
#     V06BMI                                        0.0886
#     iv_weekend                                    0.0524
#     acrophase                                     0.0431
#     mean_light_bout_max_duration                  0.0344
#     iv_contrast                                   0.0339
#     wake_minute_sd                                0.0326
#     V06AGE                                        0.0324
#     mean_sedentary_bout_max_duration              0.0320
#     wake_minute_mean                              0.0317
#
#   Outcome: V06KOOSFX4
#   --------------------------------------------------
#   Complete cases : 1,430 of 1,845 (77.5 %)
#   Training set   : 1,144 participants
#   Test set       : 286 participants
#
#   Test R²   : 0.0997
#   Test RMSE : 0.9000
#   Test MAE  : 0.7390
#
#   Top 10 feature importances (MDI):
#     kl_grade_index_knee                           0.1749
#     V06BMI                                        0.0706
#     wake_minute_sd                                0.0493
#     V06AGE                                        0.0424
#     mean_mvpa_bout_mean_duration                  0.0404
#     acrophase                                     0.0401
#     acrophase_mean_curve_weekday                  0.0374
#     mean_sedentary_bout_mean_duration             0.0348
#     mean_sedentary_bout_max_duration              0.0341
#     wake_minute_mean                              0.0334
#
#   Outcome: V06KOOSFX5
#   --------------------------------------------------
#   Complete cases : 1,515 of 1,845 (82.1 %)
#   Training set   : 1,212 participants
#   Test set       : 303 participants
#
#   Test R²   : 0.0322
#   Test RMSE : 1.0338
#   Test MAE  : 0.8754
#
#   Top 10 feature importances (MDI):
#     V06BMI                                        0.0876
#     mean_mvpa_bout_mean_duration                  0.0629
#     V06AGE                                        0.0460
#     mean_sedentary_bout_max_duration              0.0443
#     mean_sedentary_bout_total_minutes             0.0442
#     mean_sedentary_bout_count                     0.0433
#     wear_duration_mean                            0.0423
#     iv_weekday                                    0.0407
#     kl_grade_index_knee                           0.0373
#     amplitude_mean_curve_weekday                  0.0363

# %% [markdown]
# #### Random Forest summary table

# %%
summary_rows = []

for group_name, group_results in random_forest_results.items():
    for result in group_results:
        summary_rows.append({
            "group": group_name,
            "outcome": result["outcome_column"],
            "n_training": result["n_training"],
            "test_r2": round(result["test_r2"], 4),
            "test_rmse": round(result["test_rmse"], 4),
            "test_mae": round(result["test_mae"], 4),
        })

random_forest_summary_table = pd.DataFrame(summary_rows)

print("\nStage 4 — Random Forest summary (sorted by test R²):")
print(
    random_forest_summary_table
    .sort_values("test_r2", ascending=False)
    .to_string(index=False)
)
# Out:
# Stage 4 — Random Forest summary (sorted by test R²):
#                  group                        outcome  n_training  test_r2  test_rmse  test_mae
#               function                     V06STEPST1        1364   0.3762     3.4720    2.5892
#               function                     V0620MPACE        1364   0.3468     0.1799    0.1403
#               function                     V06400MTIM        1248   0.2465    48.7012   33.3090
# self_reported_function        dirkn1_symptomatic_side        1384   0.1357     0.8422    0.6982
#                    adl                       V06LLD6A        1386   0.1330     1.0966    0.8992
# self_reported_function        dirkn8_symptomatic_side        1384   0.1197     0.7677    0.5542
# self_reported_function        dirkn2_symptomatic_side        1383   0.1193     0.8803    0.7246
#                   pain   icoap_total_symptomatic_side        1386   0.1080    13.0324    9.2384
#                   pain     koos_pain_symptomatic_side        1388   0.1078    16.5498   12.9491
# self_reported_function                     V06KOOSFX4        1144   0.0997     0.9000    0.7390
# self_reported_function       dirkn13_symptomatic_side        1149   0.0961     0.6974    0.5102
# self_reported_function        dirkn5_symptomatic_side        1341   0.0934     1.0038    0.8274
# self_reported_function        dirkn6_symptomatic_side        1388   0.0925     0.6304    0.4829
#                    adl                      V06LLD10B        1385   0.0887     0.8925    0.7418
# self_reported_function        dirkn3_symptomatic_side        1388   0.0872     0.8504    0.7083
# self_reported_function       dirkn16_symptomatic_side        1312   0.0861     0.8268    0.6663
# self_reported_function       dirkn15_symptomatic_side        1388   0.0793     0.6723    0.5442
# self_reported_function        dirkn4_symptomatic_side        1388   0.0775     0.6838    0.5050
#                   pain     pain_7day_symptomatic_side        1383   0.0764     2.6728    2.2769
# self_reported_function        dirkn9_symptomatic_side        1388   0.0761     0.7133    0.5325
#                   pain      pain_bed_symptomatic_side        1388   0.0755     0.8381    0.5829
# self_reported_function                     V06KOOSFX1        1147   0.0615     1.0715    0.9080
# self_reported_function       dilkn10_symptomatic_side        1388   0.0562     0.5966    0.4594
# self_reported_function       dirkn17_symptomatic_side        1386   0.0557     0.6163    0.4481
# self_reported_function                     V06KOOSFX2         648   0.0553     1.0147    0.7777
#                    adl                       V06LLD6B        1381   0.0552     1.0460    0.8834
#                    adl                     V06LLDILST        1352   0.0534    15.1105   13.0489
#                   pain global_rating_symptomatic_side        1388   0.0457     1.8524    1.4415
#               function                      V06CSPACE        1310   0.0346     0.1435    0.1066
# self_reported_function                     V06KOOSFX5        1212   0.0322     1.0338    0.8754
# self_reported_function        dirkn7_symptomatic_side        1388   0.0310     0.8184    0.6836

# %% [markdown]
# ### 2.2.5. XGBoost
#
# ## Purpose
#
# XGBoost is the final and most flexible model in the pipeline. It fits
# an ensemble of gradient-boosted decision trees sequentially, where
# each tree corrects the residual errors of the previous ensemble.
# Compared to Random Forest (Stage 4), which builds trees independently
# in parallel, XGBoost uses a more targeted learning process that often
# achieves higher predictive accuracy at the cost of additional
# hyperparameters requiring tuning.
#
# ## Why XGBoost after Random Forest
#
# Random Forest established whether non-linear effects are present.
# XGBoost answers whether those non-linear effects can be exploited
# more efficiently with a sequential boosting strategy. If XGBoost
# substantially outperforms Random Forest, the outcome-predictor
# relationships contain structured residual patterns that boosting
# can exploit. If performance is comparable, Random Forest's simpler
# parallel averaging is sufficient.
#
# ## Hyperparameter tuning
#
# A focused grid search is performed over two hyperparameters:
#
# - max_depth: [3, 4, 6] — controls tree complexity and the depth
#   of interactions captured. Shallow trees (3) produce smoother,
#   more regularised fits; deeper trees (6) can capture higher-order
#   interactions at the risk of overfitting.
# - learning_rate: [0.03, 0.05, 0.1] — controls the contribution
#   of each tree to the ensemble. Lower rates require more trees but
#   generalise better.
#
# All other hyperparameters are fixed:
# - n_estimators = 500: sufficient trees for convergence at the
#   learning rates used
# - subsample = 0.8: each tree is fitted on 80% of the training
#   data, reducing variance
# - colsample_bytree = 0.8: each tree uses 80% of predictors,
#   further reducing variance and computation time
#
# Grid search uses 10-fold cross-validation on the training set with
# R² as the scoring metric, yielding 9 configurations × 10 folds =
# 90 fits per outcome. No standardisation is applied since tree-based
# models are scale-invariant.
#
# ## Feature importance
#
# Gain-based feature importance is reported for the top 10 predictors
# per outcome. Gain measures the average improvement in the loss
# function brought by a feature across all splits where it is used,
# making it more informative than the frequency-based importance used
# in Random Forest.
#
# ## Output
#
# xgboost_results: dict mapping outcome_group_name -> list of
# per-outcome result dicts. Each result dict contains:
# - outcome_column
# - n_training, n_test
# - cross_validated_r2 (training set, best CV score from grid search)
# - test_r2
# - test_rmse
# - test_mae
# - best_hyperparameters
# - feature_importances (Series, all predictors ranked by gain)

# %%
def run_xgboost_for_outcome(
    *,
    outcome_column: str,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    include_structural_covariate: bool = True,
    cross_validation_folds: int = 10,
    random_state: int = 42,
) -> dict:
    """
    Fit an XGBoost gradient-boosted regressor with grid-searched
    hyperparameters for a single outcome and return held-out test
    set metrics and feature importances.

    A focused grid search over max_depth [3, 4, 6] and learning_rate
    [0.03, 0.05, 0.1] is performed using 10-fold cross-validation on
    the training set. All other hyperparameters are fixed: 500 trees,
    subsample 0.8, colsample_bytree 0.8.

    No standardisation is applied since tree-based models are scale-
    invariant. Feature importances are gain-based, measuring the
    average loss improvement per split where each feature is used.

    :param outcome_column: Name of the outcome variable to model.
    :param dataframe: Modelling dataframe with one row per participant.
    :param activity_predictor_columns: Activity predictor column names.
    :param demographic_covariate_columns: Demographic covariate column
        names.
    :param structural_covariate_column: KL grade column name.
    :param include_structural_covariate: Whether to include KL grade as
        a covariate. Always True except for Stage 6.
    :param cross_validation_folds: Number of CV folds (default 10).
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys outcome_column, n_training, n_test,
        cross_validated_r2, test_r2, test_rmse, test_mae,
        best_hyperparameters, feature_importances.
    """
    covariate_columns = list(demographic_covariate_columns)
    if include_structural_covariate:
        covariate_columns.append(structural_covariate_column)

    all_predictor_columns = covariate_columns + activity_predictor_columns

    (
        training_predictors,
        training_outcome,
        test_predictors,
        test_outcome,
    ) = prepare_modelling_dataset_for_stage(
        dataframe=dataframe,
        outcome_column=outcome_column,
        activity_predictor_columns=activity_predictor_columns,
        demographic_covariate_columns=demographic_covariate_columns,
        structural_covariate_column=structural_covariate_column,
        include_structural_covariate=include_structural_covariate,
    )

    training_matrix = training_predictors[all_predictor_columns].values
    test_matrix = test_predictors[all_predictor_columns].values

    hyperparameter_grid = {
        "max_depth": [3, 4, 6],
        "learning_rate": [0.03, 0.05, 0.1],
    }

    grid_search = GridSearchCV(
        estimator=xgboost.XGBRegressor(
            n_estimators=500,
            subsample=0.8,
            colsample_bytree=0.8,
            objective="reg:squarederror",
            random_state=random_state,
            n_jobs=-1,
            verbosity=0,
        ),
        param_grid=hyperparameter_grid,
        cv=KFold(
            n_splits=cross_validation_folds,
            shuffle=True,
            random_state=random_state,
        ),
        scoring="r2",
        n_jobs=-1,
    )
    grid_search.fit(training_matrix, training_outcome)

    best_model = grid_search.best_estimator_
    test_predictions = best_model.predict(test_matrix)
    test_r2 = r2_score(test_outcome, test_predictions)
    test_rmse = float(np.sqrt(mean_squared_error(test_outcome, test_predictions)))
    test_mae = float(mean_absolute_error(test_outcome, test_predictions))

    feature_importances = pd.Series(
        data=best_model.feature_importances_,
        index=all_predictor_columns,
        name="importance",
    ).sort_values(ascending=False)

    print(
        f"\n  Cross-validated R² (train, 10-fold) : "
        f"{grid_search.best_score_:.4f}\n"
        f"  Test R²                             : {test_r2:.4f}\n"
        f"  Test RMSE                           : {test_rmse:.4f}\n"
        f"  Test MAE                            : {test_mae:.4f}\n"
        f"  Best hyperparameters                : "
        f"{grid_search.best_params_}\n"
        f"\n  Top 10 feature importances (gain):"
    )
    for predictor_name, importance_value in feature_importances.head(10).items():
        print(f"    {predictor_name:<45} {importance_value:.4f}")

    return {
        "outcome_column": outcome_column,
        "n_training": len(training_predictors),
        "n_test": len(test_predictors),
        "cross_validated_r2": float(grid_search.best_score_),
        "test_r2": test_r2,
        "test_rmse": test_rmse,
        "test_mae": test_mae,
        "best_hyperparameters": grid_search.best_params_,
        "feature_importances": feature_importances,
    }

# %% [markdown]
# #### Execute XGBoost for all outcomes

# %%
xgboost_results: dict[str, list[dict]] = {}

for group_name, outcome_columns in OUTCOME_GROUPS.items():
    print(f"\n{'=' * 70}")
    print(f"Group: {group_name}  ({len(outcome_columns)} outcomes)")
    print(f"{'=' * 70}")

    group_results = []

    for outcome_column in outcome_columns:
        print(f"\n  Outcome: {outcome_column}")
        print(f"  {'-' * 50}")

        try:
            result = run_xgboost_for_outcome(
                outcome_column=outcome_column,
                dataframe=summary_metrics_06,
                activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
                demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
                structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
                include_structural_covariate=True,
                cross_validation_folds=CROSS_VALIDATION_FOLDS,
                random_state=RANDOM_STATE,
            )
            group_results.append(result)

        except ValueError as error:
            print(f"  Skipped: {error}")

    xgboost_results[group_name] = group_results
# Out:
# ======================================================================
# Group: pain  (5 outcomes)
# ======================================================================
#
#   Outcome: koos_pain_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0643
#   Test R²                             : 0.1061
#   Test RMSE                           : 16.5655
#   Test MAE                            : 12.8742
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0987
#     V06COMORB                                     0.0499
#     V06BMI                                        0.0431
#     mean_mvpa_bout_count                          0.0426
#     wake_minute_sd                                0.0414
#     mean_sedentary_bout_total_minutes             0.0409
#     mean_mvpa_bout_mean_duration                  0.0404
#     V06AGE                                        0.0369
#     amplitude_mean_curve_weekday                  0.0351
#     acrophase                                     0.0347
#
#   Outcome: icoap_total_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0117
#   Test R²                             : 0.1005
#   Test RMSE                           : 13.0872
#   Test MAE                            : 9.4192
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0786
#     V06COMORB                                     0.0617
#     iv_weekend                                    0.0402
#     acrophase_mean_curve_weekday                  0.0400
#     mean_sedentary_bout_total_minutes             0.0383
#     mean_sedentary_bout_max_duration              0.0382
#     V06AGE                                        0.0372
#     wake_minute_sd                                0.0370
#     V06BMI                                        0.0350
#     mean_active_bout_mean_duration                0.0341
#
#   Outcome: pain_7day_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0467
#   Test R²                             : 0.0676
#   Test RMSE                           : 2.6855
#   Test MAE                            : 2.2511
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0888
#     V06BMI                                        0.0463
#     mean_mvpa_bout_mean_duration                  0.0461
#     mean_sedentary_bout_total_minutes             0.0444
#     V06COMORB                                     0.0363
#     wake_minute_sd                                0.0361
#     wear_duration_mean                            0.0351
#     mean_mvpa_bout_count                          0.0346
#     amplitude_mean_curve_weekend                  0.0344
#     acrophase_mean_curve_weekday                  0.0331
#
#   Outcome: pain_bed_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0526
#   Test R²                             : 0.0642
#   Test RMSE                           : 0.8432
#   Test MAE                            : 0.5683
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0602
#     mean_sedentary_bout_total_minutes             0.0452
#     mesor_mean_curve_weekend                      0.0416
#     wake_minute_sd                                0.0411
#     mean_mvpa_bout_mean_duration                  0.0395
#     employment_working                            0.0379
#     V06BMI                                        0.0368
#     mean_active_bout_max_duration                 0.0367
#     interdaily_stability                          0.0366
#     mean_mvpa_bout_count                          0.0363
#
#   Outcome: global_rating_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0021
#   Test R²                             : -0.0122
#   Test RMSE                           : 1.9078
#   Test MAE                            : 1.4653
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 6}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0626
#     mean_mvpa_bout_mean_duration                  0.0453
#     amplitude_mean_curve_weekend                  0.0430
#     mean_sedentary_bout_total_minutes             0.0429
#     iv_weekend                                    0.0423
#     acrophase_mean_curve_weekend                  0.0394
#     V06COMORB                                     0.0387
#     mean_light_bout_max_duration                  0.0375
#     acrophase_mean_curve_weekday                  0.0375
#     mean_mvpa_bout_count                          0.0368
#
# ======================================================================
# Group: function  (4 outcomes)
# ======================================================================
#
#   Outcome: V0620MPACE
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Cross-validated R² (train, 10-fold) : 0.2405
#   Test R²                             : 0.3460
#   Test RMSE                           : 0.1800
#   Test MAE                            : 0.1426
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     mean_mvpa_bout_count                          0.1560
#     mean_mvpa_bout_mean_duration                  0.1160
#     mesor_mean_curve_weekend                      0.0531
#     mesor_mean_curve_weekday                      0.0392
#     V06COMORB                                     0.0353
#     V06BMI                                        0.0324
#     amplitude_mean_curve_weekend                  0.0318
#     V06AGE                                        0.0310
#     employment_working                            0.0301
#     mean_active_bout_mean_duration                0.0299
#
#   Outcome: V06CSPACE
#   --------------------------------------------------
#   Complete cases : 1,638 of 1,845 (88.8 %)
#   Training set   : 1,310 participants
#   Test set       : 328 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0615
#   Test R²                             : -0.0309
#   Test RMSE                           : 0.1482
#   Test MAE                            : 0.1092
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     V06AGE                                        0.0693
#     mean_mvpa_bout_count                          0.0537
#     mean_mvpa_bout_mean_duration                  0.0494
#     V06BMI                                        0.0465
#     mesor_mean_curve_weekend                      0.0431
#     employment_working                            0.0392
#     iv_weekday                                    0.0358
#     amplitude_mean_curve_weekend                  0.0357
#     mean_active_bout_max_duration                 0.0352
#     interdaily_stability                          0.0350
#
#   Outcome: V06STEPST1
#   --------------------------------------------------
#   Complete cases : 1,705 of 1,845 (92.4 %)
#   Training set   : 1,364 participants
#   Test set       : 341 participants
#
#   Cross-validated R² (train, 10-fold) : 0.3355
#   Test R²                             : 0.3879
#   Test RMSE                           : 3.4392
#   Test MAE                            : 2.5823
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     mean_mvpa_bout_count                          0.2354
#     mean_mvpa_bout_mean_duration                  0.0727
#     mesor_mean_curve_weekend                      0.0443
#     V06AGE                                        0.0421
#     mean_active_bout_mean_duration                0.0346
#     amplitude_mean_curve_weekend                  0.0335
#     mesor_mean_curve_weekday                      0.0320
#     iv_weekday                                    0.0303
#     mean_sedentary_bout_mean_duration             0.0301
#     V06BMI                                        0.0300
#
#   Outcome: V06400MTIM
#   --------------------------------------------------
#   Complete cases : 1,560 of 1,845 (84.6 %)
#   Training set   : 1,248 participants
#   Test set       : 312 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1934
#   Test R²                             : 0.2197
#   Test RMSE                           : 49.5610
#   Test MAE                            : 33.0613
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     mean_mvpa_bout_count                          0.1488
#     mean_mvpa_bout_mean_duration                  0.0828
#     V06COMORB                                     0.0439
#     mesor_mean_curve_weekday                      0.0402
#     amplitude_mean_curve_weekend                  0.0362
#     mesor_mean_curve_weekend                      0.0362
#     wake_minute_sd                                0.0360
#     employment_working                            0.0357
#     V06AGE                                        0.0353
#     amplitude_mean_curve_weekday                  0.0327
#
# ======================================================================
# Group: adl  (4 outcomes)
# ======================================================================
#
#   Outcome: V06LLD6B
#   --------------------------------------------------
#   Complete cases : 1,727 of 1,845 (93.6 %)
#   Training set   : 1,381 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0213
#   Test R²                             : -0.0139
#   Test RMSE                           : 1.0836
#   Test MAE                            : 0.9065
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     mean_mvpa_bout_mean_duration                  0.0585
#     mean_active_bout_max_duration                 0.0564
#     V06COMORB                                     0.0473
#     employment_working                            0.0442
#     mesor_mean_curve_weekday                      0.0403
#     mean_mvpa_bout_count                          0.0379
#     kl_grade_index_knee                           0.0368
#     iv_weekday                                    0.0361
#     mesor_mean_curve_weekend                      0.0349
#     V06BMI                                        0.0345
#
#   Outcome: V06LLD6A
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.1075
#   Test R²                             : 0.0961
#   Test RMSE                           : 1.1197
#   Test MAE                            : 0.9090
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     mean_mvpa_bout_mean_duration                  0.1314
#     mean_active_bout_max_duration                 0.0506
#     mesor_mean_curve_weekday                      0.0483
#     amplitude_mean_curve_weekday                  0.0415
#     iv_weekend                                    0.0413
#     mean_mvpa_bout_count                          0.0379
#     V06BMI                                        0.0323
#     mean_active_bout_total_minutes                0.0320
#     mean_sedentary_bout_total_minutes             0.0317
#     wake_minute_sd                                0.0310
#
#   Outcome: V06LLDILST
#   --------------------------------------------------
#   Complete cases : 1,691 of 1,845 (91.7 %)
#   Training set   : 1,352 participants
#   Test set       : 339 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0296
#   Test R²                             : 0.0303
#   Test RMSE                           : 15.2934
#   Test MAE                            : 12.9438
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     mean_mvpa_bout_count                          0.0534
#     V06COMORB                                     0.0488
#     mean_mvpa_bout_mean_duration                  0.0472
#     wake_minute_sd                                0.0430
#     mesor_mean_curve_weekday                      0.0375
#     mesor_mean_curve_weekend                      0.0375
#     mean_active_bout_max_duration                 0.0366
#     mean_sedentary_bout_max_duration              0.0366
#     iv_weekday                                    0.0363
#     mean_sedentary_bout_count                     0.0347
#
#   Outcome: V06LLD10B
#   --------------------------------------------------
#   Complete cases : 1,732 of 1,845 (93.9 %)
#   Training set   : 1,385 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0291
#   Test R²                             : 0.1557
#   Test RMSE                           : 0.8590
#   Test MAE                            : 0.7028
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     V06COMORB                                     0.0587
#     mesor_mean_curve_weekday                      0.0494
#     mean_mvpa_bout_mean_duration                  0.0491
#     kl_grade_index_knee                           0.0463
#     V06BMI                                        0.0415
#     mean_active_bout_max_duration                 0.0398
#     iv_weekday                                    0.0396
#     V06AGE                                        0.0392
#     mean_mvpa_bout_count                          0.0362
#     wake_minute_sd                                0.0346
#
# ======================================================================
# Group: self_reported_function  (18 outcomes)
# ======================================================================
#
#   Outcome: dirkn1_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0279
#   Test R²                             : 0.1060
#   Test RMSE                           : 0.8565
#   Test MAE                            : 0.6922
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0886
#     V06BMI                                        0.0473
#     mean_mvpa_bout_mean_duration                  0.0441
#     V06COMORB                                     0.0416
#     employment_working                            0.0396
#     mean_sedentary_bout_total_minutes             0.0382
#     mean_mvpa_bout_count                          0.0377
#     iv_contrast                                   0.0377
#     wake_minute_sd                                0.0373
#     mean_sedentary_bout_mean_duration             0.0352
#
#   Outcome: dirkn2_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,729 of 1,845 (93.7 %)
#   Training set   : 1,383 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0783
#   Test R²                             : 0.1003
#   Test RMSE                           : 0.8898
#   Test MAE                            : 0.7204
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0744
#     V06BMI                                        0.0548
#     V06COMORB                                     0.0537
#     mean_mvpa_bout_mean_duration                  0.0475
#     interdaily_stability                          0.0405
#     mean_mvpa_bout_count                          0.0378
#     wake_minute_sd                                0.0377
#     mean_active_bout_max_duration                 0.0365
#     mesor_mean_curve_weekday                      0.0356
#     iv_weekend                                    0.0341
#
#   Outcome: dirkn3_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0744
#   Test R²                             : 0.0698
#   Test RMSE                           : 0.8584
#   Test MAE                            : 0.7032
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0788
#     V06COMORB                                     0.0569
#     mean_mvpa_bout_mean_duration                  0.0534
#     V06BMI                                        0.0412
#     mean_sedentary_bout_total_minutes             0.0410
#     mean_mvpa_bout_count                          0.0380
#     wake_minute_sd                                0.0376
#     acrophase_mean_curve_weekday                  0.0349
#     mean_sedentary_bout_mean_duration             0.0345
#     amplitude_mean_curve_weekend                  0.0326
#
#   Outcome: dirkn4_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0159
#   Test R²                             : 0.0316
#   Test RMSE                           : 0.7006
#   Test MAE                            : 0.5005
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0786
#     V06COMORB                                     0.0514
#     V06BMI                                        0.0480
#     mean_mvpa_bout_mean_duration                  0.0448
#     wake_minute_sd                                0.0437
#     mean_sedentary_bout_total_minutes             0.0402
#     iv_weekend                                    0.0364
#     acrophase_mean_curve_weekday                  0.0357
#     mean_mvpa_bout_count                          0.0349
#     mean_light_bout_max_duration                  0.0347
#
#   Outcome: dirkn5_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,677 of 1,845 (90.9 %)
#   Training set   : 1,341 participants
#   Test set       : 336 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0443
#   Test R²                             : 0.0800
#   Test RMSE                           : 1.0111
#   Test MAE                            : 0.8198
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0689
#     V06BMI                                        0.0454
#     V06COMORB                                     0.0412
#     mean_mvpa_bout_mean_duration                  0.0395
#     acrophase                                     0.0377
#     iv_weekend                                    0.0373
#     mean_sedentary_bout_total_minutes             0.0371
#     mean_sedentary_bout_mean_duration             0.0357
#     amplitude_mean_curve_weekday                  0.0355
#     mean_sedentary_bout_max_duration              0.0345
#
#   Outcome: dirkn6_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0379
#   Test R²                             : 0.0361
#   Test RMSE                           : 0.6497
#   Test MAE                            : 0.4856
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0869
#     V06COMORB                                     0.0560
#     mean_mvpa_bout_mean_duration                  0.0421
#     mean_sedentary_bout_total_minutes             0.0413
#     V06BMI                                        0.0400
#     mean_active_bout_total_minutes                0.0394
#     wake_minute_sd                                0.0364
#     mean_mvpa_bout_count                          0.0354
#     V06AGE                                        0.0350
#     acrophase_mean_curve_weekday                  0.0340
#
#   Outcome: dirkn7_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0295
#   Test R²                             : 0.0192
#   Test RMSE                           : 0.8234
#   Test MAE                            : 0.6709
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0708
#     V06COMORB                                     0.0486
#     wake_minute_sd                                0.0468
#     V06BMI                                        0.0446
#     mean_mvpa_bout_mean_duration                  0.0403
#     mean_mvpa_bout_count                          0.0356
#     amplitude_mean_curve_weekday                  0.0351
#     acrophase                                     0.0348
#     mesor_mean_curve_weekend                      0.0345
#     acrophase_mean_curve_weekday                  0.0344
#
#   Outcome: dirkn8_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,730 of 1,845 (93.8 %)
#   Training set   : 1,384 participants
#   Test set       : 346 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0429
#   Test R²                             : 0.0902
#   Test RMSE                           : 0.7805
#   Test MAE                            : 0.5511
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0729
#     mean_mvpa_bout_mean_duration                  0.0530
#     V06COMORB                                     0.0489
#     iv_weekday                                    0.0404
#     mean_active_bout_total_minutes                0.0397
#     V06BMI                                        0.0371
#     wake_minute_sd                                0.0365
#     mean_mvpa_bout_count                          0.0365
#     mean_sedentary_bout_mean_duration             0.0362
#     amplitude_mean_curve_weekday                  0.0351
#
#   Outcome: dirkn9_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0129
#   Test R²                             : 0.0308
#   Test RMSE                           : 0.7306
#   Test MAE                            : 0.5332
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 6}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0594
#     iv_weekend                                    0.0510
#     mean_mvpa_bout_count                          0.0454
#     V06COMORB                                     0.0454
#     amplitude_mean_curve_weekend                  0.0439
#     mesor_mean_curve_weekday                      0.0423
#     mean_sedentary_bout_total_minutes             0.0403
#     acrophase_mean_curve_weekend                  0.0373
#     iv_contrast                                   0.0372
#     wake_minute_sd                                0.0360
#
#   Outcome: dirkn13_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,437 of 1,845 (77.9 %)
#   Training set   : 1,149 participants
#   Test set       : 288 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0192
#   Test R²                             : 0.0902
#   Test RMSE                           : 0.6997
#   Test MAE                            : 0.4964
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0560
#     V06COMORB                                     0.0511
#     V06BMI                                        0.0437
#     wake_minute_mean                              0.0421
#     wake_minute_sd                                0.0396
#     mean_sedentary_bout_total_minutes             0.0395
#     mean_mvpa_bout_mean_duration                  0.0394
#     amplitude_mean_curve_weekday                  0.0385
#     mean_mvpa_bout_count                          0.0364
#     mean_sedentary_bout_mean_duration             0.0356
#
#   Outcome: dirkn15_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0160
#   Test R²                             : 0.0442
#   Test RMSE                           : 0.6850
#   Test MAE                            : 0.5301
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0731
#     V06COMORB                                     0.0502
#     wake_minute_sd                                0.0401
#     mean_mvpa_bout_mean_duration                  0.0388
#     mean_sedentary_bout_total_minutes             0.0376
#     V06AGE                                        0.0368
#     mesor_mean_curve_weekday                      0.0363
#     employment_working                            0.0363
#     mean_sedentary_bout_mean_duration             0.0348
#     V06BMI                                        0.0347
#
#   Outcome: dirkn16_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,640 of 1,845 (88.9 %)
#   Training set   : 1,312 participants
#   Test set       : 328 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0127
#   Test R²                             : 0.0274
#   Test RMSE                           : 0.8530
#   Test MAE                            : 0.6747
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0657
#     V06COMORB                                     0.0598
#     V06BMI                                        0.0430
#     wake_minute_mean                              0.0405
#     wake_minute_sd                                0.0395
#     mean_mvpa_bout_mean_duration                  0.0392
#     mean_mvpa_bout_count                          0.0369
#     iv_weekend                                    0.0361
#     mean_active_bout_max_duration                 0.0349
#     acrophase                                     0.0341
#
#   Outcome: dirkn17_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,733 of 1,845 (93.9 %)
#   Training set   : 1,386 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0108
#   Test R²                             : 0.0034
#   Test RMSE                           : 0.6331
#   Test MAE                            : 0.4560
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0661
#     V06COMORB                                     0.0507
#     wake_minute_sd                                0.0472
#     mesor_mean_curve_weekday                      0.0468
#     mean_mvpa_bout_mean_duration                  0.0467
#     mean_mvpa_bout_count                          0.0398
#     iv_weekday                                    0.0386
#     acrophase_mean_curve_weekday                  0.0365
#     acrophase                                     0.0364
#     mean_sedentary_bout_total_minutes             0.0344
#
#   Outcome: dilkn10_symptomatic_side
#   --------------------------------------------------
#   Complete cases : 1,735 of 1,845 (94.0 %)
#   Training set   : 1,388 participants
#   Test set       : 347 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0408
#   Test R²                             : -0.0327
#   Test RMSE                           : 0.6241
#   Test MAE                            : 0.4553
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     employment_working                            0.0513
#     V06COMORB                                     0.0486
#     wake_minute_sd                                0.0461
#     mean_sedentary_bout_total_minutes             0.0434
#     kl_grade_index_knee                           0.0428
#     mean_mvpa_bout_mean_duration                  0.0377
#     V06BMI                                        0.0373
#     mean_active_bout_max_duration                 0.0373
#     interdaily_stability                          0.0370
#     wake_minute_mean                              0.0348
#
#   Outcome: V06KOOSFX1
#   --------------------------------------------------
#   Complete cases : 1,434 of 1,845 (77.7 %)
#   Training set   : 1,147 participants
#   Test set       : 287 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0049
#   Test R²                             : 0.0537
#   Test RMSE                           : 1.0759
#   Test MAE                            : 0.9021
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0624
#     V06BMI                                        0.0446
#     mean_mvpa_bout_mean_duration                  0.0429
#     V06COMORB                                     0.0421
#     mean_sedentary_bout_mean_duration             0.0398
#     mean_sedentary_bout_total_minutes             0.0392
#     mean_active_bout_total_minutes                0.0380
#     iv_weekday                                    0.0360
#     wear_duration_mean                            0.0353
#     iv_weekend                                    0.0351
#
#   Outcome: V06KOOSFX2
#   --------------------------------------------------
#   Complete cases : 810 of 1,845 (43.9 %)
#   Training set   : 648 participants
#   Test set       : 162 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0260
#   Test R²                             : -0.0257
#   Test RMSE                           : 1.0573
#   Test MAE                            : 0.8107
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 6}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.1265
#     iv_weekend                                    0.0560
#     V06COMORB                                     0.0481
#     iv_contrast                                   0.0402
#     mesor_mean_curve_weekend                      0.0387
#     mean_light_bout_max_duration                  0.0376
#     mean_active_bout_total_minutes                0.0376
#     acrophase                                     0.0372
#     acrophase_mean_curve_weekend                  0.0343
#     amplitude_mean_curve_weekend                  0.0340
#
#   Outcome: V06KOOSFX4
#   --------------------------------------------------
#   Complete cases : 1,430 of 1,845 (77.5 %)
#   Training set   : 1,144 participants
#   Test set       : 286 participants
#
#   Cross-validated R² (train, 10-fold) : 0.0204
#   Test R²                             : 0.0542
#   Test RMSE                           : 0.9224
#   Test MAE                            : 0.7449
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0941
#     mean_mvpa_bout_count                          0.0404
#     V06COMORB                                     0.0401
#     amplitude_mean_curve_weekend                  0.0365
#     mean_mvpa_bout_mean_duration                  0.0362
#     V06BMI                                        0.0361
#     iv_weekend                                    0.0359
#     acrophase_mean_curve_weekday                  0.0357
#     acrophase                                     0.0354
#     mean_active_bout_mean_duration                0.0345
#
#   Outcome: V06KOOSFX5
#   --------------------------------------------------
#   Complete cases : 1,515 of 1,845 (82.1 %)
#   Training set   : 1,212 participants
#   Test set       : 303 participants
#
#   Cross-validated R² (train, 10-fold) : -0.0104
#   Test R²                             : 0.0288
#   Test RMSE                           : 1.0356
#   Test MAE                            : 0.8716
#   Best hyperparameters                : {'learning_rate': 0.03, 'max_depth': 3}
#
#   Top 10 feature importances (gain):
#     kl_grade_index_knee                           0.0504
#     V06COMORB                                     0.0453
#     mean_mvpa_bout_mean_duration                  0.0453
#     V06BMI                                        0.0405
#     iv_weekday                                    0.0404
#     mean_sedentary_bout_total_minutes             0.0391
#     amplitude_mean_curve_weekday                  0.0389
#     mean_sedentary_bout_max_duration              0.0357
#     mean_active_bout_mean_duration                0.0355
#     mean_mvpa_bout_count                          0.0354

# %% [markdown]
# #### XGBoost summary table

# %%
summary_rows = []

for group_name, group_results in xgboost_results.items():
    for result in group_results:
        summary_rows.append({
            "group": group_name,
            "outcome": result["outcome_column"],
            "n_training": result["n_training"],
            "cv_r2_train": round(result["cross_validated_r2"], 4),
            "test_r2": round(result["test_r2"], 4),
            "test_rmse": round(result["test_rmse"], 4),
            "test_mae": round(result["test_mae"], 4),
            "max_depth": result["best_hyperparameters"]["max_depth"],
            "learning_rate": result["best_hyperparameters"]["learning_rate"],
        })

xgboost_summary_table = pd.DataFrame(summary_rows)

print("\nStage 5 — XGBoost summary (sorted by test R²):")
print(
    xgboost_summary_table
    .sort_values("test_r2", ascending=False)
    .to_string(index=False)
)
# Out:
# Stage 5 — XGBoost summary (sorted by test R²):
#                  group                        outcome  n_training  cv_r2_train  test_r2  test_rmse  test_mae  max_depth  learning_rate
#               function                     V06STEPST1        1364       0.3355   0.3879     3.4392    2.5823          3           0.03
#               function                     V0620MPACE        1364       0.2405   0.3460     0.1800    0.1426          3           0.03
#               function                     V06400MTIM        1248       0.1934   0.2197    49.5610   33.0613          3           0.03
#                    adl                      V06LLD10B        1385       0.0291   0.1557     0.8590    0.7028          3           0.03
#                   pain     koos_pain_symptomatic_side        1388       0.0643   0.1061    16.5655   12.8742          3           0.03
# self_reported_function        dirkn1_symptomatic_side        1384       0.0279   0.1060     0.8565    0.6922          3           0.03
#                   pain   icoap_total_symptomatic_side        1386       0.0117   0.1005    13.0872    9.4192          3           0.03
# self_reported_function        dirkn2_symptomatic_side        1383       0.0783   0.1003     0.8898    0.7204          3           0.03
#                    adl                       V06LLD6A        1386       0.1075   0.0961     1.1197    0.9090          3           0.03
# self_reported_function       dirkn13_symptomatic_side        1149      -0.0192   0.0902     0.6997    0.4964          3           0.03
# self_reported_function        dirkn8_symptomatic_side        1384       0.0429   0.0902     0.7805    0.5511          3           0.03
# self_reported_function        dirkn5_symptomatic_side        1341       0.0443   0.0800     1.0111    0.8198          3           0.03
# self_reported_function        dirkn3_symptomatic_side        1388       0.0744   0.0698     0.8584    0.7032          3           0.03
#                   pain     pain_7day_symptomatic_side        1383       0.0467   0.0676     2.6855    2.2511          3           0.03
#                   pain      pain_bed_symptomatic_side        1388      -0.0526   0.0642     0.8432    0.5683          3           0.03
# self_reported_function                     V06KOOSFX4        1144       0.0204   0.0542     0.9224    0.7449          3           0.03
# self_reported_function                     V06KOOSFX1        1147      -0.0049   0.0537     1.0759    0.9021          3           0.03
# self_reported_function       dirkn15_symptomatic_side        1388      -0.0160   0.0442     0.6850    0.5301          3           0.03
# self_reported_function        dirkn6_symptomatic_side        1388       0.0379   0.0361     0.6497    0.4856          3           0.03
# self_reported_function        dirkn4_symptomatic_side        1388       0.0159   0.0316     0.7006    0.5005          3           0.03
# self_reported_function        dirkn9_symptomatic_side        1388       0.0129   0.0308     0.7306    0.5332          6           0.03
#                    adl                     V06LLDILST        1352       0.0296   0.0303    15.2934   12.9438          3           0.03
# self_reported_function                     V06KOOSFX5        1212      -0.0104   0.0288     1.0356    0.8716          3           0.03
# self_reported_function       dirkn16_symptomatic_side        1312      -0.0127   0.0274     0.8530    0.6747          3           0.03
# self_reported_function        dirkn7_symptomatic_side        1388       0.0295   0.0192     0.8234    0.6709          3           0.03
# self_reported_function       dirkn17_symptomatic_side        1386       0.0108   0.0034     0.6331    0.4560          3           0.03
#                   pain global_rating_symptomatic_side        1388       0.0021  -0.0122     1.9078    1.4653          6           0.03
#                    adl                       V06LLD6B        1381       0.0213  -0.0139     1.0836    0.9065          3           0.03
# self_reported_function                     V06KOOSFX2         648       0.0260  -0.0257     1.0573    0.8107          6           0.03
#               function                      V06CSPACE        1310       0.0615  -0.0309     0.1482    0.1092          3           0.03
# self_reported_function       dilkn10_symptomatic_side        1388      -0.0408  -0.0327     0.6241    0.4553          3           0.03

# %% [markdown]
# ### 2.2.6 KL grade classification
#
# ## Purpose
#
# Stage 6 treats KL grade as a multiclass ordinal outcome rather than
# a covariate. The question being asked is different from Stages 1–5:
# not "how well do activity features predict a clinical symptom outcome"
# but "how much does the activity pattern alone reveal about the
# structural severity of a participant's knee osteoarthritis".
#
# This is methodologically distinct because KL grade is a radiographic
# measure of structural joint damage that is only loosely coupled to
# symptoms. A participant with KL grade 4 may report minimal pain if
# they have adapted their behaviour; a participant with KL grade 1 may
# report severe pain due to sensitisation. If activity features
# nonetheless predict KL grade above chance, this suggests that
# structural severity leaves a detectable signature in movement patterns
# independent of subjective symptom reporting.
#
# ## Why ordinal classification rather than regression
#
# KL grade takes integer values from 0 to 4 with an ordered but not
# necessarily interval-scaled relationship. Treating it as a continuous
# regression target would impose the assumption that the step from
# KL 0 to KL 1 represents the same magnitude of change as KL 3 to KL 4,
# which is not clinically justified. Ordinal classification preserves
# the ordering without imposing equal spacing.
#
# ## Evaluation metric
#
# Quadratic weighted kappa (QWK) is the primary metric. QWK penalises
# predictions in proportion to how far they are from the true class —
# a prediction of KL 4 when the true grade is KL 0 is penalised much
# more heavily than a prediction of KL 2 when the true grade is KL 1.
# This is the appropriate metric for an ordinal outcome where adjacent
# misclassifications are less serious than distant ones.
#
# Accuracy and mean absolute error on the integer-coded grade are
# reported as secondary metrics for interpretability.
#
# ## Class imbalance
#
# KL grade is not uniformly distributed — KL 2 and KL 3 are the most
# common grades while KL 4 is rare. Class imbalance is handled via:
# - Random Forest: balanced class weights, which up-weight minority
#   classes during tree fitting
# - XGBoost: sample weights inversely proportional to class frequency,
#   applied during fitting
#
# ## Model specification
#
# Two classifiers are fitted:
#
# Random Forest classifier:
# - 500 trees, balanced class weights, min 10 samples per leaf
# - No standardisation required
#
# XGBoost classifier:
# - 400 trees, max_depth 4, learning_rate 0.05
# - subsample 0.8, colsample_bytree 0.8
# - Inverse frequency sample weights for class imbalance
# - Hyperparameters are fixed rather than grid-searched to keep
#   runtime manageable; the specification follows the same
#   rationale as Stage 5
#
# ## Important note on covariates
#
# KL grade must not appear in the covariate block when it is the
# outcome. The structural covariate (kl_grade_index_knee) is therefore
# excluded and the model uses demographic covariates only: age, BMI,
# comorbidity count, and employment status.
#
# ## Output
#
# kl_grade_results: dict with keys random_forest and xgboost, each
# containing:
# - test_kappa (quadratic weighted kappa, primary metric)
# - test_accuracy
# - test_mean_absolute_error_grade
# - cross_validated_kappa (training set, stratified 10-fold CV)
# - feature_importances (Series, all predictors ranked)
# - confusion_matrix (DataFrame, rows = actual, columns = predicted)

# %%
def run_kl_grade_classification(
    *,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    model_name: str,
    cross_validation_folds: int = 10,
    random_state: int = 42,
) -> dict:
    """
    Fit a multiclass classifier for KL grade (0 to 4) and evaluate
    using metrics appropriate for an ordinal outcome.

    KL grade is excluded from the covariate block to prevent data
    leakage. The train/test split is stratified by KL grade itself.
    Class imbalance is handled via balanced class weights for Random
    Forest and normalised inverse frequency sample weights for XGBoost.

    Quadratic weighted kappa is the primary evaluation metric. It
    penalises predictions in proportion to the squared distance from
    the true class, which is appropriate for an ordinal outcome where
    distant misclassifications are more serious than adjacent ones.

    :param dataframe: Modelling dataframe with one row per participant.
    :param activity_predictor_columns: Activity predictor column names.
    :param demographic_covariate_columns: Demographic covariate column
        names. Must not contain KL grade.
    :param structural_covariate_column: KL grade column name. Used only
        to verify it is absent from covariate_columns and to prepare
        the dataset split — not included as a predictor.
    :param model_name: Either ``"random_forest"`` or ``"xgboost"``.
    :param cross_validation_folds: Number of CV folds (default 10).
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys cross_validated_kappa, test_kappa,
        test_accuracy, test_mean_absolute_error_grade,
        feature_importances, confusion_matrix.
    :raises ValueError: If ``model_name`` is not recognised or if KL
        grade appears in ``demographic_covariate_columns``.
    """
    if structural_covariate_column in demographic_covariate_columns:
        raise ValueError(
            f"KL grade column '{structural_covariate_column}' must not "
            f"appear in demographic_covariate_columns when modelling KL "
            f"grade as the outcome — this would cause data leakage."
        )

    if model_name not in {"random_forest", "xgboost"}:
        raise ValueError(
            f"Unrecognised model_name '{model_name}'. "
            f"Expected 'random_forest' or 'xgboost'."
        )

    all_predictor_columns = (
        list(demographic_covariate_columns) + activity_predictor_columns
    )

    (
        training_predictors,
        training_outcome,
        test_predictors,
        test_outcome,
    ) = prepare_modelling_dataset_for_stage(
        dataframe=dataframe,
        outcome_column=structural_covariate_column,
        activity_predictor_columns=activity_predictor_columns,
        demographic_covariate_columns=demographic_covariate_columns,
        structural_covariate_column=structural_covariate_column,
        include_structural_covariate=False,
    )

    training_matrix = training_predictors[all_predictor_columns].values
    test_matrix = test_predictors[all_predictor_columns].values

    training_classes = training_outcome.astype(int).values
    test_classes = test_outcome.astype(int).values

    if model_name == "random_forest":
        classifier = RandomForestClassifier(
            n_estimators=500,
            max_depth=None,
            min_samples_leaf=10,
            class_weight="balanced",
            n_jobs=-1,
            random_state=random_state,
        )
        classifier.fit(training_matrix, training_classes)

    else:
        # Scale each sample's weight by the inverse of its class frequency,
        # normalised so the total weight equals the number of training
        # samples. This avoids the over-correction that occurs with raw
        # inverse counts and prevents the classifier collapsing to a
        # single predicted class.
        class_counts = np.bincount(training_classes)
        class_weights = len(training_classes) / (
            len(class_counts) * class_counts
        )
        sample_weights = class_weights[training_classes]

        classifier = xgboost.XGBClassifier(
            n_estimators=400,
            max_depth=4,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            objective="multi:softmax",
            num_class=int(np.max(training_classes)) + 1,
            random_state=random_state,
            n_jobs=-1,
            verbosity=0,
        )
        classifier.fit(
            training_matrix,
            training_classes,
            sample_weight=sample_weights,
        )

    def score_quadratic_weighted_kappa(
        estimator,
        predictor_matrix,
        true_values,
    ) -> float:
        """
        Scorer function for cross_val_score computing quadratic weighted
        kappa between true and predicted KL grade classes.

        :param estimator: Fitted classifier with a predict method.
        :param predictor_matrix: Feature matrix to predict from.
        :param true_values: True integer-coded KL grade values.
        :returns: Quadratic weighted kappa score.
        """
        return cohen_kappa_score(
            y1=true_values,
            y2=estimator.predict(predictor_matrix),
            weights="quadratic",
        )

    cross_validation_kappa_scores = cross_val_score(
        estimator=classifier.__class__(**classifier.get_params()),
        X=training_matrix,
        y=training_classes,
        cv=StratifiedKFold(
            n_splits=cross_validation_folds,
            shuffle=True,
            random_state=random_state,
        ),
        scoring=score_quadratic_weighted_kappa,
        n_jobs=-1,
    )

    test_predictions = classifier.predict(test_matrix)

    test_kappa = cohen_kappa_score(
        y1=test_classes,
        y2=test_predictions,
        weights="quadratic",
    )
    test_accuracy = accuracy_score(test_classes, test_predictions)
    test_mean_absolute_error_grade = float(
        np.mean(np.abs(test_classes - test_predictions))
    )

    feature_importances = pd.Series(
        data=classifier.feature_importances_,
        index=all_predictor_columns,
        name="importance",
    ).sort_values(ascending=False)

    confusion_matrix = pd.crosstab(
        pd.Series(test_classes, name="actual"),
        pd.Series(test_predictions, name="predicted"),
    )

    print(
        f"\n  Cross-validated kappa (train, {cross_validation_folds}-fold) : "
        f"{cross_validation_kappa_scores.mean():.4f}\n"
        f"  Test quadratic weighted kappa          : {test_kappa:.4f}\n"
        f"  Test accuracy                          : {test_accuracy:.4f}\n"
        f"  Test MAE (grade)                       : "
        f"{test_mean_absolute_error_grade:.4f}\n"
        f"\n  Confusion matrix (rows: actual, columns: predicted):\n"
        f"{confusion_matrix}\n"
        f"\n  Top 10 feature importances:"
    )
    for predictor_name, importance_value in feature_importances.head(10).items():
        print(f"    {predictor_name:<45} {importance_value:.4f}")

    return {
        "cross_validated_kappa": float(cross_validation_kappa_scores.mean()),
        "test_kappa": test_kappa,
        "test_accuracy": test_accuracy,
        "test_mean_absolute_error_grade": test_mean_absolute_error_grade,
        "feature_importances": feature_importances,
        "confusion_matrix": confusion_matrix,
    }

# %% [markdown]
# #### Execute KL grade classification for both models

# %%
print(f"\n{'=' * 70}")
print("Stage 6 — KL grade classification")
print(f"{'=' * 70}")

kl_grade_results: dict[str, dict] = {}

for model_name in ["random_forest", "xgboost"]:
    print(f"\n  Model: {model_name}")
    print(f"  {'-' * 50}")

    kl_grade_results[model_name] = run_kl_grade_classification(
        dataframe=summary_metrics_06,
        activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
        demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
        structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
        model_name=model_name,
        cross_validation_folds=CROSS_VALIDATION_FOLDS,
        random_state=RANDOM_STATE,
    )
# Out:
# ======================================================================
# Stage 6 — KL grade classification
# ======================================================================
#
#   Model: random_forest
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated kappa (train, 10-fold) : 0.2085
#   Test quadratic weighted kappa          : 0.2556
#   Test accuracy                          : 0.2874
#   Test MAE (grade)                       : 1.2270
#
#   Confusion matrix (rows: actual, columns: predicted):
# predicted   0   1   2   3   4
# actual
# 0          35   7  23  15   5
# 1          17   5  21   9   5
# 2          22   9  34  20  14
# 3          12  10  18  22  16
# 4           2   3  10  10   4
#
#   Top 10 feature importances:
#     V06BMI                                        0.0633
#     mean_mvpa_bout_mean_duration                  0.0440
#     mean_mvpa_bout_count                          0.0436
#     wake_minute_sd                                0.0432
#     mean_active_bout_mean_duration                0.0418
#     V06AGE                                        0.0411
#     mesor_mean_curve_weekday                      0.0398
#     mean_sedentary_bout_mean_duration             0.0390
#     iv_weekend                                    0.0388
#     wake_minute_mean                              0.0382
#
#   Model: xgboost
#   --------------------------------------------------
#   Complete cases : 1,736 of 1,845 (94.1 %)
#   Training set   : 1,388 participants
#   Test set       : 348 participants
#
#   Cross-validated kappa (train, 10-fold) : 0.1496
#   Test quadratic weighted kappa          : 0.2368
#   Test accuracy                          : 0.2730
#   Test MAE (grade)                       : 1.1983
#
#   Confusion matrix (rows: actual, columns: predicted):
# predicted   0   1   2   3   4
# actual
# 0          25  13  32  12   3
# 1          18  11  18   7   3
# 2          26   8  36  22   7
# 3           9  10  27  21  11
# 4           3   3  10  11   2
#
#   Top 10 feature importances:
#     V06BMI                                        0.0413
#     mean_mvpa_bout_count                          0.0403
#     V06AGE                                        0.0401
#     mean_active_bout_mean_duration                0.0388
#     mesor_mean_curve_weekday                      0.0385
#     interdaily_stability                          0.0371
#     mean_sedentary_bout_count                     0.0365
#     mesor_mean_curve_weekend                      0.0365
#     mean_mvpa_bout_mean_duration                  0.0363
#     wake_minute_mean                              0.0362

# %% [markdown]
# #### KL grade classification summary table

# %%
print(f"\n{'=' * 70}")
print("Stage 6 — KL grade classification summary")
print(f"{'=' * 70}")

for model_name, result in kl_grade_results.items():
    print(
        f"\n  {model_name.replace('_', ' ').title()}\n"
        f"    CV kappa (train)          : "
        f"{result['cross_validated_kappa']:.4f}\n"
        f"    Test kappa (QWK)          : {result['test_kappa']:.4f}\n"
        f"    Test accuracy             : {result['test_accuracy']:.4f}\n"
        f"    Test MAE (grade)          : "
        f"{result['test_mean_absolute_error_grade']:.4f}"
    )

best_model_name = max(
    kl_grade_results,
    key=lambda name: kl_grade_results[name]["test_kappa"],
)
print(
    f"\n  Best model: {best_model_name.replace('_', ' ').title()} "
    f"(test kappa = "
    f"{kl_grade_results[best_model_name]['test_kappa']:.4f})"
)
# Out:
# ======================================================================
# Stage 6 — KL grade classification summary
# ======================================================================
#
#   Random Forest
#     CV kappa (train)          : 0.2085
#     Test kappa (QWK)          : 0.2556
#     Test accuracy             : 0.2874
#     Test MAE (grade)          : 1.2270
#
#   Xgboost
#     CV kappa (train)          : 0.1496
#     Test kappa (QWK)          : 0.2368
#     Test accuracy             : 0.2730
#     Test MAE (grade)          : 1.1983
#
#   Best model: Random Forest (test kappa = 0.2556)

# %% [markdown]
# ## 2.3 Cross-model comparison
#
# ## Purpose
#
# Stage 7 assembles the results from all previous stages into a single
# comparison table per outcome, enabling direct comparison of all five
# model families on a common held-out test set metric. This is the
# primary results table for the thesis modelling chapter.
#
# ## What is being compared
#
# For continuous outcomes (Stages 1–5), the comparison metric is test
# R² — the proportion of variance in the held-out test set explained
# by each model. All models were evaluated on the same 20% held-out
# test set produced by the same stratified split, so test R² values
# are directly comparable across model families.
#
# Stage 1 LASSO contributes full_r2_cv rather than a test set R²
# because its role is explanatory rather than predictive. It is included
# in the table for reference but is not directly comparable to the
# held-out test R² values from Stages 2–5. The incremental_r2 from
# Stage 1 is reported as a separate column.
#
# For KL grade (Stage 6), the comparison metric is quadratic weighted
# kappa. This is reported in a separate table.
#
# ## Best model selection
#
# The best model per outcome is selected as the model family with the
# highest test R² among Stages 2–5. Stage 1 is excluded from best
# model selection because it optimises for explanation rather than
# prediction.
#
# ## What the table reveals
#
# Outcomes where all models produce similar test R² indicate that the
# predictor-outcome relationship is well-described by linear models and
# tree-based models offer no advantage. Outcomes where tree-based
# models substantially outperform linear models indicate non-linear or
# interaction effects. Outcomes where all models produce low test R²
# across the board indicate weak or absent signal from the activity
# predictor set for that outcome.

# %%
def build_continuous_outcome_comparison_table(
    *,
    lasso_results: dict[str, list[dict]],
    ridge_results: dict[str, list[dict]],
    elastic_net_results: dict[str, list[dict]],
    random_forest_results: dict[str, list[dict]],
    xgboost_results: dict[str, list[dict]],
) -> pd.DataFrame:
    """
    Assemble a single comparison table across all five model families
    for every continuous outcome modelled in Stages 1–5.

    For each outcome the table contains:
    - Stage 1 LASSO: incremental_r2 and full_r2_cv (explanatory,
      training set CV — not directly comparable to test R²)
    - Stages 2–5: test_r2 on the held-out test set
    - best_model: model family with the highest test R² among
      Stages 2–5
    - best_test_r2: the corresponding test R²

    :param lasso_results: Output of Stage 1 execution cell.
    :param ridge_results: Output of Stage 2 execution cell.
    :param elastic_net_results: Output of Stage 3 execution cell.
    :param random_forest_results: Output of Stage 4 execution cell.
    :param xgboost_results: Output of Stage 5 execution cell.
    :returns: DataFrame with one row per outcome sorted by
        best_test_r2 descending.
    """
    lasso_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in lasso_results.values()
        for result in group_results
    }
    ridge_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in ridge_results.values()
        for result in group_results
    }
    elastic_net_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in elastic_net_results.values()
        for result in group_results
    }
    random_forest_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in random_forest_results.values()
        for result in group_results
    }
    xgboost_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in xgboost_results.values()
        for result in group_results
    }

    all_outcome_columns = list(ridge_lookup.keys())

    rows = []

    for outcome_column in all_outcome_columns:
        lasso_result = lasso_lookup.get(outcome_column, {})
        ridge_result = ridge_lookup.get(outcome_column, {})
        elastic_net_result = elastic_net_lookup.get(outcome_column, {})
        random_forest_result = random_forest_lookup.get(outcome_column, {})
        xgboost_result = xgboost_lookup.get(outcome_column, {})

        ridge_test_r2 = ridge_result.get("test_r2", np.nan)
        elastic_net_test_r2 = elastic_net_result.get("test_r2", np.nan)
        random_forest_test_r2 = random_forest_result.get("test_r2", np.nan)
        xgboost_test_r2 = xgboost_result.get("test_r2", np.nan)

        predictive_model_r2_values = {
            "ridge": ridge_test_r2,
            "elastic_net": elastic_net_test_r2,
            "random_forest": random_forest_test_r2,
            "xgboost": xgboost_test_r2,
        }

        best_model_name = max(
            predictive_model_r2_values,
            key=lambda name: (
                predictive_model_r2_values[name]
                if not np.isnan(predictive_model_r2_values[name])
                else -np.inf
            ),
        )
        best_test_r2 = predictive_model_r2_values[best_model_name]

        group_name = next(
            (
                group
                for group, group_results in ridge_results.items()
                for result in group_results
                if result["outcome_column"] == outcome_column
            ),
            "unknown",
        )

        rows.append({
            "group": group_name,
            "outcome": outcome_column,
            "n_training": ridge_result.get("n_training", np.nan),
            "lasso_incremental_r2": round(
                lasso_result.get("incremental_r2", np.nan), 4
            ),
            "lasso_full_r2_cv": round(
                lasso_result.get("full_r2_cv", np.nan), 4
            ),
            "ridge_test_r2": round(ridge_test_r2, 4),
            "elastic_net_test_r2": round(elastic_net_test_r2, 4),
            "random_forest_test_r2": round(random_forest_test_r2, 4),
            "xgboost_test_r2": round(xgboost_test_r2, 4),
            "best_model": best_model_name,
            "best_test_r2": round(best_test_r2, 4),
        })

    comparison_table = (
        pd.DataFrame(rows)
        .sort_values("best_test_r2", ascending=False)
        .reset_index(drop=True)
    )

    return comparison_table


def print_comparison_table_by_group(
    comparison_table: pd.DataFrame,
) -> None:
    """
    Print the comparison table grouped by outcome domain for
    readability in the notebook output.

    :param comparison_table: Output of
        build_continuous_outcome_comparison_table.
    """
    column_widths = {
        "outcome": 40,
        "n_training": 10,
        "lasso_incremental_r2": 14,
        "lasso_full_r2_cv": 14,
        "ridge_test_r2": 13,
        "elastic_net_test_r2": 16,
        "random_forest_test_r2": 18,
        "xgboost_test_r2": 13,
        "best_model": 14,
        "best_test_r2": 12,
    }

    header = (
        f"{'Outcome':<40} {'n_train':>10} {'LASSO_incR²':>14} "
        f"{'LASSO_cvR²':>14} {'Ridge_R²':>13} {'ElNet_R²':>16} "
        f"{'RF_R²':>18} {'XGB_R²':>13} {'Best':>14} {'BestR²':>12}"
    )
    separator = "-" * len(header)

    for group_name, group_data in comparison_table.groupby("group", sort=False):
        print(f"\n{'=' * len(header)}")
        print(f"Group: {group_name}")
        print(f"{'=' * len(header)}")
        print(header)
        print(separator)

        for _, row in group_data.iterrows():
            print(
                f"{row['outcome']:<40} "
                f"{row['n_training']:>10} "
                f"{row['lasso_incremental_r2']:>14.4f} "
                f"{row['lasso_full_r2_cv']:>14.4f} "
                f"{row['ridge_test_r2']:>13.4f} "
                f"{row['elastic_net_test_r2']:>16.4f} "
                f"{row['random_forest_test_r2']:>18.4f} "
                f"{row['xgboost_test_r2']:>13.4f} "
                f"{row['best_model']:>14} "
                f"{row['best_test_r2']:>12.4f}"
            )

# %% [markdown]
# ### Execute comparison table construction and printing

# %%
comparison_table = build_continuous_outcome_comparison_table(
    lasso_results=lasso_results,
    ridge_results=ridge_results,
    elastic_net_results=elastic_net_results,
    random_forest_results=random_forest_results,
    xgboost_results=xgboost_results,
)

print_comparison_table_by_group(comparison_table=comparison_table)

# Save results

comparison_table.to_csv(
    output_path / "stage_7_model_comparison.csv",
    index=False,
)

print(f"\nComparison table saved to: stage_7_model_comparison.csv")
print(f"Total outcomes compared: {len(comparison_table)}")
# Out:
# =============================================================================================================================================================================
# Group: function
# =============================================================================================================================================================================
# Outcome                                     n_train    LASSO_incR²     LASSO_cvR²      Ridge_R²         ElNet_R²              RF_R²        XGB_R²           Best       BestR²
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# V06STEPST1                                     1364         0.0916         0.2747        0.3350           0.3354             0.3762        0.3879        xgboost       0.3879
# V0620MPACE                                     1364         0.0531         0.2258        0.3361           0.3400             0.3468        0.3460  random_forest       0.3468
# V06400MTIM                                     1248         0.0501         0.2285        0.2117           0.2133             0.2465        0.2197  random_forest       0.2465
# V06CSPACE                                      1310         0.0015         0.1195        0.0729           0.0731             0.0346       -0.0309    elastic_net       0.0731
#
# =============================================================================================================================================================================
# Group: self_reported_function
# =============================================================================================================================================================================
# Outcome                                     n_train    LASSO_incR²     LASSO_cvR²      Ridge_R²         ElNet_R²              RF_R²        XGB_R²           Best       BestR²
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# dirkn1_symptomatic_side                        1384         0.0151         0.0943        0.1712           0.1687             0.1357        0.1060          ridge       0.1712
# dirkn5_symptomatic_side                        1341         0.0157         0.0900        0.1621           0.1682             0.0934        0.0800    elastic_net       0.1682
# dirkn2_symptomatic_side                        1383         0.0211         0.1122        0.1469           0.1521             0.1193        0.1003    elastic_net       0.1521
# dirkn13_symptomatic_side                       1149         0.0164         0.0689        0.1399           0.1391             0.0961        0.0902          ridge       0.1399
# dirkn8_symptomatic_side                        1384         0.0216         0.1077        0.1305           0.1281             0.1197        0.0902          ridge       0.1305
# dirkn3_symptomatic_side                        1388         0.0137         0.1118        0.1281           0.1284             0.0872        0.0698    elastic_net       0.1284
# V06KOOSFX4                                     1144        -0.0110         0.0762        0.1246           0.1235             0.0997        0.0542          ridge       0.1246
# dirkn15_symptomatic_side                       1388         0.0083         0.0529        0.1161           0.1135             0.0793        0.0442          ridge       0.1161
# dirkn4_symptomatic_side                        1388         0.0059         0.0959        0.1124           0.1139             0.0775        0.0316    elastic_net       0.1139
# V06KOOSFX1                                     1147         0.0106         0.0623        0.1044           0.1075             0.0615        0.0537    elastic_net       0.1075
# dirkn6_symptomatic_side                        1388         0.0128         0.1030        0.1008           0.1049             0.0925        0.0361    elastic_net       0.1049
# dirkn17_symptomatic_side                       1386         0.0245         0.0752        0.1006           0.1019             0.0557        0.0034    elastic_net       0.1019
# dirkn16_symptomatic_side                       1312         0.0069         0.0766        0.0999           0.1013             0.0861        0.0274    elastic_net       0.1013
# V06KOOSFX5                                     1212         0.0169         0.0581        0.0898           0.0975             0.0322        0.0288    elastic_net       0.0975
# dirkn9_symptomatic_side                        1388         0.0095         0.0689        0.0838           0.0843             0.0761        0.0308    elastic_net       0.0843
# V06KOOSFX2                                      648        -0.0042         0.1237        0.0657           0.0598             0.0553       -0.0257          ridge       0.0657
# dilkn10_symptomatic_side                       1388         0.0084         0.0367        0.0599           0.0648             0.0562       -0.0327    elastic_net       0.0648
# dirkn7_symptomatic_side                        1388         0.0137         0.0765        0.0622           0.0605             0.0310        0.0192          ridge       0.0622
#
# =============================================================================================================================================================================
# Group: adl
# =============================================================================================================================================================================
# Outcome                                     n_train    LASSO_incR²     LASSO_cvR²      Ridge_R²         ElNet_R²              RF_R²        XGB_R²           Best       BestR²
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# V06LLD10B                                      1385         0.0197         0.0711        0.1093           0.1159             0.0887        0.1557        xgboost       0.1557
# V06LLD6A                                       1386         0.0965         0.1440        0.1264           0.1141             0.1330        0.0961  random_forest       0.1330
# V06LLDILST                                     1352         0.0358         0.0600        0.0665           0.0680             0.0534        0.0303    elastic_net       0.0680
# V06LLD6B                                       1381         0.0345         0.0777        0.0358           0.0290             0.0552       -0.0139  random_forest       0.0552
#
# =============================================================================================================================================================================
# Group: pain
# =============================================================================================================================================================================
# Outcome                                     n_train    LASSO_incR²     LASSO_cvR²      Ridge_R²         ElNet_R²              RF_R²        XGB_R²           Best       BestR²
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# koos_pain_symptomatic_side                     1388         0.0153         0.1354        0.1368           0.1426             0.1078        0.1061    elastic_net       0.1426
# icoap_total_symptomatic_side                   1386         0.0069         0.0835        0.1308           0.1330             0.1080        0.1005    elastic_net       0.1330
# pain_7day_symptomatic_side                     1383         0.0226         0.0928        0.1245           0.1315             0.0764        0.0676    elastic_net       0.1315
# global_rating_symptomatic_side                 1388         0.0137         0.0942        0.0889           0.0903             0.0457       -0.0122    elastic_net       0.0903
# pain_bed_symptomatic_side                      1388         0.0034         0.0468        0.0674           0.0761             0.0755        0.0642    elastic_net       0.0761
#
# Comparison table saved to: stage_7_model_comparison.csv
# Total outcomes compared: 31

# %% [markdown]
# #### KL grade classification summary

# %%
print(f"\n{'=' * 70}")
print("KL grade classification (Stage 6)")
print(f"{'=' * 70}")
print(
    f"\n{'Model':<20} {'CV kappa':>12} {'Test kappa':>12} "
    f"{'Accuracy':>12} {'MAE grade':>12}"
)
print("-" * 70)

for model_name, result in kl_grade_results.items():
    print(
        f"{model_name.replace('_', ' ').title():<20} "
        f"{result['cross_validated_kappa']:>12.4f} "
        f"{result['test_kappa']:>12.4f} "
        f"{result['test_accuracy']:>12.4f} "
        f"{result['test_mean_absolute_error_grade']:>12.4f}"
    )
# Out:
# ======================================================================
# KL grade classification (Stage 6)
# ======================================================================
#
# Model                    CV kappa   Test kappa     Accuracy    MAE grade
# ----------------------------------------------------------------------
# Random Forest              0.2085       0.2556       0.2874       1.2270
# Xgboost                    0.1496       0.2368       0.2730       1.1983

# %% [markdown]
# # 3. Longitudinal prediction preparation

# %% [markdown]
# ## 3.1 Outcome selection
#
# Filters the 2.3 comparison table to the outcomes that carry enough signal to be worth validating longitudinally.
# 1. R² threshold: test R² ≥ 0.1 in at least one model family (Stages 2–5). This ensures we only attempt longitudinal prediction for outcomes where the activity predictors explain a meaningful portion of variance in the held-out test set.
# 2. 400m walk test outcomes are excluded because they are only measured at baseline and therefore cannot be predicted longitudinally.

# %%
MINIMUM_TEST_R2_FOR_VALIDATION = 0.10

EXCLUDED_OUTCOMES_400M = {"V06400MTIM"}

outcomes_above_threshold = comparison_table[
    comparison_table["best_test_r2"] > MINIMUM_TEST_R2_FOR_VALIDATION
].copy()

outcomes_after_exclusion = outcomes_above_threshold[
    ~outcomes_above_threshold["outcome"].isin(EXCLUDED_OUTCOMES_400M)
].copy()

print(
    f"Outcome selection for longitudinal validation\n"
    f"  Total outcomes modelled        : {len(comparison_table)}\n"
    f"  Above R² threshold (> "
    f"{MINIMUM_TEST_R2_FOR_VALIDATION:.2f})       : "
    f"{len(outcomes_above_threshold)}\n"
    f"  After 400m walk exclusion      : {len(outcomes_after_exclusion)}\n"
    f"  Excluded (below threshold)     : "
    f"{len(comparison_table) - len(outcomes_above_threshold)}\n"
    f"  Excluded (400m walk)           : "
    f"{len(outcomes_above_threshold) - len(outcomes_after_exclusion)}"
)
# Out:
# Outcome selection for longitudinal validation
#   Total outcomes modelled        : 31
#   Above R² threshold (> 0.10)       : 21
#   After 400m walk exclusion      : 20
#   Excluded (below threshold)     : 10
#   Excluded (400m walk)           : 1

# %% [markdown]
# ## 3.2 Longitudinal model specification
#
# For each selected outcome the winning model family (highest test R² among Ridge, Elastic Net, Random Forest, XGBoost) is refitted using the same hyperparameters on the full baseline dataset (no train/test split). Only that model will be re-fitted on the full Visit 06 training set and used to generate Visit 08 predictions during the longitudinal validation phase.

# %%
LONGITUDINAL_VALIDATION_OUTCOMES: dict[str, dict] = {
    row["outcome"]: {
        "group": row["group"],
        "best_model": row["best_model"],
        "best_test_r2": row["best_test_r2"],
        "lasso_incremental_r2": row["lasso_incremental_r2"],
        "n_training": int(row["n_training"]),
    }
    for _, row in outcomes_after_exclusion.iterrows()
}

print(f"\nSelected outcomes ({len(LONGITUDINAL_VALIDATION_OUTCOMES)} total):\n")
print(
    f"  {'Outcome':<45} {'Group':<25} "
    f"{'Best model':<15} {'Test R²':>8} {'LASSO ΔR²':>10}"
)
print("  " + "-" * 105)

current_group = None

for outcome_column, metadata in sorted(
    LONGITUDINAL_VALIDATION_OUTCOMES.items(),
    key=lambda item: (item[1]["group"], -item[1]["best_test_r2"]),
):
    if metadata["group"] != current_group:
        current_group = metadata["group"]
        print(f"\n  [{current_group.upper()}]")

    print(
        f"  {outcome_column:<45} {metadata['group']:<25} "
        f"{metadata['best_model']:<15} "
        f"{metadata['best_test_r2']:>8.4f} "
        f"{metadata['lasso_incremental_r2']:>10.4f}"
    )
# Out:
# Selected outcomes (20 total):
#
#   Outcome                                       Group                     Best model       Test R²  LASSO ΔR²
#   ---------------------------------------------------------------------------------------------------------
#
#   [ADL]
#   V06LLD10B                                     adl                       xgboost           0.1557     0.0197
#   V06LLD6A                                      adl                       random_forest     0.1330     0.0965
#
#   [FUNCTION]
#   V06STEPST1                                    function                  xgboost           0.3879     0.0916
#   V0620MPACE                                    function                  random_forest     0.3468     0.0531
#
#   [PAIN]
#   koos_pain_symptomatic_side                    pain                      elastic_net       0.1426     0.0153
#   icoap_total_symptomatic_side                  pain                      elastic_net       0.1330     0.0069
#   pain_7day_symptomatic_side                    pain                      elastic_net       0.1315     0.0226
#
#   [SELF_REPORTED_FUNCTION]
#   dirkn1_symptomatic_side                       self_reported_function    ridge             0.1712     0.0151
#   dirkn5_symptomatic_side                       self_reported_function    elastic_net       0.1682     0.0157
#   dirkn2_symptomatic_side                       self_reported_function    elastic_net       0.1521     0.0211
#   dirkn13_symptomatic_side                      self_reported_function    ridge             0.1399     0.0164
#   dirkn8_symptomatic_side                       self_reported_function    ridge             0.1305     0.0216
#   dirkn3_symptomatic_side                       self_reported_function    elastic_net       0.1284     0.0137
#   V06KOOSFX4                                    self_reported_function    ridge             0.1246    -0.0110
#   dirkn15_symptomatic_side                      self_reported_function    ridge             0.1161     0.0083
#   dirkn4_symptomatic_side                       self_reported_function    elastic_net       0.1139     0.0059
#   V06KOOSFX1                                    self_reported_function    elastic_net       0.1075     0.0106
#   dirkn6_symptomatic_side                       self_reported_function    elastic_net       0.1049     0.0128
#   dirkn17_symptomatic_side                      self_reported_function    elastic_net       0.1019     0.0245
#   dirkn16_symptomatic_side                      self_reported_function    elastic_net       0.1013     0.0069

# %% [markdown]
# # 3 Longitudinal prediction

# %%
summary_metrics_08 = pd.read_csv("data/output/08_output/summary_metrics_08.csv", sep="|", na_values=[" ", ""],)

# %% [markdown]
# ## 3.3 Refit winning models on full Visit 06 dataset
#
# For each outcome selected for longitudinal validation, the winning model
# family is refitted on the complete Visit 06 dataset (training and test
# combined). The fitted model and its StandardScaler are stored in memory
# for direct use in the Visit 08 prediction step that follows.
#
# No train/test split is applied here. The held-out test set R² from
# Stage 7 already provides the unbiased performance estimate. Refitting
# on the full dataset maximises the training signal available to the model
# before it is asked to generalise to Visit 08.

# %%
def refit_winning_model_on_full_visit_06(
        *,
        outcome_column: str,
        best_model: str,
        dataframe: pd.DataFrame,
        activity_predictor_columns: list[str],
        demographic_covariate_columns: list[str],
        structural_covariate_column: str,
        ridge_results: dict[str, list[dict]],
        elastic_net_results: dict[str, list[dict]],
        random_forest_results: dict[str, list[dict]],
        xgboost_results: dict[str, list[dict]],
        random_state: int = 42,
) -> dict:
    """
    Refit the winning model family for a single outcome on the full
    Visit 06 dataset (no train/test split).

    The scaler is fitted on the full Visit 06 predictor matrix and
    stored alongside the model so that the same transformation can
    be applied to Visit 08 data without refitting.

    Hyperparameters are taken directly from the in-memory result
    dictionaries produced during Stages 2–5, so no cross-validation
    or grid search is repeated here.

    :param outcome_column: Name of the outcome variable to model.
    :param best_model: Winning model family name. One of ``"ridge"``,
        ``"elastic_net"``, ``"random_forest"``, or ``"xgboost"``.
    :param dataframe: Full Visit 06 modelling dataframe with one row
        per participant.
    :param activity_predictor_columns: Activity predictor column names.
    :param demographic_covariate_columns: Demographic covariate column
        names.
    :param structural_covariate_column: KL grade column name.
    :param ridge_results: In-memory Ridge results from Stage 2.
    :param elastic_net_results: In-memory Elastic Net results from Stage 3.
    :param random_forest_results: In-memory Random Forest results from Stage 4.
    :param xgboost_results: In-memory XGBoost results from Stage 5.
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys ``outcome_column``, ``best_model``,
        ``fitted_model``, ``scaler`` (or None for tree-based models),
        ``covariate_columns``, ``activity_predictor_columns``,
        and ``n_fitted``.
    :raises ValueError: If ``best_model`` is not a recognised model family.
    """
    covariate_columns = list(demographic_covariate_columns) + [structural_covariate_column]
    all_required_columns = covariate_columns + activity_predictor_columns + [outcome_column]

    complete_cases = dataframe[all_required_columns].dropna()
    number_of_complete_cases = len(complete_cases)

    print(
        f"  Refitting on full Visit 06 — {number_of_complete_cases:,} complete cases"
    )

    outcome_series = complete_cases[outcome_column]
    covariate_matrix = complete_cases[covariate_columns].values
    activity_matrix = complete_cases[activity_predictor_columns].values

    # Flatten result lists into outcome-keyed lookups
    ridge_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in ridge_results.values()
        for result in group_results
    }
    elastic_net_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in elastic_net_results.values()
        for result in group_results
    }
    xgboost_lookup: dict[str, dict] = {
        str(result["outcome_column"]): result
        for group_results in xgboost_results.values()
        for result in group_results
    }

    if best_model == "ridge":
        optimal_alpha = ridge_lookup[outcome_column]["optimal_alpha"]

        scaler = StandardScaler()
        activity_matrix_scaled = scaler.fit_transform(activity_matrix)
        full_matrix = np.hstack([covariate_matrix, activity_matrix_scaled])

        fitted_model = Ridge(alpha=optimal_alpha)
        fitted_model.fit(full_matrix, outcome_series)

        print(f"  Ridge — alpha={optimal_alpha:.6f}")

    elif best_model == "elastic_net":
        result = elastic_net_lookup[outcome_column]
        optimal_alpha = result["optimal_alpha"]
        optimal_l1_ratio = result["optimal_l1_ratio"]

        scaler = StandardScaler()
        activity_matrix_scaled = scaler.fit_transform(activity_matrix)
        full_matrix = np.hstack([covariate_matrix, activity_matrix_scaled])

        from sklearn.linear_model import ElasticNet
        fitted_model = ElasticNet(
            alpha=optimal_alpha,
            l1_ratio=optimal_l1_ratio,
            max_iter=50_000,
        )
        fitted_model.fit(full_matrix, outcome_series)

        print(
            f"  Elastic Net — alpha={optimal_alpha:.6f}, "
            f"l1_ratio={optimal_l1_ratio:.2f}"
        )

    elif best_model == "random_forest":
        scaler = None
        all_predictor_columns = covariate_columns + activity_predictor_columns
        full_matrix = complete_cases[all_predictor_columns].values

        fitted_model = RandomForestRegressor(
            n_estimators=500,
            max_depth=None,
            min_samples_leaf=10,
            n_jobs=-1,
            random_state=random_state,
        )
        fitted_model.fit(full_matrix, outcome_series)

        print("  Random Forest — n_estimators=500, min_samples_leaf=10")

    elif best_model == "xgboost":
        result = xgboost_lookup[outcome_column]
        best_hyperparameters = result["best_hyperparameters"]

        scaler = None
        all_predictor_columns = covariate_columns + activity_predictor_columns
        full_matrix = complete_cases[all_predictor_columns].values

        fitted_model = xgboost.XGBRegressor(
            n_estimators=500,
            max_depth=best_hyperparameters["max_depth"],
            learning_rate=best_hyperparameters["learning_rate"],
            subsample=0.8,
            colsample_bytree=0.8,
            objective="reg:squarederror",
            random_state=random_state,
            n_jobs=-1,
            verbosity=0,
        )
        fitted_model.fit(full_matrix, outcome_series)

        print(
            f"  XGBoost — max_depth={best_hyperparameters['max_depth']}, "
            f"learning_rate={best_hyperparameters['learning_rate']}"
        )

    else:
        raise ValueError(
            f"Unrecognised model family '{best_model}'. Expected one of: "
            f"ridge, elastic_net, random_forest, xgboost."
        )

    return {
        "outcome_column": outcome_column,
        "best_model": best_model,
        "fitted_model": fitted_model,
        "scaler": scaler,
        "covariate_columns": covariate_columns,
        "activity_predictor_columns": activity_predictor_columns,
        "n_fitted": number_of_complete_cases,
    }


#### Execute refit for all selected outcomes
refitted_models: dict[str, dict] = {}

for outcome_column, outcome_metadata in LONGITUDINAL_VALIDATION_OUTCOMES.items():
    print(f"\n{'=' * 60}")
    print(f"Outcome: {outcome_column}  [{outcome_metadata['best_model']}]")
    print(f"{'=' * 60}")

    refitted_models[outcome_column] = refit_winning_model_on_full_visit_06(
        outcome_column=outcome_column,
        best_model=outcome_metadata["best_model"],
        dataframe=summary_metrics_06,
        activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
        demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
        structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
        ridge_results=ridge_results,
        elastic_net_results=elastic_net_results,
        random_forest_results=random_forest_results,
        xgboost_results=xgboost_results,
        random_state=RANDOM_STATE,
    )

print(
    f"\nRefit complete — {len(refitted_models)} models ready for "
    f"Visit 08 prediction."
)
# Out:
# ============================================================
# Outcome: V06STEPST1  [xgboost]
# ============================================================
#   Refitting on full Visit 06 — 1,705 complete cases
#   XGBoost — max_depth=3, learning_rate=0.03
#
# ============================================================
# Outcome: V0620MPACE  [random_forest]
# ============================================================
#   Refitting on full Visit 06 — 1,705 complete cases
#   Random Forest — n_estimators=500, min_samples_leaf=10
#
# ============================================================
# Outcome: dirkn1_symptomatic_side  [ridge]
# ============================================================
#   Refitting on full Visit 06 — 1,730 complete cases
#   Ridge — alpha=316.227766
#
# ============================================================
# Outcome: dirkn5_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,677 complete cases
#   Elastic Net — alpha=0.010254, l1_ratio=1.00
#
# ============================================================
# Outcome: V06LLD10B  [xgboost]
# ============================================================
#   Refitting on full Visit 06 — 1,732 complete cases
#   XGBoost — max_depth=3, learning_rate=0.03
#
# ============================================================
# Outcome: dirkn2_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,729 complete cases
#   Elastic Net — alpha=0.056448, l1_ratio=0.30
#
# ============================================================
# Outcome: koos_pain_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,736 complete cases
#   Elastic Net — alpha=0.336356, l1_ratio=1.00
#
# ============================================================
# Outcome: dirkn13_symptomatic_side  [ridge]
# ============================================================
#   Refitting on full Visit 06 — 1,437 complete cases
#   Ridge — alpha=316.227766
#
# ============================================================
# Outcome: icoap_total_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,733 complete cases
#   Elastic Net — alpha=0.259137, l1_ratio=0.70
#
# ============================================================
# Outcome: V06LLD6A  [random_forest]
# ============================================================
#   Refitting on full Visit 06 — 1,733 complete cases
#   Random Forest — n_estimators=500, min_samples_leaf=10
#
# ============================================================
# Outcome: pain_7day_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,729 complete cases
#   Elastic Net — alpha=0.060765, l1_ratio=0.70
#
# ============================================================
# Outcome: dirkn8_symptomatic_side  [ridge]
# ============================================================
#   Refitting on full Visit 06 — 1,730 complete cases
#   Ridge — alpha=316.227766
#
# ============================================================
# Outcome: dirkn3_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,736 complete cases
#   Elastic Net — alpha=0.055286, l1_ratio=0.10
#
# ============================================================
# Outcome: V06KOOSFX4  [ridge]
# ============================================================
#   Refitting on full Visit 06 — 1,430 complete cases
#   Ridge — alpha=316.227766
#
# ============================================================
# Outcome: dirkn15_symptomatic_side  [ridge]
# ============================================================
#   Refitting on full Visit 06 — 1,735 complete cases
#   Ridge — alpha=316.227766
#
# ============================================================
# Outcome: dirkn4_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,736 complete cases
#   Elastic Net — alpha=0.130227, l1_ratio=0.10
#
# ============================================================
# Outcome: V06KOOSFX1  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,434 complete cases
#   Elastic Net — alpha=0.186193, l1_ratio=0.10
#
# ============================================================
# Outcome: dirkn6_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,736 complete cases
#   Elastic Net — alpha=0.012626, l1_ratio=1.00
#
# ============================================================
# Outcome: dirkn17_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,733 complete cases
#   Elastic Net — alpha=0.079809, l1_ratio=0.10
#
# ============================================================
# Outcome: dirkn16_symptomatic_side  [elastic_net]
# ============================================================
#   Refitting on full Visit 06 — 1,640 complete cases
#   Elastic Net — alpha=0.029587, l1_ratio=0.50
#
# Refit complete — 20 models ready for Visit 08 prediction.

# %% [markdown]
# ## 3.4 Prepare Visit 08 dataset
#
# Applies the same derivations to Visit 08 that were applied to Visit 06:
# - employment_working binary column
# - Symptomatic-side outcome columns via derive_symptomatic_side_outcome
#
# The BILATERAL_PAIRS_* dictionaries and derive_symptomatic_side_outcome
# function are reused without modification.

# %%
summary_metrics_08 = summary_metrics_08.reset_index() if "ID" not in summary_metrics_08.columns else summary_metrics_08

summary_metrics_08["employment_working"] = summary_metrics_08["employment_group"].map(
    {"working": 1.0, "not working": 0.0}
)

def swap_visit_prefix(column_name: str | None, target_prefix: str = "V08") -> str | None:
    """
    Replace the V06 prefix in a column name with the target visit prefix.

    :param column_name: Original column name, or None for single-side variables.
    :param target_prefix: Visit prefix to substitute in (default ``"V08"``).
    :returns: Column name with V06 replaced by target_prefix, or None.
    """
    if column_name is None:
        return None
    return column_name.replace("V06", target_prefix)

for output_column, (right_column, left_column) in BILATERAL_PAIRS_LOWER_IS_WORSE.items():
    summary_metrics_08 = derive_symptomatic_side_outcome(
        dataframe=summary_metrics_08,
        output_column=output_column,
        right_column=swap_visit_prefix(right_column),
        left_column=swap_visit_prefix(left_column),
        higher_is_worse=False,
    )

for output_column, (right_column, left_column) in BILATERAL_PAIRS_HIGHER_IS_WORSE.items():
    summary_metrics_08 = derive_symptomatic_side_outcome(
        dataframe=summary_metrics_08,
        output_column=output_column,
        right_column=swap_visit_prefix(right_column),
        left_column=swap_visit_prefix(left_column),
        higher_is_worse=True,
    )

print(
    f"Visit 08 dataset ready:\n"
    f"  Shape        : {summary_metrics_08.shape}\n"
    f"  Participants : {len(summary_metrics_08):,}"
)
# Out:
# Visit 08 dataset ready:
#   Shape        : (1005, 148)
#   Participants : 1,005
# /var/folders/cs/bm2yt5mj1c9ffjcq4b73z9240000gn/T/ipykernel_22614/3575718552.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   summary_metrics_08["employment_working"] = summary_metrics_08["employment_group"].map(

# %% [markdown]
# ## 3.5 Match Visit 06 and Visit 08 participants
#
# Inner join on participant ID to retain only participants with complete
# data at both visits. The Visit 06 observed outcome values are carried
# forward as the baseline for direction-of-change computation.

# %%
paired_dataframe = summary_metrics_06.merge(
    summary_metrics_08,
    on="ID",
    suffixes=("_v06", "_v08"),
)

print(
    f"Matched participants:\n"
    f"  Visit 06     : {len(summary_metrics_06):,}\n"
    f"  Visit 08     : {len(summary_metrics_08):,}\n"
    f"  Paired       : {len(paired_dataframe):,}"
)
# Out:
# Matched participants:
#   Visit 06     : 1,845
#   Visit 08     : 1,005
#   Paired       : 948

# %% [markdown]
# ## 3.6 Longitudinal prediction and direction-of-change evaluation
#
# For each outcome in refitted_models:
# 1. The Visit 08 predictor matrix is assembled from the paired dataframe
#    using the same covariate and activity predictor columns as Visit 06.
# 2. The scaler fitted on Visit 06 is applied to activity predictors
#    without refitting (linear models only).
# 3. Predictions are generated for Visit 08.
# 4. Direction-of-change accuracy is computed: whether the predicted
#    direction of change from Visit 06 to Visit 08 matches the actual
#    direction.

# %%
def evaluate_longitudinal_predictions(
    *,
    outcome_column: str,
    refitted_model_bundle: dict,
    paired_dataframe: pd.DataFrame,
) -> dict:
    """
    Generate Visit 08 predictions for a single outcome and evaluate
    direction-of-change accuracy against observed Visit 08 values.

    The Visit 08 predictor matrix is assembled using the covariate and
    activity predictor columns stored in the refitted model bundle. For
    linear models the Visit 06 scaler is applied to activity predictors.
    For tree-based models no scaling is applied.

    Direction-of-change accuracy is the proportion of participants for
    whom the predicted direction of change (predicted Visit 08 minus
    observed Visit 06) matches the actual direction of change (observed
    Visit 08 minus observed Visit 06). Participants with no change at
    Visit 08 (actual delta = 0) are excluded from this calculation.

    :param outcome_column: Name of the outcome variable.
    :param refitted_model_bundle: Output of
        refit_winning_model_on_full_visit_06 for this outcome.
    :param paired_dataframe: Merged Visit 06 / Visit 08 dataframe with
        suffixes _v06 and _v08 on overlapping columns.
    :returns: Dictionary with keys outcome_column, n_paired,
        n_direction_evaluated, direction_of_change_accuracy,
        test_r2_visit_08, rmse_visit_08, mae_visit_08.
    """
    fitted_model = refitted_model_bundle["fitted_model"]
    scaler = refitted_model_bundle["scaler"]
    covariate_columns = refitted_model_bundle["covariate_columns"]
    activity_predictor_columns = refitted_model_bundle["activity_predictor_columns"]

    def resolve_column(column_name: str) -> str:
        """
        Return the correct column name in the paired dataframe for a
        given predictor or covariate column.

        :param column_name: Original column name before merging.
        :returns: Column name as it appears in the paired dataframe.
        """
        visit_08_column = f"{column_name}_v08"
        if visit_08_column in paired_dataframe.columns:
            return visit_08_column
        return column_name

    resolved_covariate_columns = [resolve_column(c) for c in covariate_columns]
    resolved_activity_columns = [resolve_column(c) for c in activity_predictor_columns]

    outcome_v06_column = (
        f"{outcome_column}_v06"
        if f"{outcome_column}_v06" in paired_dataframe.columns
        else outcome_column.replace("V06", "V06")  # already V06, no change needed
    )
    outcome_v08_column = (
        f"{outcome_column}_v08"
        if f"{outcome_column}_v08" in paired_dataframe.columns
        else outcome_column.replace("V06", "V08")  # swap prefix for Visit 08
    )

    all_required_columns = (
        resolved_covariate_columns
        + resolved_activity_columns
        + [outcome_v06_column, outcome_v08_column]
    )

    complete_cases = paired_dataframe[all_required_columns].dropna()
    number_of_complete_cases = len(complete_cases)

    print(f"  Complete paired cases : {number_of_complete_cases:,}")

    covariate_matrix = complete_cases[resolved_covariate_columns].values
    activity_matrix = complete_cases[resolved_activity_columns].values

    if scaler is not None:
        activity_matrix_scaled = scaler.transform(activity_matrix)
        full_matrix = np.hstack([covariate_matrix, activity_matrix_scaled])
    else:
        full_matrix = np.hstack([covariate_matrix, activity_matrix])

    visit_08_predictions = fitted_model.predict(full_matrix)
    observed_visit_06 = complete_cases[outcome_v06_column].values
    observed_visit_08 = complete_cases[outcome_v08_column].values

    test_r2_visit_08 = r2_score(observed_visit_08, visit_08_predictions)
    rmse_visit_08 = float(np.sqrt(mean_squared_error(observed_visit_08, visit_08_predictions)))
    mae_visit_08 = float(mean_absolute_error(observed_visit_08, visit_08_predictions))

    actual_delta = observed_visit_08 - observed_visit_06
    predicted_delta = visit_08_predictions - observed_visit_06

    non_zero_change_mask = actual_delta != 0
    number_direction_evaluated = int(non_zero_change_mask.sum())

    direction_of_change_accuracy = float(
        np.mean(
            np.sign(predicted_delta[non_zero_change_mask])
            == np.sign(actual_delta[non_zero_change_mask])
        )
    )

    print(
        f"  Visit 08 R²                    : {test_r2_visit_08:.4f}\n"
        f"  Visit 08 RMSE                  : {rmse_visit_08:.4f}\n"
        f"  Visit 08 MAE                   : {mae_visit_08:.4f}\n"
        f"  Direction-of-change accuracy   : {direction_of_change_accuracy:.4f} "
        f"(n={number_direction_evaluated})"
    )

    return {
        "outcome_column": outcome_column,
        "n_paired": number_of_complete_cases,
        "n_direction_evaluated": number_direction_evaluated,
        "direction_of_change_accuracy": direction_of_change_accuracy,
        "test_r2_visit_08": test_r2_visit_08,
        "rmse_visit_08": rmse_visit_08,
        "mae_visit_08": mae_visit_08,
    }

# %% [markdown]
# #### Execute longitudinal evaluation for all selected outcomes

# %%
longitudinal_results: list[dict] = []

for outcome_column, refitted_model_bundle in refitted_models.items():
    print(f"\n{'=' * 60}")
    print(f"Outcome: {outcome_column}  [{refitted_model_bundle['best_model']}]")
    print(f"{'=' * 60}")

    try:
        result = evaluate_longitudinal_predictions(
            outcome_column=outcome_column,
            refitted_model_bundle=refitted_model_bundle,
            paired_dataframe=paired_dataframe,
        )
        longitudinal_results.append(result)

    except Exception as error:
        print(f"  Skipped: {error}")
# Out:
# ============================================================
# Outcome: V06STEPST1  [xgboost]
# ============================================================
#   Complete paired cases : 878
#   Visit 08 R²                    : 0.3715
#   Visit 08 RMSE                  : 3.0201
#   Visit 08 MAE                   : 2.3001
#   Direction-of-change accuracy   : 0.6391 (n=676)
#
# ============================================================
# Outcome: V0620MPACE  [random_forest]
# ============================================================
#   Complete paired cases : 878
#   Visit 08 R²                    : 0.3097
#   Visit 08 RMSE                  : 0.1654
#   Visit 08 MAE                   : 0.1270
#   Direction-of-change accuracy   : 0.6326 (n=871)
#
# ============================================================
# Outcome: dirkn1_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 901
#   Visit 08 R²                    : 0.0520
#   Visit 08 RMSE                  : 0.8009
#   Visit 08 MAE                   : 0.6508
#   Direction-of-change accuracy   : 0.8343 (n=338)
#
# ============================================================
# Outcome: dirkn5_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 851
#   Visit 08 R²                    : -0.0152
#   Visit 08 RMSE                  : 0.8975
#   Visit 08 MAE                   : 0.7219
#   Direction-of-change accuracy   : 0.8287 (n=356)
#
# ============================================================
# Outcome: V06LLD10B  [xgboost]
# ============================================================
#   Complete paired cases : 898
#   Visit 08 R²                    : 0.0084
#   Visit 08 RMSE                  : 0.8990
#   Visit 08 MAE                   : 0.7357
#   Direction-of-change accuracy   : 0.7922 (n=361)
#
# ============================================================
# Outcome: dirkn2_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 900
#   Visit 08 R²                    : 0.0626
#   Visit 08 RMSE                  : 0.8532
#   Visit 08 MAE                   : 0.6864
#   Direction-of-change accuracy   : 0.8225 (n=355)
#
# ============================================================
# Outcome: koos_pain_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0771
#   Visit 08 RMSE                  : 14.9491
#   Visit 08 MAE                   : 12.0248
#   Direction-of-change accuracy   : 0.6394 (n=710)
#
# ============================================================
# Outcome: dirkn13_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 673
#   Visit 08 R²                    : 0.0365
#   Visit 08 RMSE                  : 0.6560
#   Visit 08 MAE                   : 0.4582
#   Direction-of-change accuracy   : 0.8633 (n=139)
#
# ============================================================
# Outcome: icoap_total_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 887
#   Visit 08 R²                    : 0.0547
#   Visit 08 RMSE                  : 9.6572
#   Visit 08 MAE                   : 7.3318
#   Direction-of-change accuracy   : 0.6747 (n=584)
#
# ============================================================
# Outcome: V06LLD6A  [random_forest]
# ============================================================
#   Complete paired cases : 899
#   Visit 08 R²                    : 0.1521
#   Visit 08 RMSE                  : 1.0738
#   Visit 08 MAE                   : 0.8714
#   Direction-of-change accuracy   : 0.7812 (n=457)
#
# ============================================================
# Outcome: pain_7day_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 900
#   Visit 08 R²                    : 0.0688
#   Visit 08 RMSE                  : 2.5225
#   Visit 08 MAE                   : 2.0815
#   Direction-of-change accuracy   : 0.6931 (n=606)
#
# ============================================================
# Outcome: dirkn8_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 885
#   Visit 08 R²                    : 0.0272
#   Visit 08 RMSE                  : 0.5953
#   Visit 08 MAE                   : 0.4501
#   Direction-of-change accuracy   : 0.8830 (n=188)
#
# ============================================================
# Outcome: dirkn3_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0419
#   Visit 08 RMSE                  : 0.7956
#   Visit 08 MAE                   : 0.6510
#   Direction-of-change accuracy   : 0.8344 (n=320)
#
# ============================================================
# Outcome: V06KOOSFX4  [ridge]
# ============================================================
#   Complete paired cases : 689
#   Visit 08 R²                    : 0.0581
#   Visit 08 RMSE                  : 0.8863
#   Visit 08 MAE                   : 0.7075
#   Direction-of-change accuracy   : 0.8244 (n=262)
#
# ============================================================
# Outcome: dirkn15_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 902
#   Visit 08 R²                    : 0.0266
#   Visit 08 RMSE                  : 0.6564
#   Visit 08 MAE                   : 0.4983
#   Direction-of-change accuracy   : 0.8558 (n=215)
#
# ============================================================
# Outcome: dirkn4_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0495
#   Visit 08 RMSE                  : 0.6089
#   Visit 08 MAE                   : 0.4547
#   Direction-of-change accuracy   : 0.9104 (n=212)
#
# ============================================================
# Outcome: V06KOOSFX1  [elastic_net]
# ============================================================
#   Complete paired cases : 689
#   Visit 08 R²                    : 0.0165
#   Visit 08 RMSE                  : 0.9400
#   Visit 08 MAE                   : 0.7767
#   Direction-of-change accuracy   : 0.7993 (n=284)
#
# ============================================================
# Outcome: dirkn6_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0322
#   Visit 08 RMSE                  : 0.5761
#   Visit 08 MAE                   : 0.4312
#   Direction-of-change accuracy   : 0.9113 (n=203)
#
# ============================================================
# Outcome: dirkn17_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 898
#   Visit 08 R²                    : 0.0348
#   Visit 08 RMSE                  : 0.5424
#   Visit 08 MAE                   : 0.4009
#   Direction-of-change accuracy   : 0.9148 (n=176)
#
# ============================================================
# Outcome: dirkn16_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 841
#   Visit 08 R²                    : 0.0223
#   Visit 08 RMSE                  : 0.7608
#   Visit 08 MAE                   : 0.6085
#   Direction-of-change accuracy   : 0.8630 (n=292)

# %% [markdown]
# #### Longitudinal validation summary table

# %%
longitudinal_summary_table = (
    pd.DataFrame(longitudinal_results)
    .sort_values("direction_of_change_accuracy", ascending=False)
    .reset_index(drop=True)
)

longitudinal_summary_table.to_csv(
    output_path / "stage_9_longitudinal_validation.csv",
    index=False,
)

print("\nStage 9 — Longitudinal validation summary (sorted by direction-of-change accuracy):")
print(longitudinal_summary_table.to_string(index=False))
# Out:
# Stage 9 — Longitudinal validation summary (sorted by direction-of-change accuracy):
#               outcome_column  n_paired  n_direction_evaluated  direction_of_change_accuracy  test_r2_visit_08  rmse_visit_08  mae_visit_08
#     dirkn17_symptomatic_side       898                    176                      0.914773          0.034809       0.542384      0.400878
#      dirkn6_symptomatic_side       903                    203                      0.911330          0.032184       0.576081      0.431151
#      dirkn4_symptomatic_side       903                    212                      0.910377          0.049484       0.608947      0.454655
#      dirkn8_symptomatic_side       885                    188                      0.882979          0.027247       0.595290      0.450114
#     dirkn13_symptomatic_side       673                    139                      0.863309          0.036493       0.655968      0.458235
#     dirkn16_symptomatic_side       841                    292                      0.863014          0.022283       0.760805      0.608518
#     dirkn15_symptomatic_side       902                    215                      0.855814          0.026584       0.656437      0.498347
#      dirkn3_symptomatic_side       903                    320                      0.834375          0.041886       0.795603      0.651021
#      dirkn1_symptomatic_side       901                    338                      0.834320          0.051968       0.800853      0.650789
#      dirkn5_symptomatic_side       851                    356                      0.828652         -0.015192       0.897501      0.721939
#                   V06KOOSFX4       689                    262                      0.824427          0.058145       0.886347      0.707477
#      dirkn2_symptomatic_side       900                    355                      0.822535          0.062613       0.853183      0.686411
#                   V06KOOSFX1       689                    284                      0.799296          0.016465       0.939952      0.776702
#                    V06LLD10B       898                    361                      0.792244          0.008361       0.898995      0.735683
#                     V06LLD6A       899                    457                      0.781182          0.152132       1.073842      0.871399
#   pain_7day_symptomatic_side       900                    606                      0.693069          0.068780       2.522506      2.081450
# icoap_total_symptomatic_side       887                    584                      0.674658          0.054670       9.657249      7.331833
#   koos_pain_symptomatic_side       903                    710                      0.639437          0.077054      14.949115     12.024768
#                   V06STEPST1       878                    676                      0.639053          0.371520       3.020075      2.300124
#                   V0620MPACE       878                    871                      0.632606          0.309660       0.165391      0.127032

# %% [markdown]
# ## 3.7 Refit KL grade classifiers on full Visit 06 dataset
#
# Refits both the Random Forest and XGBoost classifiers from Stage 6 on
# the complete Visit 06 dataset (no train/test split) in preparation for
# longitudinal KL grade prediction at Visit 08.
#
# KL grade is excluded from the covariate block to prevent data leakage,
# consistent with Stage 6. Class imbalance is handled via balanced class
# weights (Random Forest) and inverse frequency sample weights (XGBoost).

# %%
def refit_kl_grade_classifier_on_full_visit_06(
    *,
    dataframe: pd.DataFrame,
    activity_predictor_columns: list[str],
    demographic_covariate_columns: list[str],
    structural_covariate_column: str,
    model_name: str,
    random_state: int = 42,
) -> dict:
    """
    Refit a KL grade classifier on the full Visit 06 dataset.

    No train/test split is applied. The held-out test set kappa from
    Stage 6 already provides the unbiased performance estimate.
    Refitting on the full dataset maximises the training signal before
    generalising to Visit 08.

    :param dataframe: Full Visit 06 modelling dataframe.
    :param activity_predictor_columns: Activity predictor column names.
    :param demographic_covariate_columns: Demographic covariate column
        names. Must not contain KL grade.
    :param structural_covariate_column: KL grade column name. Used as
        the outcome — not included as a predictor.
    :param model_name: Either ``"random_forest"`` or ``"xgboost"``.
    :param random_state: Random seed for reproducibility.
    :returns: Dictionary with keys ``model_name``, ``fitted_classifier``,
        ``all_predictor_columns``, and ``n_fitted``.
    :raises ValueError: If ``model_name`` is not recognised.
    """
    if model_name not in {"random_forest", "xgboost"}:
        raise ValueError(
            f"Unrecognised model_name '{model_name}'. "
            f"Expected 'random_forest' or 'xgboost'."
        )

    all_predictor_columns = (
        list(demographic_covariate_columns) + activity_predictor_columns
    )
    all_required_columns = all_predictor_columns + [structural_covariate_column]

    complete_cases = dataframe[all_required_columns].dropna()
    number_of_complete_cases = len(complete_cases)

    print(
        f"  Refitting on full Visit 06 — {number_of_complete_cases:,} complete cases"
    )

    predictor_matrix = complete_cases[all_predictor_columns].values
    outcome_classes = complete_cases[structural_covariate_column].astype(int).values

    if model_name == "random_forest":
        fitted_classifier = RandomForestClassifier(
            n_estimators=500,
            max_depth=None,
            min_samples_leaf=10,
            class_weight="balanced",
            n_jobs=-1,
            random_state=random_state,
        )
        fitted_classifier.fit(predictor_matrix, outcome_classes)

    else:
        class_counts = np.bincount(outcome_classes)
        class_weights = len(outcome_classes) / (
            len(class_counts) * class_counts
        )
        sample_weights = class_weights[outcome_classes]

        fitted_classifier = xgboost.XGBClassifier(
            n_estimators=400,
            max_depth=4,
            learning_rate=0.05,
            subsample=0.8,
            colsample_bytree=0.8,
            objective="multi:softmax",
            num_class=int(np.max(outcome_classes)) + 1,
            random_state=random_state,
            n_jobs=-1,
            verbosity=0,
        )
        fitted_classifier.fit(
            predictor_matrix,
            outcome_classes,
            sample_weight=sample_weights,
        )

    print(f"  {model_name.replace('_', ' ').title()} refitted successfully")

    return {
        "model_name": model_name,
        "fitted_classifier": fitted_classifier,
        "all_predictor_columns": all_predictor_columns,
        "n_fitted": number_of_complete_cases,
    }

# %% [markdown]
# #### Execute KL grade classifier refit

# %%
refitted_kl_grade_classifiers: dict[str, dict] = {}

for model_name in ["random_forest", "xgboost"]:
    print(f"\n{'=' * 60}")
    print(f"Model: {model_name}")
    print(f"{'=' * 60}")

    refitted_kl_grade_classifiers[model_name] = refit_kl_grade_classifier_on_full_visit_06(
        dataframe=summary_metrics_06,
        activity_predictor_columns=FINAL_PREDICTOR_COLUMNS,
        demographic_covariate_columns=DEMOGRAPHIC_COVARIATE_COLUMNS,
        structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
        model_name=model_name,
        random_state=RANDOM_STATE,
    )

print(f"\nKL grade classifiers refitted and ready for Visit 08 prediction.")
# Out:
# ============================================================
# Model: random_forest
# ============================================================
#   Refitting on full Visit 06 — 1,736 complete cases
#   Random Forest refitted successfully
#
# ============================================================
# Model: xgboost
# ============================================================
#   Refitting on full Visit 06 — 1,736 complete cases
#   Xgboost refitted successfully
#
# KL grade classifiers refitted and ready for Visit 08 prediction.

# %% [markdown]
# ## 3.8 Longitudinal KL grade prediction and evaluation
#
# For each refitted classifier, Visit 08 KL grade is predicted from the
# Visit 08 predictor matrix. Evaluation uses:
# - Quadratic weighted kappa: primary metric, penalises distant
#   misclassifications proportionally
# - Accuracy: proportion of exact grade matches
# - Mean absolute error on the integer grade
# - Direction-of-change accuracy: whether the predicted grade change
#   direction (stable, improve, worsen) matches the actual direction

# %%
def evaluate_longitudinal_kl_grade_predictions(
    *,
    model_name: str,
    refitted_classifier_bundle: dict,
    paired_dataframe: pd.DataFrame,
    structural_covariate_column: str,
) -> dict:
    """
    Generate Visit 08 KL grade predictions and evaluate against observed
    Visit 08 KL grade values.

    Direction-of-change accuracy for KL grade is computed as the
    proportion of participants for whom the predicted direction of grade
    change (predicted V08 minus observed V06) matches the actual
    direction (observed V08 minus observed V06). Participants with no
    grade change at Visit 08 are excluded from this calculation.

    :param model_name: Name of the classifier (``"random_forest"`` or
        ``"xgboost"``).
    :param refitted_classifier_bundle: Output of
        refit_kl_grade_classifier_on_full_visit_06.
    :param paired_dataframe: Merged Visit 06 / Visit 08 dataframe with
        suffixes _v06 and _v08 on overlapping columns.
    :param structural_covariate_column: KL grade column name as it
        appears in Visit 06 (before merge suffixes are applied).
    :returns: Dictionary with keys model_name, n_paired,
        n_direction_evaluated, direction_of_change_accuracy,
        test_kappa, test_accuracy, test_mae_grade, confusion_matrix.
    """
    fitted_classifier = refitted_classifier_bundle["fitted_classifier"]
    all_predictor_columns = refitted_classifier_bundle["all_predictor_columns"]

    def resolve_column(column_name: str) -> str:
        """
        Return the correct column name in the paired dataframe for a
        given predictor column, preferring the _v08 suffixed version.

        :param column_name: Original column name before merging.
        :returns: Column name as it appears in the paired dataframe.
        """
        visit_08_column = f"{column_name}_v08"
        if visit_08_column in paired_dataframe.columns:
            return visit_08_column
        return column_name

    resolved_predictor_columns = [
        resolve_column(column) for column in all_predictor_columns
    ]

    kl_grade_v06_column = (
        f"{structural_covariate_column}_v06"
        if f"{structural_covariate_column}_v06" in paired_dataframe.columns
        else structural_covariate_column
    )
    kl_grade_v08_column = (
        f"{structural_covariate_column}_v08"
        if f"{structural_covariate_column}_v08" in paired_dataframe.columns
        else structural_covariate_column
    )

    all_required_columns = (
        resolved_predictor_columns
        + [kl_grade_v06_column, kl_grade_v08_column]
    )

    complete_cases = paired_dataframe[all_required_columns].dropna()
    number_of_complete_cases = len(complete_cases)

    print(f"  Complete paired cases : {number_of_complete_cases:,}")

    predictor_matrix = complete_cases[resolved_predictor_columns].values
    observed_kl_v06 = complete_cases[kl_grade_v06_column].astype(int).values
    observed_kl_v08 = complete_cases[kl_grade_v08_column].astype(int).values

    visit_08_predictions = fitted_classifier.predict(predictor_matrix).astype(int)

    test_kappa = cohen_kappa_score(
        y1=observed_kl_v08,
        y2=visit_08_predictions,
        weights="quadratic",
    )
    test_accuracy = accuracy_score(observed_kl_v08, visit_08_predictions)
    test_mae_grade = float(np.mean(np.abs(observed_kl_v08 - visit_08_predictions)))

    actual_delta = observed_kl_v08 - observed_kl_v06
    predicted_delta = visit_08_predictions - observed_kl_v06

    non_zero_change_mask = actual_delta != 0
    number_direction_evaluated = int(non_zero_change_mask.sum())

    direction_of_change_accuracy = float(
        np.mean(
            np.sign(predicted_delta[non_zero_change_mask])
            == np.sign(actual_delta[non_zero_change_mask])
        )
    )

    confusion_matrix = pd.crosstab(
        pd.Series(observed_kl_v08, name="actual"),
        pd.Series(visit_08_predictions, name="predicted"),
    )

    print(
        f"  Test kappa (QWK)               : {test_kappa:.4f}\n"
        f"  Test accuracy                  : {test_accuracy:.4f}\n"
        f"  Test MAE (grade)               : {test_mae_grade:.4f}\n"
        f"  Direction-of-change accuracy   : {direction_of_change_accuracy:.4f} "
        f"(n={number_direction_evaluated})\n"
        f"\n  Confusion matrix (rows: actual, columns: predicted):\n"
        f"{confusion_matrix}"
    )

    return {
        "model_name": model_name,
        "n_paired": number_of_complete_cases,
        "n_direction_evaluated": number_direction_evaluated,
        "direction_of_change_accuracy": direction_of_change_accuracy,
        "test_kappa": test_kappa,
        "test_accuracy": test_accuracy,
        "test_mae_grade": test_mae_grade,
        "confusion_matrix": confusion_matrix,
    }

# %% [markdown]
# #### Execute longitudinal KL grade evaluation

# %%
longitudinal_kl_grade_results: dict[str, dict] = {}

for model_name, refitted_classifier_bundle in refitted_kl_grade_classifiers.items():
    print(f"\n{'=' * 60}")
    print(f"Model: {model_name}")
    print(f"{'=' * 60}")

    longitudinal_kl_grade_results[model_name] = evaluate_longitudinal_kl_grade_predictions(
        model_name=model_name,
        refitted_classifier_bundle=refitted_classifier_bundle,
        paired_dataframe=paired_dataframe,
        structural_covariate_column=STRUCTURAL_COVARIATE_COLUMN,
    )
# Out:
# ============================================================
# Model: random_forest
# ============================================================
#   Complete paired cases : 903
#   Test kappa (QWK)               : 0.1897
#   Test accuracy                  : 0.3189
#   Test MAE (grade)               : 1.2204
#   Direction-of-change accuracy   : 0.4800 (n=150)
#
#   Confusion matrix (rows: actual, columns: predicted):
# predicted    0   1   2   3   4
# actual
# 0          123  32  47  38  22
# 1           66  40  44  39  22
# 2           90  30  76  50  27
# 3           27  15  21  44  17
# 4            5   2  10  11   5
#
# ============================================================
# Model: xgboost
# ============================================================
#   Complete paired cases : 903
#   Test kappa (QWK)               : 0.1842
#   Test accuracy                  : 0.3422
#   Test MAE (grade)               : 1.1251
#   Direction-of-change accuracy   : 0.5600 (n=150)
#
#   Confusion matrix (rows: actual, columns: predicted):
# predicted    0   1    2   3   4
# actual
# 0          112  40   67  31  12
# 1           51  52   62  31  15
# 2           78  36  105  38  16
# 3           26  20   35  36   7
# 4            4   4   10  11   4

# %% [markdown]
# #### Longitudinal KL grade summary table

# %%
print(f"\n{'=' * 70}")
print("Longitudinal KL grade prediction summary (Visit 06 → Visit 08)")
print(f"{'=' * 70}")

print(
    f"\n{'Model':<20} {'Test kappa':>12} {'Accuracy':>12} "
    f"{'MAE grade':>12} {'Dir. accuracy':>15} {'n dir.':>8}"
)
print("-" * 80)

for model_name, result in longitudinal_kl_grade_results.items():
    print(
        f"{model_name.replace('_', ' ').title():<20} "
        f"{result['test_kappa']:>12.4f} "
        f"{result['test_accuracy']:>12.4f} "
        f"{result['test_mae_grade']:>12.4f} "
        f"{result['direction_of_change_accuracy']:>15.4f} "
        f"{result['n_direction_evaluated']:>8}"
    )
# Out:
# ======================================================================
# Longitudinal KL grade prediction summary (Visit 06 → Visit 08)
# ======================================================================
#
# Model                  Test kappa     Accuracy    MAE grade   Dir. accuracy   n dir.
# --------------------------------------------------------------------------------
# Random Forest              0.1897       0.3189       1.2204          0.4800      150
# Xgboost                    0.1842       0.3422       1.1251          0.5600      150

# %% [markdown]
# # Test

# %%
OUTCOME_HIGHER_IS_WORSE: dict[str, bool] = {
    # Pain outcomes
    "koos_pain_symptomatic_side":     False,  # KOOS: higher = better
    "icoap_total_symptomatic_side":   True,   # ICOAP: higher = worse
    "pain_7day_symptomatic_side":     True,   # Pain severity: higher = worse
    "pain_bed_symptomatic_side":      True,   # Pain in bed: higher = worse
    "global_rating_symptomatic_side": True,   # Global rating: higher = worse

    # Function outcomes
    "V0620MPACE":                     False,  # Walk pace: higher = better
    "V06CSPACE":                      False,  # Chair stand pace: higher = better
    "V06STEPST1":                     True,   # Steps: higher = worse (more steps = slower)
    "V06400MTIM":                     True,   # 400m time: higher = worse

    # ADL outcomes
    "V06LLD6B":                       True,   # LLDI limitation: higher = worse
    "V06LLD6A":                       True,   # LLDI frequency: higher = worse
    "V06LLDILST":                     True,   # LLDI total: higher = worse
    "V06LLD10B":                      True,   # LLDI fitness limitation: higher = worse

    # Self-reported function — all difficulty items: higher = worse
    "dirkn1_symptomatic_side":        True,
    "dirkn2_symptomatic_side":        True,
    "dirkn3_symptomatic_side":        True,
    "dirkn4_symptomatic_side":        True,
    "dirkn5_symptomatic_side":        True,
    "dirkn6_symptomatic_side":        True,
    "dirkn7_symptomatic_side":        True,
    "dirkn8_symptomatic_side":        True,
    "dirkn9_symptomatic_side":        True,
    "dirkn13_symptomatic_side":       True,
    "dirkn15_symptomatic_side":       True,
    "dirkn16_symptomatic_side":       True,
    "dirkn17_symptomatic_side":       True,
    "dilkn10_symptomatic_side":       True,
    "V06KOOSFX1":                     True,   # Squatting difficulty: higher = worse
    "V06KOOSFX2":                     True,   # Running difficulty: higher = worse
    "V06KOOSFX4":                     True,   # Twisting difficulty: higher = worse
    "V06KOOSFX5":                     True,   # Kneeling difficulty: higher = worse
}

# %%
def classify_trajectory(
    *,
    delta: np.ndarray,
    higher_is_worse: bool,
) -> np.ndarray:
    """
    Classify a delta array into improve, stable, or worsen categories.

    For outcomes where higher is worse (pain, difficulty items), a
    negative delta indicates improvement. For outcomes where higher is
    better (KOOS, walk pace), a positive delta indicates improvement.

    :param delta: Array of change values (Visit 08 minus Visit 06).
    :param higher_is_worse: If True, negative delta = improvement.
        If False, positive delta = improvement.
    :returns: String array with values ``"improve"``, ``"stable"``,
        or ``"worsen"``.
    """
    trajectory = np.where(delta == 0, "stable", "")

    if higher_is_worse:
        trajectory = np.where(delta < 0, "improve", trajectory)
        trajectory = np.where(delta > 0, "worsen", trajectory)
    else:
        trajectory = np.where(delta > 0, "improve", trajectory)
        trajectory = np.where(delta < 0, "worsen", trajectory)

    return trajectory


def evaluate_longitudinal_predictions(
    *,
    outcome_column: str,
    refitted_model_bundle: dict,
    paired_dataframe: pd.DataFrame,
    outcome_higher_is_worse: dict[str, bool],
) -> dict:
    """
    Generate Visit 08 predictions for a single outcome and evaluate
    direction-of-change accuracy and three-way trajectory classification
    against observed Visit 08 values.

    The Visit 08 predictor matrix is assembled using the covariate and
    activity predictor columns stored in the refitted model bundle. For
    linear models the Visit 06 scaler is applied to activity predictors.
    For tree-based models no scaling is applied.

    Direction-of-change accuracy is the proportion of participants for
    whom the predicted direction of change (predicted Visit 08 minus
    observed Visit 06) matches the actual direction of change (observed
    Visit 08 minus observed Visit 06). Participants with no change at
    Visit 08 (actual delta == 0) are excluded from this calculation.

    Three-way trajectory accuracy classifies all participants into
    improve, stable, or worsen categories based on the delta between
    visits, using the outcome-specific direction convention defined in
    outcome_higher_is_worse.

    :param outcome_column: Name of the outcome variable.
    :param refitted_model_bundle: Output of
        refit_winning_model_on_full_visit_06 for this outcome.
    :param paired_dataframe: Merged Visit 06 / Visit 08 dataframe with
        suffixes _v06 and _v08 on overlapping columns.
    :param outcome_higher_is_worse: Mapping of outcome column name to
        whether a higher value indicates worse status.
    :returns: Dictionary with keys outcome_column, n_paired,
        n_direction_evaluated, direction_of_change_accuracy,
        three_way_accuracy, trajectory_distribution,
        test_r2_visit_08, rmse_visit_08, mae_visit_08.
    :raises KeyError: If outcome_column is not found in
        outcome_higher_is_worse.
    """
    if outcome_column not in outcome_higher_is_worse:
        raise KeyError(
            f"Outcome '{outcome_column}' not found in "
            f"outcome_higher_is_worse. Add it before running."
        )

    higher_is_worse = outcome_higher_is_worse[outcome_column]

    fitted_model = refitted_model_bundle["fitted_model"]
    scaler = refitted_model_bundle["scaler"]
    covariate_columns = refitted_model_bundle["covariate_columns"]
    activity_predictor_columns = refitted_model_bundle["activity_predictor_columns"]

    def resolve_column(column_name: str) -> str:
        """
        Return the correct column name in the paired dataframe for a
        given predictor or covariate column.

        :param column_name: Original column name before merging.
        :returns: Column name as it appears in the paired dataframe.
        """
        visit_08_column = f"{column_name}_v08"
        if visit_08_column in paired_dataframe.columns:
            return visit_08_column
        return column_name

    resolved_covariate_columns = [resolve_column(c) for c in covariate_columns]
    resolved_activity_columns = [resolve_column(c) for c in activity_predictor_columns]

    outcome_v06_column = (
        f"{outcome_column}_v06"
        if f"{outcome_column}_v06" in paired_dataframe.columns
        else outcome_column
    )
    outcome_v08_column = (
        f"{outcome_column}_v08"
        if f"{outcome_column}_v08" in paired_dataframe.columns
        else outcome_column.replace("V06", "V08")
    )

    all_required_columns = (
        resolved_covariate_columns
        + resolved_activity_columns
        + [outcome_v06_column, outcome_v08_column]
    )

    complete_cases = paired_dataframe[all_required_columns].dropna()
    number_of_complete_cases = len(complete_cases)

    print(f"  Complete paired cases : {number_of_complete_cases:,}")

    covariate_matrix = complete_cases[resolved_covariate_columns].values
    activity_matrix = complete_cases[resolved_activity_columns].values

    if scaler is not None:
        activity_matrix_scaled = scaler.transform(activity_matrix)
        full_matrix = np.hstack([covariate_matrix, activity_matrix_scaled])
    else:
        full_matrix = np.hstack([covariate_matrix, activity_matrix])

    visit_08_predictions = fitted_model.predict(full_matrix)
    observed_visit_06 = complete_cases[outcome_v06_column].values
    observed_visit_08 = complete_cases[outcome_v08_column].values

    test_r2_visit_08 = r2_score(observed_visit_08, visit_08_predictions)
    rmse_visit_08 = float(np.sqrt(mean_squared_error(observed_visit_08, visit_08_predictions)))
    mae_visit_08 = float(mean_absolute_error(observed_visit_08, visit_08_predictions))

    actual_delta = observed_visit_08 - observed_visit_06
    predicted_delta = visit_08_predictions - observed_visit_06

    # Direction-of-change accuracy (excludes stable participants)
    non_zero_change_mask = actual_delta != 0
    number_direction_evaluated = int(non_zero_change_mask.sum())

    direction_of_change_accuracy = float(
        np.mean(
            np.sign(predicted_delta[non_zero_change_mask])
            == np.sign(actual_delta[non_zero_change_mask])
        )
    )

    # Three-way trajectory classification (includes all participants)
    actual_trajectory = classify_trajectory(
        delta=actual_delta,
        higher_is_worse=higher_is_worse,
    )
    predicted_trajectory = classify_trajectory(
        delta=predicted_delta,
        higher_is_worse=higher_is_worse,
    )

    three_way_accuracy = float(
        np.mean(actual_trajectory == predicted_trajectory)
    )

    trajectory_distribution = {
        category: int(np.sum(actual_trajectory == category))
        for category in ["improve", "stable", "worsen"]
    }

    print(
        f"  Visit 08 R²                    : {test_r2_visit_08:.4f}\n"
        f"  Visit 08 RMSE                  : {rmse_visit_08:.4f}\n"
        f"  Visit 08 MAE                   : {mae_visit_08:.4f}\n"
        f"  Direction-of-change accuracy   : {direction_of_change_accuracy:.4f} "
        f"(n={number_direction_evaluated})\n"
        f"  Three-way trajectory accuracy  : {three_way_accuracy:.4f} "
        f"(n={number_of_complete_cases})\n"
        f"  Actual trajectory distribution : {trajectory_distribution}"
    )

    return {
        "outcome_column": outcome_column,
        "n_paired": number_of_complete_cases,
        "n_direction_evaluated": number_direction_evaluated,
        "direction_of_change_accuracy": direction_of_change_accuracy,
        "three_way_accuracy": three_way_accuracy,
        "trajectory_distribution": trajectory_distribution,
        "test_r2_visit_08": test_r2_visit_08,
        "rmse_visit_08": rmse_visit_08,
        "mae_visit_08": mae_visit_08,
    }

# %%
longitudinal_results: list[dict] = []

for outcome_column, refitted_model_bundle in refitted_models.items():
    print(f"\n{'=' * 60}")
    print(f"Outcome: {outcome_column}  [{refitted_model_bundle['best_model']}]")
    print(f"{'=' * 60}")

    try:
        result = evaluate_longitudinal_predictions(
            outcome_column=outcome_column,
            refitted_model_bundle=refitted_model_bundle,
            paired_dataframe=paired_dataframe,
            outcome_higher_is_worse=OUTCOME_HIGHER_IS_WORSE,
        )
        longitudinal_results.append(result)

    except Exception as error:
        print(f"  Skipped: {error}")
# Out:
# ============================================================
# Outcome: V06STEPST1  [xgboost]
# ============================================================
#   Complete paired cases : 878
#   Visit 08 R²                    : 0.3715
#   Visit 08 RMSE                  : 3.0201
#   Visit 08 MAE                   : 2.3001
#   Direction-of-change accuracy   : 0.6391 (n=676)
#   Three-way trajectory accuracy  : 0.4920 (n=878)
#   Actual trajectory distribution : {'improve': 296, 'stable': 202, 'worsen': 380}
#
# ============================================================
# Outcome: V0620MPACE  [random_forest]
# ============================================================
#   Complete paired cases : 878
#   Visit 08 R²                    : 0.3097
#   Visit 08 RMSE                  : 0.1654
#   Visit 08 MAE                   : 0.1270
#   Direction-of-change accuracy   : 0.6326 (n=871)
#   Three-way trajectory accuracy  : 0.6276 (n=878)
#   Actual trajectory distribution : {'improve': 371, 'stable': 7, 'worsen': 500}
#
# ============================================================
# Outcome: dirkn1_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 901
#   Visit 08 R²                    : 0.0520
#   Visit 08 RMSE                  : 0.8009
#   Visit 08 MAE                   : 0.6508
#   Direction-of-change accuracy   : 0.8343 (n=338)
#   Three-way trajectory accuracy  : 0.3130 (n=901)
#   Actual trajectory distribution : {'improve': 145, 'stable': 563, 'worsen': 193}
#
# ============================================================
# Outcome: dirkn5_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 851
#   Visit 08 R²                    : -0.0152
#   Visit 08 RMSE                  : 0.8975
#   Visit 08 MAE                   : 0.7219
#   Direction-of-change accuracy   : 0.8287 (n=356)
#   Three-way trajectory accuracy  : 0.3467 (n=851)
#   Actual trajectory distribution : {'improve': 152, 'stable': 495, 'worsen': 204}
#
# ============================================================
# Outcome: V06LLD10B  [xgboost]
# ============================================================
#   Complete paired cases : 898
#   Visit 08 R²                    : 0.0084
#   Visit 08 RMSE                  : 0.8990
#   Visit 08 MAE                   : 0.7357
#   Direction-of-change accuracy   : 0.7922 (n=361)
#   Three-way trajectory accuracy  : 0.3185 (n=898)
#   Actual trajectory distribution : {'improve': 182, 'stable': 537, 'worsen': 179}
#
# ============================================================
# Outcome: dirkn2_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 900
#   Visit 08 R²                    : 0.0626
#   Visit 08 RMSE                  : 0.8532
#   Visit 08 MAE                   : 0.6864
#   Direction-of-change accuracy   : 0.8225 (n=355)
#   Three-way trajectory accuracy  : 0.3244 (n=900)
#   Actual trajectory distribution : {'improve': 141, 'stable': 545, 'worsen': 214}
#
# ============================================================
# Outcome: koos_pain_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0771
#   Visit 08 RMSE                  : 14.9491
#   Visit 08 MAE                   : 12.0248
#   Direction-of-change accuracy   : 0.6394 (n=710)
#   Three-way trajectory accuracy  : 0.5028 (n=903)
#   Actual trajectory distribution : {'improve': 326, 'stable': 193, 'worsen': 384}
#
# ============================================================
# Outcome: dirkn13_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 673
#   Visit 08 R²                    : 0.0365
#   Visit 08 RMSE                  : 0.6560
#   Visit 08 MAE                   : 0.4582
#   Direction-of-change accuracy   : 0.8633 (n=139)
#   Three-way trajectory accuracy  : 0.1783 (n=673)
#   Actual trajectory distribution : {'improve': 54, 'stable': 534, 'worsen': 85}
#
# ============================================================
# Outcome: icoap_total_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 887
#   Visit 08 R²                    : 0.0547
#   Visit 08 RMSE                  : 9.6572
#   Visit 08 MAE                   : 7.3318
#   Direction-of-change accuracy   : 0.6747 (n=584)
#   Three-way trajectory accuracy  : 0.4442 (n=887)
#   Actual trajectory distribution : {'improve': 277, 'stable': 303, 'worsen': 307}
#
# ============================================================
# Outcome: V06LLD6A  [random_forest]
# ============================================================
#   Complete paired cases : 899
#   Visit 08 R²                    : 0.1521
#   Visit 08 RMSE                  : 1.0738
#   Visit 08 MAE                   : 0.8714
#   Direction-of-change accuracy   : 0.7812 (n=457)
#   Three-way trajectory accuracy  : 0.3971 (n=899)
#   Actual trajectory distribution : {'improve': 251, 'stable': 442, 'worsen': 206}
#
# ============================================================
# Outcome: pain_7day_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 900
#   Visit 08 R²                    : 0.0688
#   Visit 08 RMSE                  : 2.5225
#   Visit 08 MAE                   : 2.0815
#   Direction-of-change accuracy   : 0.6931 (n=606)
#   Three-way trajectory accuracy  : 0.4667 (n=900)
#   Actual trajectory distribution : {'improve': 294, 'stable': 294, 'worsen': 312}
#
# ============================================================
# Outcome: dirkn8_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 885
#   Visit 08 R²                    : 0.0272
#   Visit 08 RMSE                  : 0.5953
#   Visit 08 MAE                   : 0.4501
#   Direction-of-change accuracy   : 0.8830 (n=188)
#   Three-way trajectory accuracy  : 0.1876 (n=885)
#   Actual trajectory distribution : {'improve': 74, 'stable': 697, 'worsen': 114}
#
# ============================================================
# Outcome: dirkn3_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0419
#   Visit 08 RMSE                  : 0.7956
#   Visit 08 MAE                   : 0.6510
#   Direction-of-change accuracy   : 0.8344 (n=320)
#   Three-way trajectory accuracy  : 0.2957 (n=903)
#   Actual trajectory distribution : {'improve': 147, 'stable': 583, 'worsen': 173}
#
# ============================================================
# Outcome: V06KOOSFX4  [ridge]
# ============================================================
#   Complete paired cases : 689
#   Visit 08 R²                    : 0.0581
#   Visit 08 RMSE                  : 0.8863
#   Visit 08 MAE                   : 0.7075
#   Direction-of-change accuracy   : 0.8244 (n=262)
#   Three-way trajectory accuracy  : 0.3135 (n=689)
#   Actual trajectory distribution : {'improve': 109, 'stable': 427, 'worsen': 153}
#
# ============================================================
# Outcome: dirkn15_symptomatic_side  [ridge]
# ============================================================
#   Complete paired cases : 902
#   Visit 08 R²                    : 0.0266
#   Visit 08 RMSE                  : 0.6564
#   Visit 08 MAE                   : 0.4983
#   Direction-of-change accuracy   : 0.8558 (n=215)
#   Three-way trajectory accuracy  : 0.2040 (n=902)
#   Actual trajectory distribution : {'improve': 97, 'stable': 687, 'worsen': 118}
#
# ============================================================
# Outcome: dirkn4_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0495
#   Visit 08 RMSE                  : 0.6089
#   Visit 08 MAE                   : 0.4547
#   Direction-of-change accuracy   : 0.9104 (n=212)
#   Three-way trajectory accuracy  : 0.2137 (n=903)
#   Actual trajectory distribution : {'improve': 82, 'stable': 691, 'worsen': 130}
#
# ============================================================
# Outcome: V06KOOSFX1  [elastic_net]
# ============================================================
#   Complete paired cases : 689
#   Visit 08 R²                    : 0.0165
#   Visit 08 RMSE                  : 0.9400
#   Visit 08 MAE                   : 0.7767
#   Direction-of-change accuracy   : 0.7993 (n=284)
#   Three-way trajectory accuracy  : 0.3295 (n=689)
#   Actual trajectory distribution : {'improve': 118, 'stable': 405, 'worsen': 166}
#
# ============================================================
# Outcome: dirkn6_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 903
#   Visit 08 R²                    : 0.0322
#   Visit 08 RMSE                  : 0.5761
#   Visit 08 MAE                   : 0.4312
#   Direction-of-change accuracy   : 0.9113 (n=203)
#   Three-way trajectory accuracy  : 0.2049 (n=903)
#   Actual trajectory distribution : {'improve': 90, 'stable': 700, 'worsen': 113}
#
# ============================================================
# Outcome: dirkn17_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 898
#   Visit 08 R²                    : 0.0348
#   Visit 08 RMSE                  : 0.5424
#   Visit 08 MAE                   : 0.4009
#   Direction-of-change accuracy   : 0.9148 (n=176)
#   Three-way trajectory accuracy  : 0.1793 (n=898)
#   Actual trajectory distribution : {'improve': 76, 'stable': 722, 'worsen': 100}
#
# ============================================================
# Outcome: dirkn16_symptomatic_side  [elastic_net]
# ============================================================
#   Complete paired cases : 841
#   Visit 08 R²                    : 0.0223
#   Visit 08 RMSE                  : 0.7608
#   Visit 08 MAE                   : 0.6085
#   Direction-of-change accuracy   : 0.8630 (n=292)
#   Three-way trajectory accuracy  : 0.2996 (n=841)
#   Actual trajectory distribution : {'improve': 117, 'stable': 549, 'worsen': 175}

# %%
longitudinal_summary_table = (
    pd.DataFrame(longitudinal_results)
    .sort_values("direction_of_change_accuracy", ascending=False)
    .reset_index(drop=True)
)

longitudinal_summary_table.to_csv(
    output_path / "stage_9_longitudinal_validation.csv",
    index=False,
)

print("\nStage 9 — Longitudinal validation summary (sorted by direction-of-change accuracy):")
print(longitudinal_summary_table[
    [
        "outcome_column",
        "n_paired",
        "n_direction_evaluated",
        "direction_of_change_accuracy",
        "three_way_accuracy",
        "test_r2_visit_08",
        "rmse_visit_08",
        "mae_visit_08",
    ]
].to_string(index=False))
# Out:
# Stage 9 — Longitudinal validation summary (sorted by direction-of-change accuracy):
#               outcome_column  n_paired  n_direction_evaluated  direction_of_change_accuracy  three_way_accuracy  test_r2_visit_08  rmse_visit_08  mae_visit_08
#     dirkn17_symptomatic_side       898                    176                      0.914773            0.179287          0.034809       0.542384      0.400878
#      dirkn6_symptomatic_side       903                    203                      0.911330            0.204873          0.032184       0.576081      0.431151
#      dirkn4_symptomatic_side       903                    212                      0.910377            0.213732          0.049484       0.608947      0.454655
#      dirkn8_symptomatic_side       885                    188                      0.882979            0.187571          0.027247       0.595290      0.450114
#     dirkn13_symptomatic_side       673                    139                      0.863309            0.178306          0.036493       0.655968      0.458235
#     dirkn16_symptomatic_side       841                    292                      0.863014            0.299643          0.022283       0.760805      0.608518
#     dirkn15_symptomatic_side       902                    215                      0.855814            0.203991          0.026584       0.656437      0.498347
#      dirkn3_symptomatic_side       903                    320                      0.834375            0.295681          0.041886       0.795603      0.651021
#      dirkn1_symptomatic_side       901                    338                      0.834320            0.312986          0.051968       0.800853      0.650789
#      dirkn5_symptomatic_side       851                    356                      0.828652            0.346651         -0.015192       0.897501      0.721939
#                   V06KOOSFX4       689                    262                      0.824427            0.313498          0.058145       0.886347      0.707477
#      dirkn2_symptomatic_side       900                    355                      0.822535            0.324444          0.062613       0.853183      0.686411
#                   V06KOOSFX1       689                    284                      0.799296            0.329463          0.016465       0.939952      0.776702
#                    V06LLD10B       898                    361                      0.792244            0.318486          0.008361       0.898995      0.735683
#                     V06LLD6A       899                    457                      0.781182            0.397108          0.152132       1.073842      0.871399
#   pain_7day_symptomatic_side       900                    606                      0.693069            0.466667          0.068780       2.522506      2.081450
# icoap_total_symptomatic_side       887                    584                      0.674658            0.444194          0.054670       9.657249      7.331833
#   koos_pain_symptomatic_side       903                    710                      0.639437            0.502769          0.077054      14.949115     12.024768
#                   V06STEPST1       878                    676                      0.639053            0.492027          0.371520       3.020075      2.300124
#                   V0620MPACE       878                    871                      0.632606            0.627563          0.309660       0.165391      0.127032

# %%
def build_per_participant_prediction_table(
    *,
    outcome_column: str,
    refitted_model_bundle: dict,
    paired_dataframe: pd.DataFrame,
    outcome_higher_is_worse: dict[str, bool],
) -> pd.DataFrame:
    """
    Build a per-participant prediction table for a single outcome.

    For each participant with complete data the table contains:
    - participant ID
    - observed Visit 06 value
    - predicted Visit 08 value
    - observed Visit 08 value
    - actual delta (observed V08 minus observed V06)
    - predicted delta (predicted V08 minus observed V06)
    - actual trajectory (improve / stable / worsen)
    - predicted trajectory (improve / stable / worsen)
    - correct: whether predicted trajectory matches actual trajectory

    :param outcome_column: Name of the outcome variable.
    :param refitted_model_bundle: Output of
        refit_winning_model_on_full_visit_06 for this outcome.
    :param paired_dataframe: Merged Visit 06 / Visit 08 dataframe with
        suffixes _v06 and _v08 on overlapping columns.
    :param outcome_higher_is_worse: Mapping of outcome column name to
        whether a higher value indicates worse status.
    :returns: DataFrame with one row per participant.
    """
    higher_is_worse = outcome_higher_is_worse[outcome_column]

    fitted_model = refitted_model_bundle["fitted_model"]
    scaler = refitted_model_bundle["scaler"]
    covariate_columns = refitted_model_bundle["covariate_columns"]
    activity_predictor_columns = refitted_model_bundle["activity_predictor_columns"]

    def resolve_column(column_name: str) -> str:
        """
        Return the correct column name in the paired dataframe for a
        given predictor or covariate column.

        :param column_name: Original column name before merging.
        :returns: Column name as it appears in the paired dataframe.
        """
        visit_08_column = f"{column_name}_v08"
        if visit_08_column in paired_dataframe.columns:
            return visit_08_column
        return column_name

    resolved_covariate_columns = [resolve_column(c) for c in covariate_columns]
    resolved_activity_columns = [resolve_column(c) for c in activity_predictor_columns]

    outcome_v06_column = (
        f"{outcome_column}_v06"
        if f"{outcome_column}_v06" in paired_dataframe.columns
        else outcome_column
    )
    outcome_v08_column = (
        f"{outcome_column}_v08"
        if f"{outcome_column}_v08" in paired_dataframe.columns
        else outcome_column.replace("V06", "V08")
    )

    all_required_columns = (
        ["ID"]
        + resolved_covariate_columns
        + resolved_activity_columns
        + [outcome_v06_column, outcome_v08_column]
    )

    complete_cases = paired_dataframe[all_required_columns].dropna()

    covariate_matrix = complete_cases[resolved_covariate_columns].values
    activity_matrix = complete_cases[resolved_activity_columns].values

    if scaler is not None:
        activity_matrix_scaled = scaler.transform(activity_matrix)
        full_matrix = np.hstack([covariate_matrix, activity_matrix_scaled])
    else:
        full_matrix = np.hstack([covariate_matrix, activity_matrix])

    visit_08_predictions = fitted_model.predict(full_matrix)
    observed_visit_06 = complete_cases[outcome_v06_column].values
    observed_visit_08 = complete_cases[outcome_v08_column].values

    actual_delta = observed_visit_08 - observed_visit_06
    predicted_delta = visit_08_predictions - observed_visit_06

    actual_trajectory = classify_trajectory(
        delta=actual_delta,
        higher_is_worse=higher_is_worse,
    )
    predicted_trajectory = classify_trajectory(
        delta=predicted_delta,
        higher_is_worse=higher_is_worse,
    )

    prediction_table = pd.DataFrame({
        "ID": complete_cases["ID"].values,
        "observed_v06": observed_visit_06,
        "predicted_v08": visit_08_predictions,
        "observed_v08": observed_visit_08,
        "actual_delta": actual_delta,
        "predicted_delta": predicted_delta,
        "actual_trajectory": actual_trajectory,
        "predicted_trajectory": predicted_trajectory,
        "correct": actual_trajectory == predicted_trajectory,
    })

    return prediction_table

# %%
per_participant_tables: dict[str, pd.DataFrame] = {}

for outcome_column, refitted_model_bundle in refitted_models.items():
    prediction_table = build_per_participant_prediction_table(
        outcome_column=outcome_column,
        refitted_model_bundle=refitted_model_bundle,
        paired_dataframe=paired_dataframe,
        outcome_higher_is_worse=OUTCOME_HIGHER_IS_WORSE,
    )

    per_participant_tables[outcome_column] = prediction_table

    output_filename = f"predictions_{outcome_column}.csv"
    prediction_table.to_csv(
        output_path / output_filename,
        index=False,
    )

print(
    f"Per-participant prediction tables built and saved for "
    f"{len(per_participant_tables)} outcomes."
)
print(
    f"\nTo inspect a specific outcome:\n"
    f"  per_participant_tables['koos_pain_symptomatic_side'].head(20)"
)
# Out:
# Per-participant prediction tables built and saved for 20 outcomes.
#
# To inspect a specific outcome:
#   per_participant_tables['koos_pain_symptomatic_side'].head(20)

# %%
# All participants predicted to improve but actually worsened
(
    per_participant_tables["koos_pain_symptomatic_side"]
    .query("actual_trajectory == 'worsen' and predicted_trajectory == 'improve'")
)
# Out:
#           ID  observed_v06  predicted_v08  observed_v08  actual_delta  \
# 9    9009957          86.1      87.761185          77.8          -8.3
# 29   9037697          75.0      84.774369          66.7          -8.3
# 33   9040958          80.6      84.789441          68.8         -11.8
# 39   9047539          72.2      95.446931          68.8          -3.4
# 40   9048789          58.3      83.295100          52.8          -5.5
# ..       ...           ...            ...           ...           ...
# 873  9958526          84.4      89.030059          69.4         -15.0
# 878  9969009          50.0      82.052743          25.0         -25.0
# 889  9983798          86.1      89.103745          83.3          -2.8
# 891  9986838          55.6      80.448165          52.8          -2.8
# 899  9996086          75.0      79.715381          55.6         -19.4
#
#      predicted_delta actual_trajectory predicted_trajectory  correct
# 9           1.661185            worsen              improve    False
# 29          9.774369            worsen              improve    False
# 33          4.189441            worsen              improve    False
# 39         23.246931            worsen              improve    False
# 40         24.995100            worsen              improve    False
# ..               ...               ...                  ...      ...
# 873         4.630059            worsen              improve    False
# 878        32.052743            worsen              improve    False
# 889         3.003745            worsen              improve    False
# 891        24.848165            worsen              improve    False
# 899         4.715381            worsen              improve    False
#
# [120 rows x 9 columns]

# %%
participant_id = 9048789

for outcome_column, prediction_table in per_participant_tables.items():
    row = prediction_table[prediction_table["ID"] == participant_id]
    if not row.empty:
        print(f"\n{outcome_column}")
        print(row.to_string(index=False))
# Out:
# V06STEPST1
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789          29.0      28.019815          32.0           3.0        -0.980185            worsen              improve    False
#
# V0620MPACE
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789         1.204       1.308499         0.999        -0.205         0.104499            worsen              improve    False
#
# dirkn1_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           2.0       0.736366           3.0           1.0        -1.263634            worsen              improve    False
#
# dirkn5_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           3.0       0.885299           2.0          -1.0        -2.114701           improve              improve     True
#
# V06LLD10B
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           5.0       4.167322           3.0          -2.0        -0.832678           improve              improve     True
#
# dirkn2_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           1.0       0.701438           1.0           0.0        -0.298562            stable              improve    False
#
# koos_pain_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789          58.3        83.2951          52.8          -5.5          24.9951            worsen              improve    False
#
# dirkn13_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           3.0       0.518176           2.0          -1.0        -2.481824           improve              improve     True
#
# icoap_total_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789          13.6       9.880226          11.4          -2.2        -3.719774           improve              improve     True
#
# V06LLD6A
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           1.0       2.868089           2.0           1.0         1.868089            worsen               worsen     True
#
# pain_7day_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           6.0       3.202241          10.0           4.0        -2.797759            worsen              improve    False
#
# dirkn8_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           0.0       0.444394           1.0           1.0         0.444394            worsen               worsen     True
#
# dirkn3_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           1.0       0.733618           2.0           1.0        -0.266382            worsen              improve    False
#
# dirkn15_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           2.0       0.440278           2.0           0.0        -1.559722            stable              improve    False
#
# dirkn4_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           0.0       0.410412           0.0           0.0         0.410412            stable               worsen    False
#
# dirkn6_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           1.0       0.452006           1.0           0.0        -0.547994            stable              improve    False
#
# dirkn17_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           1.0       0.321474           1.0           0.0        -0.678526            stable              improve    False
#
# dirkn16_symptomatic_side
#      ID  observed_v06  predicted_v08  observed_v08  actual_delta  predicted_delta actual_trajectory predicted_trajectory  correct
# 9048789           2.0        0.53436           2.0           0.0         -1.46564            stable              improve    False

# %%
all_outcomes_per_participant = pd.concat(
    [
        prediction_table.assign(outcome=outcome_column)
        for outcome_column, prediction_table in per_participant_tables.items()
    ],
    ignore_index=True,
)

all_outcomes_per_participant = all_outcomes_per_participant[
    [
        "ID",
        "outcome",
        "observed_v06",
        "predicted_v08",
        "observed_v08",
        "actual_delta",
        "predicted_delta",
        "actual_trajectory",
        "predicted_trajectory",
        "correct",
    ]
]

all_outcomes_per_participant.to_csv(
    output_path / "predictions_all_outcomes.csv",
    index=False,
)

print(
    f"Saved predictions for {all_outcomes_per_participant['ID'].nunique():,} "
    f"participants across {all_outcomes_per_participant['outcome'].nunique()} "
    f"outcomes — {len(all_outcomes_per_participant):,} rows total."
)
# Out:
# Saved predictions for 903 participants across 20 outcomes — 17,181 rows total.

# %%
trajectory_accuracy_summary = (
    all_outcomes_per_participant
    .groupby(["outcome", "actual_trajectory", "predicted_trajectory"])
    .size()
    .reset_index(name="count")
    .sort_values(["outcome", "actual_trajectory", "predicted_trajectory"])
)

print(trajectory_accuracy_summary.to_string(index=False))
# Out:
#                      outcome actual_trajectory predicted_trajectory  count
#                   V0620MPACE           improve              improve    232
#                   V0620MPACE           improve               worsen    139
#                   V0620MPACE            stable              improve      5
#                   V0620MPACE            stable               worsen      2
#                   V0620MPACE            worsen              improve    181
#                   V0620MPACE            worsen               worsen    319
#                   V06KOOSFX1           improve              improve    100
#                   V06KOOSFX1           improve               worsen     18
#                   V06KOOSFX1            stable              improve    136
#                   V06KOOSFX1            stable               worsen    269
#                   V06KOOSFX1            worsen              improve     39
#                   V06KOOSFX1            worsen               worsen    127
#                   V06KOOSFX4           improve              improve    103
#                   V06KOOSFX4           improve               worsen      6
#                   V06KOOSFX4            stable              improve     88
#                   V06KOOSFX4            stable               worsen    339
#                   V06KOOSFX4            worsen              improve     40
#                   V06KOOSFX4            worsen               worsen    113
#                    V06LLD10B           improve              improve    124
#                    V06LLD10B           improve               worsen     58
#                    V06LLD10B            stable              improve    394
#                    V06LLD10B            stable               worsen    143
#                    V06LLD10B            worsen              improve     17
#                    V06LLD10B            worsen               worsen    162
#                     V06LLD6A           improve              improve    198
#                     V06LLD6A           improve               worsen     53
#                     V06LLD6A            stable              improve    260
#                     V06LLD6A            stable               worsen    182
#                     V06LLD6A            worsen              improve     47
#                     V06LLD6A            worsen               worsen    159
#                   V06STEPST1           improve              improve    180
#                   V06STEPST1           improve               worsen    116
#                   V06STEPST1            stable              improve     84
#                   V06STEPST1            stable               worsen    118
#                   V06STEPST1            worsen              improve    128
#                   V06STEPST1            worsen               worsen    252
#     dirkn13_symptomatic_side           improve              improve     54
#     dirkn13_symptomatic_side            stable              improve     76
#     dirkn13_symptomatic_side            stable               worsen    458
#     dirkn13_symptomatic_side            worsen              improve     19
#     dirkn13_symptomatic_side            worsen               worsen     66
#     dirkn15_symptomatic_side           improve              improve     97
#     dirkn15_symptomatic_side            stable              improve    101
#     dirkn15_symptomatic_side            stable               worsen    586
#     dirkn15_symptomatic_side            worsen              improve     31
#     dirkn15_symptomatic_side            worsen               worsen     87
#     dirkn16_symptomatic_side           improve              improve    116
#     dirkn16_symptomatic_side           improve               worsen      1
#     dirkn16_symptomatic_side            stable              improve     99
#     dirkn16_symptomatic_side            stable               worsen    450
#     dirkn16_symptomatic_side            worsen              improve     39
#     dirkn16_symptomatic_side            worsen               worsen    136
#     dirkn17_symptomatic_side           improve              improve     76
#     dirkn17_symptomatic_side            stable              improve     95
#     dirkn17_symptomatic_side            stable               worsen    627
#     dirkn17_symptomatic_side            worsen              improve     15
#     dirkn17_symptomatic_side            worsen               worsen     85
#      dirkn1_symptomatic_side           improve              improve    141
#      dirkn1_symptomatic_side           improve               worsen      4
#      dirkn1_symptomatic_side            stable              improve    138
#      dirkn1_symptomatic_side            stable               worsen    425
#      dirkn1_symptomatic_side            worsen              improve     52
#      dirkn1_symptomatic_side            worsen               worsen    141
#      dirkn2_symptomatic_side           improve              improve    137
#      dirkn2_symptomatic_side           improve               worsen      4
#      dirkn2_symptomatic_side            stable              improve    136
#      dirkn2_symptomatic_side            stable               worsen    409
#      dirkn2_symptomatic_side            worsen              improve     59
#      dirkn2_symptomatic_side            worsen               worsen    155
#      dirkn3_symptomatic_side           improve              improve    140
#      dirkn3_symptomatic_side           improve               worsen      7
#      dirkn3_symptomatic_side            stable              improve    137
#      dirkn3_symptomatic_side            stable               worsen    446
#      dirkn3_symptomatic_side            worsen              improve     46
#      dirkn3_symptomatic_side            worsen               worsen    127
#      dirkn4_symptomatic_side           improve              improve     82
#      dirkn4_symptomatic_side            stable              improve    101
#      dirkn4_symptomatic_side            stable               worsen    590
#      dirkn4_symptomatic_side            worsen              improve     19
#      dirkn4_symptomatic_side            worsen               worsen    111
#      dirkn5_symptomatic_side           improve              improve    143
#      dirkn5_symptomatic_side           improve               worsen      9
#      dirkn5_symptomatic_side            stable              improve    107
#      dirkn5_symptomatic_side            stable               worsen    388
#      dirkn5_symptomatic_side            worsen              improve     52
#      dirkn5_symptomatic_side            worsen               worsen    152
#      dirkn6_symptomatic_side           improve              improve     90
#      dirkn6_symptomatic_side            stable              improve    111
#      dirkn6_symptomatic_side            stable               worsen    589
#      dirkn6_symptomatic_side            worsen              improve     18
#      dirkn6_symptomatic_side            worsen               worsen     95
#      dirkn8_symptomatic_side           improve              improve     74
#      dirkn8_symptomatic_side            stable              improve    123
#      dirkn8_symptomatic_side            stable               worsen    574
#      dirkn8_symptomatic_side            worsen              improve     22
#      dirkn8_symptomatic_side            worsen               worsen     92
# icoap_total_symptomatic_side           improve              improve    180
# icoap_total_symptomatic_side           improve               worsen     97
# icoap_total_symptomatic_side            stable              improve     26
# icoap_total_symptomatic_side            stable               worsen    277
# icoap_total_symptomatic_side            worsen              improve     93
# icoap_total_symptomatic_side            worsen               worsen    214
#   koos_pain_symptomatic_side           improve              improve    190
#   koos_pain_symptomatic_side           improve               worsen    136
#   koos_pain_symptomatic_side            stable              improve     22
#   koos_pain_symptomatic_side            stable               worsen    171
#   koos_pain_symptomatic_side            worsen              improve    120
#   koos_pain_symptomatic_side            worsen               worsen    264
#   pain_7day_symptomatic_side           improve              improve    203
#   pain_7day_symptomatic_side           improve               worsen     91
#   pain_7day_symptomatic_side            stable              improve     71
#   pain_7day_symptomatic_side            stable               worsen    223
#   pain_7day_symptomatic_side            worsen              improve     95
#   pain_7day_symptomatic_side            worsen               worsen    217
